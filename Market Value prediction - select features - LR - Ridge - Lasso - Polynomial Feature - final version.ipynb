# %%
# Data manipulation
import pandas as pd
import numpy as np

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sb
from pandas.plotting import scatter_matrix

# Machine Learning Algorithms
import sklearn
from sklearn.linear_model import LinearRegression, Lasso, LassoCV, Ridge, RidgeCV, ElasticNet, ElasticNetCV
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.pipeline import make_pipeline

# Model Selection and Evaluation
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold


# Performance
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error

#decision tree
import sklearn.tree as sktree

# For Missing Values
from sklearn.impute import SimpleImputer

import statsmodels.api as sm
import patsy
# Out:
# C:\Users\Kiko\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# C:\Users\Kiko\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,

# %%
import seaborn as sns #visualisation
import scipy
from scipy import stats
from scipy.stats.mstats import winsorize

# %% [markdown]
# # Get the data

# %%
players_22 = pd.read_csv('./FIFA/players_22.csv', index_col='sofifa_id')
# Out:
# C:\Users\Kiko\AppData\Local\Temp\ipykernel_22732\1465523920.py:1: DtypeWarning: Columns (25,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   players_22 = pd.read_csv('./FIFA/players_22.csv', index_col='sofifa_id')

# %%
players_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19239 entries, 158023 to 264540
# Columns: 109 entries, player_url to nation_flag_url
# dtypes: float64(16), int64(43), object(50)
# memory usage: 16.1+ MB

# %% [markdown]
# # Structure of the file

# %%
players_22.sort_values(by='value_eur', ascending=False).head(20)
# Out:
#                                                   player_url  \
# sofifa_id
# 231747     https://sofifa.com/player/231747/kylian-mbappe...
# 239085     https://sofifa.com/player/239085/erling-haalan...
# 202126     https://sofifa.com/player/202126/harry-kane/22...
# 190871     https://sofifa.com/player/190871/neymar-da-sil...
# 192985     https://sofifa.com/player/192985/kevin-de-bruy...
# 188545     https://sofifa.com/player/188545/robert-lewand...
# 228702     https://sofifa.com/player/228702/frenkie-de-jo...
# 230621     https://sofifa.com/player/230621/gianluigi-don...
# 233049     https://sofifa.com/player/233049/jadon-sancho/...
# 231281     https://sofifa.com/player/231281/trent-alexand...
# 200389     https://sofifa.com/player/200389/jan-oblak/220002
# 212622     https://sofifa.com/player/212622/joshua-kimmic...
# 212198     https://sofifa.com/player/212198/bruno-miguel-...
# 202652     https://sofifa.com/player/202652/raheem-sterli...
# 200104     https://sofifa.com/player/200104/heung-min-son...
# 239818     https://sofifa.com/player/239818/ruben-santos-...
# 209331     https://sofifa.com/player/209331/mohamed-salah...
# 208722     https://sofifa.com/player/208722/sadio-mane/22...
# 215914     https://sofifa.com/player/215914/ngolo-kante/2...
# 192448     https://sofifa.com/player/192448/marc-andre-te...
#
#                     short_name                         long_name  \
# sofifa_id
# 231747               K. Mbappé              Kylian Mbappé Lottin
# 239085              E. Haaland              Erling Braut Haaland
# 202126                 H. Kane                        Harry Kane
# 190871               Neymar Jr     Neymar da Silva Santos Júnior
# 192985            K. De Bruyne                   Kevin De Bruyne
# 188545          R. Lewandowski                Robert Lewandowski
# 228702              F. de Jong                   Frenkie de Jong
# 230621           G. Donnarumma              Gianluigi Donnarumma
# 233049               J. Sancho                      Jadon Sancho
# 231281     T. Alexander-Arnold            Trent Alexander-Arnold
# 200389                J. Oblak                         Jan Oblak
# 212622              J. Kimmich             Joshua Walter Kimmich
# 212198         Bruno Fernandes     Bruno Miguel Borges Fernandes
# 202652             R. Sterling                   Raheem Sterling
# 200104                  H. Son                           손흥민 孙兴慜
# 239818              Rúben Dias  Rúben dos Santos Gato Alves Dias
# 209331                M. Salah               Mohamed Salah Ghaly
# 208722                 S. Mané                        Sadio Mané
# 215914                N. Kanté                      N'Golo Kanté
# 192448           M. ter Stegen             Marc-André ter Stegen
#
#           player_positions  overall  potential    value_eur  wage_eur  age  \
# sofifa_id
# 231747              ST, LW       91         95  194000000.0  230000.0   22
# 239085                  ST       88         93  137500000.0  110000.0   20
# 202126                  ST       90         90  129500000.0  240000.0   27
# 190871             LW, CAM       91         91  129000000.0  270000.0   29
# 192985             CM, CAM       91         91  125500000.0  350000.0   30
# 188545                  ST       92         92  119500000.0  270000.0   32
# 228702         CM, CDM, CB       87         92  119500000.0  210000.0   24
# 230621                  GK       89         93  119500000.0  110000.0   22
# 233049          RM, CF, LM       87         91  116500000.0  150000.0   21
# 231281                  RB       87         92  114000000.0  150000.0   22
# 200389                  GK       91         93  112000000.0  130000.0   28
# 212622             CDM, RB       89         90  108000000.0  160000.0   26
# 212198                 CAM       88         89  107500000.0  250000.0   26
# 202652              LW, RW       88         89  107500000.0  290000.0   26
# 200104          LM, CF, LW       89         89  104000000.0  220000.0   28
# 239818                  CB       87         91  102500000.0  170000.0   24
# 209331                  RW       89         89  101000000.0  270000.0   29
# 208722                  LW       89         89  101000000.0  270000.0   29
# 215914             CDM, CM       90         90  100000000.0  230000.0   30
# 192448                  GK       90         92   99000000.0  250000.0   29
#
#                   dob  ...   lcb    cb   rcb    rb    gk  \
# sofifa_id              ...
# 231747     1998-12-20  ...  54+3  54+3  54+3  63+3  18+3
# 239085     2000-07-21  ...  60+3  60+3  60+3  60+3  19+3
# 202126     1993-07-28  ...  61+3  61+3  61+3  64+3  20+3
# 190871     1992-02-05  ...  50+3  50+3  50+3  62+3  20+3
# 192985     1991-06-28  ...  69+3  69+3  69+3  75+3  21+3
# 188545     1988-08-21  ...  60+3  60+3  60+3  61+3  19+3
# 228702     1997-05-12  ...  78+3  78+3  78+3  82+3  18+3
# 230621     1999-02-25  ...  31+3  31+3  31+3  31+3  87+3
# 233049     2000-03-25  ...  48+3  48+3  48+3  60+3  19+3
# 231281     1998-10-07  ...  78+3  78+3  78+3  83+3  19+3
# 200389     1993-01-07  ...  33+3  33+3  33+3  32+3  89+3
# 212622     1995-02-08  ...  81+3  81+3  81+3  83+3  21+3
# 212198     1994-09-08  ...  73+3  73+3  73+3  77+3  21+3
# 202652     1994-12-08  ...  55+3  55+3  55+3  65+3  21+3
# 200104     1992-07-08  ...  54+3  54+3  54+3  64+3  19+3
# 239818     1997-05-14  ...  86+3  86+3  86+3  80+3  17+3
# 209331     1992-06-15  ...  58+3  58+3  58+3  67+3  22+3
# 208722     1992-04-10  ...  59+3  59+3  59+3  65+3  19+3
# 215914     1991-03-29  ...  84+3  84+3  84+3  85+3  20+3
# 192448     1992-04-30  ...  33+3  33+3  33+3  31+3  88+3
#
#                                              player_face_url  \
# sofifa_id
# 231747     https://cdn.sofifa.net/players/231/747/22_120.png
# 239085     https://cdn.sofifa.net/players/239/085/22_120.png
# 202126     https://cdn.sofifa.net/players/202/126/22_120.png
# 190871     https://cdn.sofifa.net/players/190/871/22_120.png
# 192985     https://cdn.sofifa.net/players/192/985/22_120.png
# 188545     https://cdn.sofifa.net/players/188/545/22_120.png
# 228702     https://cdn.sofifa.net/players/228/702/22_120.png
# 230621     https://cdn.sofifa.net/players/230/621/22_120.png
# 233049     https://cdn.sofifa.net/players/233/049/22_120.png
# 231281     https://cdn.sofifa.net/players/231/281/22_120.png
# 200389     https://cdn.sofifa.net/players/200/389/22_120.png
# 212622     https://cdn.sofifa.net/players/212/622/22_120.png
# 212198     https://cdn.sofifa.net/players/212/198/22_120.png
# 202652     https://cdn.sofifa.net/players/202/652/22_120.png
# 200104     https://cdn.sofifa.net/players/200/104/22_120.png
# 239818     https://cdn.sofifa.net/players/239/818/22_120.png
# 209331     https://cdn.sofifa.net/players/209/331/22_120.png
# 208722     https://cdn.sofifa.net/players/208/722/22_120.png
# 215914     https://cdn.sofifa.net/players/215/914/22_120.png
# 192448     https://cdn.sofifa.net/players/192/448/22_120.png
#
#                                      club_logo_url  \
# sofifa_id
# 231747      https://cdn.sofifa.net/teams/73/60.png
# 239085      https://cdn.sofifa.net/teams/22/60.png
# 202126      https://cdn.sofifa.net/teams/18/60.png
# 190871      https://cdn.sofifa.net/teams/73/60.png
# 192985      https://cdn.sofifa.net/teams/10/60.png
# 188545      https://cdn.sofifa.net/teams/21/60.png
# 228702     https://cdn.sofifa.net/teams/241/60.png
# 230621      https://cdn.sofifa.net/teams/73/60.png
# 233049      https://cdn.sofifa.net/teams/11/60.png
# 231281       https://cdn.sofifa.net/teams/9/60.png
# 200389     https://cdn.sofifa.net/teams/240/60.png
# 212622      https://cdn.sofifa.net/teams/21/60.png
# 212198      https://cdn.sofifa.net/teams/11/60.png
# 202652      https://cdn.sofifa.net/teams/10/60.png
# 200104      https://cdn.sofifa.net/teams/18/60.png
# 239818      https://cdn.sofifa.net/teams/10/60.png
# 209331       https://cdn.sofifa.net/teams/9/60.png
# 208722       https://cdn.sofifa.net/teams/9/60.png
# 215914       https://cdn.sofifa.net/teams/5/60.png
# 192448     https://cdn.sofifa.net/teams/241/60.png
#
#                                      club_flag_url  \
# sofifa_id
# 231747         https://cdn.sofifa.net/flags/fr.png
# 239085         https://cdn.sofifa.net/flags/de.png
# 202126     https://cdn.sofifa.net/flags/gb-eng.png
# 190871         https://cdn.sofifa.net/flags/fr.png
# 192985     https://cdn.sofifa.net/flags/gb-eng.png
# 188545         https://cdn.sofifa.net/flags/de.png
# 228702         https://cdn.sofifa.net/flags/es.png
# 230621         https://cdn.sofifa.net/flags/fr.png
# 233049     https://cdn.sofifa.net/flags/gb-eng.png
# 231281     https://cdn.sofifa.net/flags/gb-eng.png
# 200389         https://cdn.sofifa.net/flags/es.png
# 212622         https://cdn.sofifa.net/flags/de.png
# 212198     https://cdn.sofifa.net/flags/gb-eng.png
# 202652     https://cdn.sofifa.net/flags/gb-eng.png
# 200104     https://cdn.sofifa.net/flags/gb-eng.png
# 239818     https://cdn.sofifa.net/flags/gb-eng.png
# 209331     https://cdn.sofifa.net/flags/gb-eng.png
# 208722     https://cdn.sofifa.net/flags/gb-eng.png
# 215914     https://cdn.sofifa.net/flags/gb-eng.png
# 192448         https://cdn.sofifa.net/flags/es.png
#
#                                       nation_logo_url  \
# sofifa_id
# 231747       https://cdn.sofifa.net/teams/1335/60.png
# 239085       https://cdn.sofifa.net/teams/1352/60.png
# 202126       https://cdn.sofifa.net/teams/1318/60.png
# 190871                                            NaN
# 192985       https://cdn.sofifa.net/teams/1325/60.png
# 188545       https://cdn.sofifa.net/teams/1353/60.png
# 228702     https://cdn.sofifa.net/teams/105035/60.png
# 230621       https://cdn.sofifa.net/teams/1343/60.png
# 233049       https://cdn.sofifa.net/teams/1318/60.png
# 231281       https://cdn.sofifa.net/teams/1318/60.png
# 200389                                            NaN
# 212622       https://cdn.sofifa.net/teams/1337/60.png
# 212198       https://cdn.sofifa.net/teams/1354/60.png
# 202652       https://cdn.sofifa.net/teams/1318/60.png
# 200104                                            NaN
# 239818       https://cdn.sofifa.net/teams/1354/60.png
# 209331                                            NaN
# 208722                                            NaN
# 215914       https://cdn.sofifa.net/teams/1335/60.png
# 192448                                            NaN
#
#                                    nation_flag_url
# sofifa_id
# 231747         https://cdn.sofifa.net/flags/fr.png
# 239085         https://cdn.sofifa.net/flags/no.png
# 202126     https://cdn.sofifa.net/flags/gb-eng.png
# 190871         https://cdn.sofifa.net/flags/br.png
# 192985         https://cdn.sofifa.net/flags/be.png
# 188545         https://cdn.sofifa.net/flags/pl.png
# 228702         https://cdn.sofifa.net/flags/nl.png
# 230621         https://cdn.sofifa.net/flags/it.png
# 233049     https://cdn.sofifa.net/flags/gb-eng.png
# 231281     https://cdn.sofifa.net/flags/gb-eng.png
# 200389         https://cdn.sofifa.net/flags/si.png
# 212622         https://cdn.sofifa.net/flags/de.png
# 212198         https://cdn.sofifa.net/flags/pt.png
# 202652     https://cdn.sofifa.net/flags/gb-eng.png
# 200104         https://cdn.sofifa.net/flags/kr.png
# 239818         https://cdn.sofifa.net/flags/pt.png
# 209331         https://cdn.sofifa.net/flags/eg.png
# 208722         https://cdn.sofifa.net/flags/sn.png
# 215914         https://cdn.sofifa.net/flags/fr.png
# 192448         https://cdn.sofifa.net/flags/de.png
#
# [20 rows x 109 columns]

# %%
players_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19239 entries, 158023 to 264540
# Columns: 109 entries, player_url to nation_flag_url
# dtypes: float64(16), int64(43), object(50)
# memory usage: 16.1+ MB

# %%
players_22.shape
# Out:
# (19239, 109)

# %% [markdown]
# # Data Cleaning

# %%
players_22.columns
# Out:
# Index(['player_url', 'short_name', 'long_name', 'player_positions', 'overall',
#        'potential', 'value_eur', 'wage_eur', 'age', 'dob',
#        ...
#        'lcb', 'cb', 'rcb', 'rb', 'gk', 'player_face_url', 'club_logo_url',
#        'club_flag_url', 'nation_logo_url', 'nation_flag_url'],
#       dtype='object', length=109)

# %%
players_22.head()
# Out:
#                                                   player_url  \
# sofifa_id
# 158023     https://sofifa.com/player/158023/lionel-messi/...
# 188545     https://sofifa.com/player/188545/robert-lewand...
# 20801      https://sofifa.com/player/20801/c-ronaldo-dos-...
# 190871     https://sofifa.com/player/190871/neymar-da-sil...
# 192985     https://sofifa.com/player/192985/kevin-de-bruy...
#
#                   short_name                            long_name  \
# sofifa_id
# 158023              L. Messi       Lionel Andrés Messi Cuccittini
# 188545        R. Lewandowski                   Robert Lewandowski
# 20801      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 190871             Neymar Jr        Neymar da Silva Santos Júnior
# 192985          K. De Bruyne                      Kevin De Bruyne
#
#           player_positions  overall  potential    value_eur  wage_eur  age  \
# sofifa_id
# 158023          RW, ST, CF       93         93   78000000.0  320000.0   34
# 188545                  ST       92         92  119500000.0  270000.0   32
# 20801               ST, LW       91         91   45000000.0  270000.0   36
# 190871             LW, CAM       91         91  129000000.0  270000.0   29
# 192985             CM, CAM       91         91  125500000.0  350000.0   30
#
#                   dob  ...   lcb    cb   rcb    rb    gk  \
# sofifa_id              ...
# 158023     1987-06-24  ...  50+3  50+3  50+3  61+3  19+3
# 188545     1988-08-21  ...  60+3  60+3  60+3  61+3  19+3
# 20801      1985-02-05  ...  53+3  53+3  53+3  60+3  20+3
# 190871     1992-02-05  ...  50+3  50+3  50+3  62+3  20+3
# 192985     1991-06-28  ...  69+3  69+3  69+3  75+3  21+3
#
#                                              player_face_url  \
# sofifa_id
# 158023     https://cdn.sofifa.net/players/158/023/22_120.png
# 188545     https://cdn.sofifa.net/players/188/545/22_120.png
# 20801      https://cdn.sofifa.net/players/020/801/22_120.png
# 190871     https://cdn.sofifa.net/players/190/871/22_120.png
# 192985     https://cdn.sofifa.net/players/192/985/22_120.png
#
#                                     club_logo_url  \
# sofifa_id
# 158023     https://cdn.sofifa.net/teams/73/60.png
# 188545     https://cdn.sofifa.net/teams/21/60.png
# 20801      https://cdn.sofifa.net/teams/11/60.png
# 190871     https://cdn.sofifa.net/teams/73/60.png
# 192985     https://cdn.sofifa.net/teams/10/60.png
#
#                                      club_flag_url  \
# sofifa_id
# 158023         https://cdn.sofifa.net/flags/fr.png
# 188545         https://cdn.sofifa.net/flags/de.png
# 20801      https://cdn.sofifa.net/flags/gb-eng.png
# 190871         https://cdn.sofifa.net/flags/fr.png
# 192985     https://cdn.sofifa.net/flags/gb-eng.png
#
#                                     nation_logo_url  \
# sofifa_id
# 158023     https://cdn.sofifa.net/teams/1369/60.png
# 188545     https://cdn.sofifa.net/teams/1353/60.png
# 20801      https://cdn.sofifa.net/teams/1354/60.png
# 190871                                          NaN
# 192985     https://cdn.sofifa.net/teams/1325/60.png
#
#                                nation_flag_url
# sofifa_id
# 158023     https://cdn.sofifa.net/flags/ar.png
# 188545     https://cdn.sofifa.net/flags/pl.png
# 20801      https://cdn.sofifa.net/flags/pt.png
# 190871     https://cdn.sofifa.net/flags/br.png
# 192985     https://cdn.sofifa.net/flags/be.png
#
# [5 rows x 109 columns]

# %%
#Keep only the target column and the columns which are not calculated using our target , or they can be calculated using the target and Item since we only have one item now
players_22 = players_22.drop(columns = ['player_url','long_name','club_loaned_from','club_contract_valid_until','club_joined','nation_team_id','nation_position','club_position','work_rate','body_type','real_face','player_tags','player_traits','player_face_url','club_logo_url','club_flag_url','nation_logo_url','nation_flag_url',
                                       'ls','st','rs','lw','lf','cf','rf','rw','lam','cam','ram','lm','lcm','cm','rcm','rm','lwb','ldm','cdm','rdm','rwb','lb','lcb','cb','rcb','rb','gk',
                                        'player_positions', 'dob', 'weak_foot', 'club_team_id',
                                        'club_name', 
                                        'league_name','league_level', 'club_jersey_number', 'nationality_id', 'nationality_name', 'nation_jersey_number',
                                        'wage_eur','height_cm','weight_kg','release_clause_eur',
                                        'pace','shooting','passing','dribbling','defending',
                                        'physic','attacking_short_passing','skill_curve',
                                        'mentality_interceptions','defending_standing_tackle',
                                        'goalkeeping_reflexes','goalkeeping_speed'])
                                        #'skill_moves', 'release_clause_eur', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy',
                                        #'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
                                        #'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
                                        #'movement_reactions', 'movement_balance', 'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots', 'attacking_short_passing',
                                        #'defending_marking_awareness','defending_sliding_tackle','defending_standing_tackle',
                                        #'defending'])
players_22
# Out:
#                    short_name  overall  potential    value_eur  age  \
# sofifa_id
# 158023               L. Messi       93         93   78000000.0   34
# 188545         R. Lewandowski       92         92  119500000.0   32
# 20801       Cristiano Ronaldo       91         91   45000000.0   36
# 190871              Neymar Jr       91         91  129000000.0   29
# 192985           K. De Bruyne       91         91  125500000.0   30
# ...                       ...      ...        ...          ...  ...
# 261962              Song Defu       47         52      70000.0   22
# 262040              C. Porter       47         59     110000.0   19
# 262760               N. Logue       47         55     100000.0   21
# 262820              L. Rudden       47         60     110000.0   19
# 264540     E. Lalchhanchhuaha       47         60     110000.0   19
#
#           preferred_foot  skill_moves  international_reputation  \
# sofifa_id
# 158023              Left            4                         5
# 188545             Right            4                         5
# 20801              Right            5                         5
# 190871             Right            5                         5
# 192985             Right            4                         4
# ...                  ...          ...                       ...
# 261962             Right            2                         1
# 262040             Right            2                         1
# 262760             Right            2                         1
# 262820             Right            2                         1
# 264540             Right            2                         1
#
#            attacking_crossing  attacking_finishing  ...  \
# sofifa_id                                           ...
# 158023                     85                   95  ...
# 188545                     71                   95  ...
# 20801                      87                   95  ...
# 190871                     85                   83  ...
# 192985                     94                   82  ...
# ...                       ...                  ...  ...
# 261962                     46                   32  ...
# 262040                     54                   33  ...
# 262760                     39                   32  ...
# 262820                     29                   49  ...
# 264540                     39                   32  ...
#
#            mentality_positioning  mentality_vision  mentality_penalties  \
# sofifa_id
# 158023                        93                95                   75
# 188545                        95                81                   90
# 20801                         95                76                   88
# 190871                        86                90                   93
# 192985                        88                94                   83
# ...                          ...               ...                  ...
# 261962                        38                43                   42
# 262040                        51                49                   44
# 262760                        45                46                   39
# 262820                        47                40                   49
# 264540                        47                46                   35
#
#            mentality_composure  defending_marking_awareness  \
# sofifa_id
# 158023                      96                           20
# 188545                      88                           35
# 20801                       95                           24
# 190871                      93                           35
# 192985                      89                           68
# ...                        ...                          ...
# 261962                      37                           38
# 262040                      47                           37
# 262760                      36                           38
# 262820                      47                           10
# 264540                      36                           33
#
#            defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# sofifa_id
# 158023                           24                   6                    11
# 188545                           19                  15                     6
# 20801                            24                   7                    11
# 190871                           29                   9                     9
# 192985                           53                  15                    13
# ...                             ...                 ...                   ...
# 261962                           48                   6                    10
# 262040                           47                  11                    12
# 262760                           48                   8                     6
# 262820                           11                   7                    10
# 264540                           37                   8                    13
#
#            goalkeeping_kicking  goalkeeping_positioning
# sofifa_id
# 158023                      15                       14
# 188545                      12                        8
# 20801                       15                       14
# 190871                      15                       15
# 192985                       5                       10
# ...                        ...                      ...
# 261962                       5                       15
# 262040                       6                        8
# 262760                       7                       10
# 262820                       7                       14
# 264540                      13                        9
#
# [19239 rows x 37 columns]

# %%
players_22.describe()
# Out:
#             overall     potential     value_eur           age   skill_moves  \
# count  19239.000000  19239.000000  1.916500e+04  19239.000000  19239.000000
# mean      65.772182     71.079370  2.850452e+06     25.210822      2.352461
# std        6.880232      6.086213  7.613700e+06      4.748235      0.767659
# min       47.000000     49.000000  9.000000e+03     16.000000      1.000000
# 25%       61.000000     67.000000  4.750000e+05     21.000000      2.000000
# 50%       66.000000     71.000000  9.750000e+05     25.000000      2.000000
# 75%       70.000000     75.000000  2.000000e+06     29.000000      3.000000
# max       93.000000     95.000000  1.940000e+08     54.000000      5.000000
#
#        international_reputation  attacking_crossing  attacking_finishing  \
# count              19239.000000        19239.000000         19239.000000
# mean                   1.094496           49.577421            45.894433
# std                    0.371859           18.034661            19.721023
# min                    1.000000            6.000000             2.000000
# 25%                    1.000000           38.000000            30.000000
# 50%                    1.000000           54.000000            50.000000
# 75%                    1.000000           63.000000            62.000000
# max                    5.000000           94.000000            95.000000
#
#        attacking_heading_accuracy  attacking_volleys  ...  \
# count                19239.000000       19239.000000  ...
# mean                    51.783877          42.463849  ...
# std                     17.294183          17.653329  ...
# min                      5.000000           3.000000  ...
# 25%                     44.000000          30.000000  ...
# 50%                     55.000000          43.000000  ...
# 75%                     64.000000          56.000000  ...
# max                     93.000000          90.000000  ...
#
#        mentality_positioning  mentality_vision  mentality_penalties  \
# count           19239.000000      19239.000000         19239.000000
# mean               50.330215         53.964603            47.858724
# std                19.621601         13.650481            15.768583
# min                 2.000000         10.000000             7.000000
# 25%                40.000000         45.000000            38.000000
# 50%                56.000000         55.000000            49.000000
# 75%                64.000000         64.000000            60.000000
# max                96.000000         95.000000            93.000000
#
#        mentality_composure  defending_marking_awareness  \
# count         19239.000000                 19239.000000
# mean             57.929830                    46.601746
# std              12.159326                    20.200807
# min              12.000000                     4.000000
# 25%              50.000000                    29.000000
# 50%              59.000000                    52.000000
# 75%              66.000000                    63.000000
# max              96.000000                    93.000000
#
#        defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# count              19239.000000        19239.000000          19239.000000
# mean                  45.906700           16.406102             16.192474
# std                   20.755683           17.574028             16.839528
# min                    5.000000            2.000000              2.000000
# 25%                   25.000000            8.000000              8.000000
# 50%                   53.000000           11.000000             11.000000
# 75%                   63.000000           14.000000             14.000000
# max                   92.000000           91.000000             92.000000
#
#        goalkeeping_kicking  goalkeeping_positioning
# count         19239.000000             19239.000000
# mean             16.055356                16.229274
# std              16.564554                17.059779
# min               2.000000                 2.000000
# 25%               8.000000                 8.000000
# 50%              11.000000                11.000000
# 75%              14.000000                14.000000
# max              93.000000                92.000000
#
# [8 rows x 35 columns]

# %%
players_22.dtypes
# Out:
# short_name                      object
# overall                          int64
# potential                        int64
# value_eur                      float64
# age                              int64
# preferred_foot                  object
# skill_moves                      int64
# international_reputation         int64
# attacking_crossing               int64
# attacking_finishing              int64
# attacking_heading_accuracy       int64
# attacking_volleys                int64
# skill_dribbling                  int64
# skill_fk_accuracy                int64
# skill_long_passing               int64
# skill_ball_control               int64
# movement_acceleration            int64
# movement_sprint_speed            int64
# movement_agility                 int64
# movement_reactions               int64
# movement_balance                 int64
# power_shot_power                 int64
# power_jumping                    int64
# power_stamina                    int64
# power_strength                   int64
# power_long_shots                 int64
# mentality_aggression             int64
# mentality_positioning            int64
# mentality_vision                 int64
# mentality_penalties              int64
# mentality_composure              int64
# defending_marking_awareness      int64
# defending_sliding_tackle         int64
# goalkeeping_diving               int64
# goalkeeping_handling             int64
# goalkeeping_kicking              int64
# goalkeeping_positioning          int64
# dtype: object

# %%
players_22 = pd.get_dummies(players_22,columns=['preferred_foot'],drop_first=True)

# %%
players_22['value_eur'] = players_22['value_eur']*0.8
players_22['value_eur'] = players_22['value_eur'].fillna(players_22['value_eur'].mean()).astype('float64')

# %%
players_22['value_eur'] = players_22['value_eur'].astype('float64')
players_22['skill_moves'] = players_22['skill_moves'].astype('float64')
players_22['attacking_crossing'] = players_22['attacking_crossing'].astype('float64')
players_22['attacking_finishing'] = players_22['attacking_finishing'].astype('float64')
players_22['attacking_heading_accuracy'] = players_22['attacking_heading_accuracy'].astype('float64')
players_22['attacking_volleys'] = players_22['attacking_volleys'].astype('float64')
players_22['skill_dribbling'] = players_22['skill_dribbling'].astype('float64')
players_22['skill_fk_accuracy'] = players_22['skill_fk_accuracy'].astype('float64')
players_22['skill_long_passing'] = players_22['skill_long_passing'].astype('float64')
players_22['skill_ball_control'] = players_22['skill_ball_control'].astype('float64')
players_22['movement_acceleration'] = players_22['movement_acceleration'].astype('float64')
players_22['movement_sprint_speed'] = players_22['movement_sprint_speed'].astype('float64')
players_22['movement_agility'] = players_22['movement_agility'].astype('float64')
players_22['movement_reactions'] = players_22['movement_reactions'].astype('float64')
players_22['movement_balance'] = players_22['movement_balance'].astype('float64')
players_22['power_shot_power'] = players_22['power_shot_power'].astype('float64')
players_22['power_jumping'] = players_22['power_jumping'].astype('float64')
players_22['power_stamina'] = players_22['power_stamina'].astype('float64')
players_22['power_strength'] = players_22['power_strength'].astype('float64')
players_22['power_long_shots'] = players_22['power_long_shots'].astype('float64')
players_22['mentality_aggression'] = players_22['mentality_aggression'].astype('float64')
players_22['mentality_positioning'] = players_22['mentality_positioning'].astype('float64')
players_22['mentality_vision'] = players_22['mentality_vision'].astype('float64')
players_22['mentality_penalties'] = players_22['mentality_penalties'].astype('float64')
players_22['mentality_composure'] = players_22['mentality_composure'].astype('float64')
players_22['defending_marking_awareness'] = players_22['defending_marking_awareness'].astype('float64')
players_22['defending_sliding_tackle'] = players_22['defending_sliding_tackle'].astype('float64')
players_22['goalkeeping_diving'] = players_22['goalkeeping_diving'].astype('float64')
players_22['goalkeeping_handling'] = players_22['goalkeeping_handling'].astype('float64')
players_22['goalkeeping_kicking'] = players_22['goalkeeping_kicking'].astype('float64')
players_22['goalkeeping_positioning'] = players_22['goalkeeping_positioning'].astype('float64')

# %%
x = players_22['age']
plt.figure(figsize=(10,8))
ax = sns.countplot(x,color='#00ffff')
ax.set_xlabel(xlabel = 'Age of the Players', fontsize = 16)
ax.set_title(label = 'Distribution of Age of the Players', fontsize = 20)
plt.show()
# Out:
# C:\Users\Kiko\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#players_22.set_index('sofifa_id', inplace = True)

# %%
players_show = players_22.copy()
players_show['value_eur'] = players_show['value_eur'].apply(lambda x : "{:,}".format(int(x)))

# %%
players_show.columns
# Out:
# Index(['short_name', 'overall', 'potential', 'value_eur', 'age', 'skill_moves',
#        'international_reputation', 'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_volleys', 'skill_dribbling',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
#        'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
#        'movement_reactions', 'movement_balance', 'power_shot_power',
#        'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
#        'mentality_aggression', 'mentality_positioning', 'mentality_vision',
#        'mentality_penalties', 'mentality_composure',
#        'defending_marking_awareness', 'defending_sliding_tackle',
#        'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking',
#        'goalkeeping_positioning', 'preferred_foot_Right'],
#       dtype='object')

# %%
players_show [['skill_moves',
       'attacking_crossing', 'attacking_finishing',
       'attacking_heading_accuracy', 'attacking_volleys', 'skill_dribbling',
       'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
       'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
       'movement_reactions', 'movement_balance', 'power_shot_power',
       'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
       'mentality_aggression', 'mentality_positioning', 'mentality_vision',
       'mentality_penalties', 'mentality_composure',
       'defending_marking_awareness', 'defending_sliding_tackle',
       'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking',
       'goalkeeping_positioning', 'preferred_foot_Right']] = players_show[['skill_moves',
       'attacking_crossing', 'attacking_finishing',
       'attacking_heading_accuracy', 'attacking_volleys', 'skill_dribbling',
       'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
       'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
       'movement_reactions', 'movement_balance', 'power_shot_power',
       'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
       'mentality_aggression', 'mentality_positioning', 'mentality_vision',
       'mentality_penalties', 'mentality_composure',
       'defending_marking_awareness', 'defending_sliding_tackle',
       'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking',
       'goalkeeping_positioning', 'preferred_foot_Right']].apply(lambda x: round(x,1))
players_show = players_show.rename(columns={'value_eur':'Market Value (Euros)'})
players_show
# Out:
#                    short_name  overall  potential Market Value (Euros)  age  \
# sofifa_id
# 158023               L. Messi       93         93           62,400,000   34
# 188545         R. Lewandowski       92         92           95,600,000   32
# 20801       Cristiano Ronaldo       91         91           36,000,000   36
# 190871              Neymar Jr       91         91          103,200,000   29
# 192985           K. De Bruyne       91         91          100,400,000   30
# ...                       ...      ...        ...                  ...  ...
# 261962              Song Defu       47         52               56,000   22
# 262040              C. Porter       47         59               88,000   19
# 262760               N. Logue       47         55               80,000   21
# 262820              L. Rudden       47         60               88,000   19
# 264540     E. Lalchhanchhuaha       47         60               88,000   19
#
#            skill_moves  international_reputation  attacking_crossing  \
# sofifa_id
# 158023             4.0                         5                85.0
# 188545             4.0                         5                71.0
# 20801              5.0                         5                87.0
# 190871             5.0                         5                85.0
# 192985             4.0                         4                94.0
# ...                ...                       ...                 ...
# 261962             2.0                         1                46.0
# 262040             2.0                         1                54.0
# 262760             2.0                         1                39.0
# 262820             2.0                         1                29.0
# 264540             2.0                         1                39.0
#
#            attacking_finishing  attacking_heading_accuracy  ...  \
# sofifa_id                                                   ...
# 158023                    95.0                        70.0  ...
# 188545                    95.0                        90.0  ...
# 20801                     95.0                        90.0  ...
# 190871                    83.0                        63.0  ...
# 192985                    82.0                        55.0  ...
# ...                        ...                         ...  ...
# 261962                    32.0                        48.0  ...
# 262040                    33.0                        46.0  ...
# 262760                    32.0                        43.0  ...
# 262820                    49.0                        40.0  ...
# 264540                    32.0                        46.0  ...
#
#            mentality_vision  mentality_penalties  mentality_composure  \
# sofifa_id
# 158023                 95.0                 75.0                 96.0
# 188545                 81.0                 90.0                 88.0
# 20801                  76.0                 88.0                 95.0
# 190871                 90.0                 93.0                 93.0
# 192985                 94.0                 83.0                 89.0
# ...                     ...                  ...                  ...
# 261962                 43.0                 42.0                 37.0
# 262040                 49.0                 44.0                 47.0
# 262760                 46.0                 39.0                 36.0
# 262820                 40.0                 49.0                 47.0
# 264540                 46.0                 35.0                 36.0
#
#            defending_marking_awareness  defending_sliding_tackle  \
# sofifa_id
# 158023                            20.0                      24.0
# 188545                            35.0                      19.0
# 20801                             24.0                      24.0
# 190871                            35.0                      29.0
# 192985                            68.0                      53.0
# ...                                ...                       ...
# 261962                            38.0                      48.0
# 262040                            37.0                      47.0
# 262760                            38.0                      48.0
# 262820                            10.0                      11.0
# 264540                            33.0                      37.0
#
#            goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# sofifa_id
# 158023                    6.0                  11.0                 15.0
# 188545                   15.0                   6.0                 12.0
# 20801                     7.0                  11.0                 15.0
# 190871                    9.0                   9.0                 15.0
# 192985                   15.0                  13.0                  5.0
# ...                       ...                   ...                  ...
# 261962                    6.0                  10.0                  5.0
# 262040                   11.0                  12.0                  6.0
# 262760                    8.0                   6.0                  7.0
# 262820                    7.0                  10.0                  7.0
# 264540                    8.0                  13.0                 13.0
#
#            goalkeeping_positioning  preferred_foot_Right
# sofifa_id
# 158023                        14.0                     0
# 188545                         8.0                     1
# 20801                         14.0                     1
# 190871                        15.0                     1
# 192985                        10.0                     1
# ...                            ...                   ...
# 261962                        15.0                     1
# 262040                         8.0                     1
# 262760                        10.0                     1
# 262820                        14.0                     1
# 264540                         9.0                     1
#
# [19239 rows x 37 columns]

# %%
players_22.dtypes
# Out:
# short_name                      object
# overall                          int64
# potential                        int64
# value_eur                      float64
# age                              int64
# skill_moves                    float64
# international_reputation         int64
# attacking_crossing             float64
# attacking_finishing            float64
# attacking_heading_accuracy     float64
# attacking_volleys              float64
# skill_dribbling                float64
# skill_fk_accuracy              float64
# skill_long_passing             float64
# skill_ball_control             float64
# movement_acceleration          float64
# movement_sprint_speed          float64
# movement_agility               float64
# movement_reactions             float64
# movement_balance               float64
# power_shot_power               float64
# power_jumping                  float64
# power_stamina                  float64
# power_strength                 float64
# power_long_shots               float64
# mentality_aggression           float64
# mentality_positioning          float64
# mentality_vision               float64
# mentality_penalties            float64
# mentality_composure            float64
# defending_marking_awareness    float64
# defending_sliding_tackle       float64
# goalkeeping_diving             float64
# goalkeeping_handling           float64
# goalkeeping_kicking            float64
# goalkeeping_positioning        float64
# preferred_foot_Right             uint8
# dtype: object

# %%
corr_matrix = players_22.corr()
corr_matrix
# Out:
#                               overall  potential  value_eur       age  \
# overall                      1.000000   0.644275   0.553823  0.459451
# potential                    0.644275   1.000000   0.526853 -0.264142
# value_eur                    0.553823   0.526853   1.000000  0.042617
# age                          0.459451  -0.264142   0.042617  1.000000
# skill_moves                  0.376226   0.283746   0.256689  0.074076
# international_reputation     0.470768   0.358839   0.631040  0.230120
# attacking_crossing           0.401356   0.243757   0.226934  0.132175
# attacking_finishing          0.338746   0.230814   0.217244  0.088754
# attacking_heading_accuracy   0.343901   0.192825   0.165578  0.154516
# attacking_volleys            0.380942   0.235766   0.237853  0.148109
# skill_dribbling              0.384351   0.311396   0.240459  0.030402
# skill_fk_accuracy            0.381030   0.207769   0.214177  0.191301
# skill_long_passing           0.498216   0.324791   0.278150  0.191542
# skill_ball_control           0.460411   0.347172   0.269295  0.092112
# movement_acceleration        0.194044   0.232621   0.157269 -0.147650
# movement_sprint_speed        0.205736   0.235577   0.164218 -0.139581
# movement_agility             0.270279   0.223385   0.176192 -0.010749
# movement_reactions           0.871823   0.522483   0.491689  0.453298
# movement_balance             0.123700   0.136890   0.117698 -0.066938
# power_shot_power             0.561180   0.332292   0.301176  0.279673
# power_jumping                0.284689   0.096992   0.118007  0.219382
# power_stamina                0.385150   0.199743   0.198277  0.131455
# power_strength               0.364366   0.073567   0.128450  0.348811
# power_long_shots             0.410010   0.243294   0.231083  0.164977
# mentality_aggression         0.400161   0.191501   0.182830  0.241968
# mentality_positioning        0.358562   0.233070   0.223637  0.101573
# mentality_vision             0.523025   0.345298   0.323736  0.209636
# mentality_penalties          0.343690   0.208062   0.195743  0.151951
# mentality_composure          0.708867   0.426790   0.388250  0.359076
# defending_marking_awareness  0.312093   0.161288   0.140712  0.163583
# defending_sliding_tackle     0.233589   0.140869   0.103281  0.089482
# goalkeeping_diving          -0.010990  -0.043093  -0.022038  0.109490
# goalkeeping_handling        -0.011080  -0.044989  -0.022424  0.112420
# goalkeeping_kicking         -0.012986  -0.047030  -0.021551  0.112025
# goalkeeping_positioning     -0.002485  -0.040184  -0.021243  0.120686
# preferred_foot_Right        -0.048961  -0.042915  -0.019993  0.003021
#
#                              skill_moves  international_reputation  \
# overall                         0.376226                  0.470768
# potential                       0.283746                  0.358839
# value_eur                       0.256689                  0.631040
# age                             0.074076                  0.230120
# skill_moves                     1.000000                  0.209266
# international_reputation        0.209266                  1.000000
# attacking_crossing              0.721700                  0.181808
# attacking_finishing             0.740851                  0.168804
# attacking_heading_accuracy      0.439020                  0.148093
# attacking_volleys               0.741924                  0.224056
# skill_dribbling                 0.799155                  0.174268
# skill_fk_accuracy               0.696867                  0.201520
# skill_long_passing              0.593681                  0.239733
# skill_ball_control              0.773110                  0.209211
# movement_acceleration           0.639940                  0.041989
# movement_sprint_speed           0.604364                  0.043941
# movement_agility                0.684825                  0.099141
# movement_reactions              0.366579                  0.427798
# movement_balance                0.584267                  0.060221
# power_shot_power                0.564069                  0.281830
# power_jumping                   0.097420                  0.117175
# power_stamina                   0.552131                  0.093469
# power_strength                 -0.012836                  0.124546
# power_long_shots                0.742904                  0.196581
# mentality_aggression            0.359648                  0.167006
# mentality_positioning           0.765659                  0.173291
# mentality_vision                0.646033                  0.279821
# mentality_penalties             0.693156                  0.191753
# mentality_composure             0.605913                  0.360216
# defending_marking_awareness     0.234671                  0.117671
# defending_sliding_tackle        0.177433                  0.078700
# goalkeeping_diving             -0.604961                  0.009710
# goalkeeping_handling           -0.603081                  0.010236
# goalkeeping_kicking            -0.601639                  0.009640
# goalkeeping_positioning        -0.601882                  0.012808
# preferred_foot_Right           -0.090886                 -0.001521
#
#                              attacking_crossing  attacking_finishing  \
# overall                                0.401356             0.338746
# potential                              0.243757             0.230814
# value_eur                              0.226934             0.217244
# age                                    0.132175             0.088754
# skill_moves                            0.721700             0.740851
# international_reputation               0.181808             0.168804
# attacking_crossing                     1.000000             0.682982
# attacking_finishing                    0.682982             1.000000
# attacking_heading_accuracy             0.493130             0.496748
# attacking_volleys                      0.698748             0.900288
# skill_dribbling                        0.863184             0.840807
# skill_fk_accuracy                      0.764766             0.721055
# skill_long_passing                     0.744209             0.544287
# skill_ball_control                     0.837386             0.801521
# movement_acceleration                  0.682473             0.623394
# movement_sprint_speed                  0.651720             0.600298
# movement_agility                       0.721440             0.667306
# movement_reactions                     0.386875             0.361212
# movement_balance                       0.642271             0.549800
# power_shot_power                       0.528963             0.738760
# power_jumping                          0.126229             0.089098
# power_stamina                          0.680769             0.540296
# power_strength                        -0.008280             0.027346
# power_long_shots                       0.749193             0.903280
# mentality_aggression                   0.499103             0.295009
# mentality_positioning                  0.803924             0.904531
# mentality_vision                       0.681170             0.713155
# mentality_penalties                    0.660510             0.852509
# mentality_composure                    0.627092             0.607211
# defending_marking_awareness            0.465374             0.057259
# defending_sliding_tackle               0.431552            -0.014740
# goalkeeping_diving                    -0.677740            -0.605657
# goalkeeping_handling                  -0.675595            -0.604279
# goalkeeping_kicking                   -0.675874            -0.601335
# goalkeeping_positioning               -0.674395            -0.601135
# preferred_foot_Right                  -0.199483            -0.028673
#
#                              attacking_heading_accuracy  attacking_volleys  \
# overall                                        0.343901           0.380942
# potential                                      0.192825           0.235766
# value_eur                                      0.165578           0.237853
# age                                            0.154516           0.148109
# skill_moves                                    0.439020           0.741924
# international_reputation                       0.148093           0.224056
# attacking_crossing                             0.493130           0.698748
# attacking_finishing                            0.496748           0.900288
# attacking_heading_accuracy                     1.000000           0.531206
# attacking_volleys                              0.531206           1.000000
# skill_dribbling                                0.592342           0.817436
# skill_fk_accuracy                              0.421178           0.753069
# skill_long_passing                             0.543108           0.577257
# skill_ball_control                             0.694926           0.797739
# movement_acceleration                          0.368015           0.586531
# movement_sprint_speed                          0.424833           0.564254
# movement_agility                               0.292908           0.642956
# movement_reactions                             0.375754           0.406562
# movement_balance                               0.207419           0.532501
# power_shot_power                               0.363491           0.749894
# power_jumping                                  0.454348           0.125415
# power_stamina                                  0.657005           0.543252
# power_strength                                 0.512679           0.068351
# power_long_shots                               0.520755           0.880530
# mentality_aggression                           0.717347           0.361252
# mentality_positioning                          0.561948           0.863984
# mentality_vision                               0.282120           0.698189
# mentality_penalties                            0.578952           0.850715
# mentality_composure                            0.569060           0.649909
# defending_marking_awareness                    0.591080           0.132471
# defending_sliding_tackle                       0.544579           0.058476
# goalkeeping_diving                            -0.748750          -0.603146
# goalkeeping_handling                          -0.749095          -0.601622
# goalkeeping_kicking                           -0.745486          -0.598669
# goalkeeping_positioning                       -0.744552          -0.598384
# preferred_foot_Right                          -0.044867          -0.040161
#
#                              ...  mentality_vision  mentality_penalties  \
# overall                      ...          0.523025             0.343690
# potential                    ...          0.345298             0.208062
# value_eur                    ...          0.323736             0.195743
# age                          ...          0.209636             0.151951
# skill_moves                  ...          0.646033             0.693156
# international_reputation     ...          0.279821             0.191753
# attacking_crossing           ...          0.681170             0.660510
# attacking_finishing          ...          0.713155             0.852509
# attacking_heading_accuracy   ...          0.282120             0.578952
# attacking_volleys            ...          0.698189             0.850715
# skill_dribbling              ...          0.727194             0.783188
# skill_fk_accuracy            ...          0.716379             0.744128
# skill_long_passing           ...          0.700809             0.561086
# skill_ball_control           ...          0.704409             0.780347
# movement_acceleration        ...          0.459908             0.549156
# movement_sprint_speed        ...          0.417537             0.533230
# movement_agility             ...          0.607565             0.580854
# movement_reactions           ...          0.527072             0.374661
# movement_balance             ...          0.501937             0.498835
# power_shot_power             ...          0.690942             0.682600
# power_jumping                ...          0.050740             0.144679
# power_stamina                ...          0.487237             0.541220
# power_strength               ...         -0.009577             0.100958
# power_long_shots             ...          0.765232             0.827723
# mentality_aggression         ...          0.325146             0.374987
# mentality_positioning        ...          0.742685             0.818198
# mentality_vision             ...          1.000000             0.633861
# mentality_penalties          ...          0.633861             1.000000
# mentality_composure          ...          0.682060             0.623061
# defending_marking_awareness  ...          0.200737             0.168848
# defending_sliding_tackle     ...          0.134847             0.097101
# goalkeeping_diving           ...         -0.362421            -0.629375
# goalkeeping_handling         ...         -0.358788            -0.628892
# goalkeeping_kicking          ...         -0.356522            -0.624459
# goalkeeping_positioning      ...         -0.355112            -0.624415
# preferred_foot_Right         ...         -0.051223            -0.047491
#
#                              mentality_composure  defending_marking_awareness  \
# overall                                 0.708867                     0.312093
# potential                               0.426790                     0.161288
# value_eur                               0.388250                     0.140712
# age                                     0.359076                     0.163583
# skill_moves                             0.605913                     0.234671
# international_reputation                0.360216                     0.117671
# attacking_crossing                      0.627092                     0.465374
# attacking_finishing                     0.607211                     0.057259
# attacking_heading_accuracy              0.569060                     0.591080
# attacking_volleys                       0.649909                     0.132471
# skill_dribbling                         0.681339                     0.376025
# skill_fk_accuracy                       0.628787                     0.321562
# skill_long_passing                      0.705187                     0.631930
# skill_ball_control                      0.743459                     0.490070
# movement_acceleration                   0.416577                     0.225918
# movement_sprint_speed                   0.414051                     0.243217
# movement_agility                        0.505192                     0.205738
# movement_reactions                      0.697543                     0.334779
# movement_balance                        0.384773                     0.218342
# power_shot_power                        0.637367                     0.058185
# power_jumping                           0.284075                     0.331472
# power_stamina                           0.588383                     0.623218
# power_strength                          0.301446                     0.340599
# power_long_shots                        0.674166                     0.222339
# mentality_aggression                    0.568585                     0.754726
# mentality_positioning                   0.653477                     0.239840
# mentality_vision                        0.682060                     0.200737
# mentality_penalties                     0.623061                     0.168848
# mentality_composure                     1.000000                     0.443772
# defending_marking_awareness             0.443772                     1.000000
# defending_sliding_tackle                0.359157                     0.933001
# goalkeeping_diving                     -0.449580                    -0.553614
# goalkeeping_handling                   -0.446860                    -0.553478
# goalkeeping_kicking                    -0.445416                    -0.552878
# goalkeeping_positioning                -0.441137                    -0.550999
# preferred_foot_Right                   -0.054276                    -0.110440
#
#                              defending_sliding_tackle  goalkeeping_diving  \
# overall                                      0.233589           -0.010990
# potential                                    0.140869           -0.043093
# value_eur                                    0.103281           -0.022038
# age                                          0.089482            0.109490
# skill_moves                                  0.177433           -0.604961
# international_reputation                     0.078700            0.009710
# attacking_crossing                           0.431552           -0.677740
# attacking_finishing                         -0.014740           -0.605657
# attacking_heading_accuracy                   0.544579           -0.748750
# attacking_volleys                            0.058476           -0.603146
# skill_dribbling                              0.327172           -0.774698
# skill_fk_accuracy                            0.270130           -0.563347
# skill_long_passing                           0.593760           -0.605294
# skill_ball_control                           0.430614           -0.804037
# movement_acceleration                        0.202282           -0.630308
# movement_sprint_speed                        0.217606           -0.633539
# movement_agility                             0.164887           -0.556989
# movement_reactions                           0.251561           -0.079749
# movement_balance                             0.200700           -0.533571
# power_shot_power                            -0.016338           -0.275670
# power_jumping                                0.301937           -0.211172
# power_stamina                                0.574866           -0.708093
# power_strength                               0.290818           -0.120404
# power_long_shots                             0.152482           -0.618455
# mentality_aggression                         0.729947           -0.598693
# mentality_positioning                        0.177224           -0.701519
# mentality_vision                             0.134847           -0.362421
# mentality_penalties                          0.097101           -0.629375
# mentality_composure                          0.359157           -0.449580
# defending_marking_awareness                  0.933001           -0.553614
# defending_sliding_tackle                     1.000000           -0.531952
# goalkeeping_diving                          -0.531952            1.000000
# goalkeeping_handling                        -0.531655            0.971585
# goalkeeping_kicking                         -0.531363            0.968414
# goalkeeping_positioning                     -0.530015            0.971219
# preferred_foot_Right                        -0.122015            0.100158
#
#                              goalkeeping_handling  goalkeeping_kicking  \
# overall                                 -0.011080            -0.012986
# potential                               -0.044989            -0.047030
# value_eur                               -0.022424            -0.021551
# age                                      0.112420             0.112025
# skill_moves                             -0.603081            -0.601639
# international_reputation                 0.010236             0.009640
# attacking_crossing                      -0.675595            -0.675874
# attacking_finishing                     -0.604279            -0.601335
# attacking_heading_accuracy              -0.749095            -0.745486
# attacking_volleys                       -0.601622            -0.598669
# skill_dribbling                         -0.772985            -0.770454
# skill_fk_accuracy                       -0.562174            -0.559885
# skill_long_passing                      -0.603459            -0.599891
# skill_ball_control                      -0.802568            -0.799088
# movement_acceleration                   -0.630237            -0.628466
# movement_sprint_speed                   -0.633607            -0.631737
# movement_agility                        -0.556642            -0.554608
# movement_reactions                      -0.080684            -0.081403
# movement_balance                        -0.532446            -0.530836
# power_shot_power                        -0.275181            -0.266944
# power_jumping                           -0.211013            -0.209847
# power_stamina                           -0.706221            -0.703382
# power_strength                          -0.122316            -0.119934
# power_long_shots                        -0.616621            -0.613442
# mentality_aggression                    -0.597210            -0.595690
# mentality_positioning                   -0.699802            -0.696555
# mentality_vision                        -0.358788            -0.356522
# mentality_penalties                     -0.628892            -0.624459
# mentality_composure                     -0.446860            -0.445416
# defending_marking_awareness             -0.553478            -0.552878
# defending_sliding_tackle                -0.531655            -0.531363
# goalkeeping_diving                       0.971585             0.968414
# goalkeeping_handling                     1.000000             0.968049
# goalkeeping_kicking                      0.968049             1.000000
# goalkeeping_positioning                  0.970705             0.967259
# preferred_foot_Right                     0.099322             0.102845
#
#                              goalkeeping_positioning  preferred_foot_Right
# overall                                    -0.002485             -0.048961
# potential                                  -0.040184             -0.042915
# value_eur                                  -0.021243             -0.019993
# age                                         0.120686              0.003021
# skill_moves                                -0.601882             -0.090886
# international_reputation                    0.012808             -0.001521
# attacking_crossing                         -0.674395             -0.199483
# attacking_finishing                        -0.601135             -0.028673
# attacking_heading_accuracy                 -0.744552             -0.044867
# attacking_volleys                          -0.598384             -0.040161
# skill_dribbling                            -0.769348             -0.120627
# skill_fk_accuracy                          -0.560211             -0.133982
# skill_long_passing                         -0.601133             -0.094901
# skill_ball_control                         -0.798632             -0.105706
# movement_acceleration                      -0.626919             -0.117393
# movement_sprint_speed                      -0.629623             -0.115139
# movement_agility                           -0.554221             -0.100907
# movement_reactions                         -0.073168             -0.017345
# movement_balance                           -0.529101             -0.086864
# power_shot_power                           -0.271049             -0.019632
# power_jumping                              -0.206477              0.019277
# power_stamina                              -0.704100             -0.089153
# power_strength                             -0.116784              0.027425
# power_long_shots                           -0.612976             -0.065733
# mentality_aggression                       -0.594173             -0.060398
# mentality_positioning                      -0.695813             -0.083620
# mentality_vision                           -0.355112             -0.051223
# mentality_penalties                        -0.624415             -0.047491
# mentality_composure                        -0.441137             -0.054276
# defending_marking_awareness                -0.550999             -0.110440
# defending_sliding_tackle                   -0.530015             -0.122015
# goalkeeping_diving                          0.971219              0.100158
# goalkeeping_handling                        0.970705              0.099322
# goalkeeping_kicking                         0.967259              0.102845
# goalkeeping_positioning                     1.000000              0.102036
# preferred_foot_Right                        0.102036              1.000000
#
# [36 rows x 36 columns]

# %%
fig = plt.figure(figsize=[21,9])
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
sns.heatmap(corr_matrix,cmap='seismic',linewidth=1,linecolor='white',vmax = 1, vmin=-1,mask=mask, annot=True,fmt='0.2f')
plt.title('Correlation Heatmap', weight='bold',fontsize=20)
#plt.savefig('heatmap1.png',transparent=True, bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
list_features = ['skill_moves',
       'attacking_crossing', 'attacking_finishing',
       'attacking_heading_accuracy', 'attacking_volleys', 'skill_dribbling',
       'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
       'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
       'movement_reactions', 'movement_balance', 'power_shot_power',
       'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
       'mentality_aggression', 'mentality_positioning', 'mentality_vision',
       'mentality_penalties', 'mentality_composure',
       'defending_marking_awareness', 'defending_sliding_tackle',
       'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking',
       'goalkeeping_positioning', 'preferred_foot_Right']

# %%
fig = plt.figure(figsize=[12,8])
sns.set(style = 'white', font_scale=1.4)
players_22[list_features].boxplot(showfliers=False)
plt.grid(False)
plt.xlabel('Skills Category',fontsize=20,weight='bold')
plt.ylabel('Score Ratings',fontsize=20,weight='bold')
plt.title('Distribution of Score Ratings',fontsize=20,weight='bold')
sns.despine()

# %%
#players_22 = players_22.drop(['preferred_foot_Right'],axis=1)

# %%
#sns.set(style='white',font_scale=1.8)
#sns.pairplot(players_22)
#plt.savefig('pairplot1.png',transparent=True, bbox_inches='tight')

# %%
l = list(players_22['value_eur'] == 0)
print('Zeros in output label: ',len([v for v in l if v==True] ))
print('\nNaN values in following features:')
players_22.isnull().any()
# Out:
# Zeros in output label:  0
#
# NaN values in following features:
# short_name                     False
# overall                        False
# potential                      False
# value_eur                      False
# age                            False
# skill_moves                    False
# international_reputation       False
# attacking_crossing             False
# attacking_finishing            False
# attacking_heading_accuracy     False
# attacking_volleys              False
# skill_dribbling                False
# skill_fk_accuracy              False
# skill_long_passing             False
# skill_ball_control             False
# movement_acceleration          False
# movement_sprint_speed          False
# movement_agility               False
# movement_reactions             False
# movement_balance               False
# power_shot_power               False
# power_jumping                  False
# power_stamina                  False
# power_strength                 False
# power_long_shots               False
# mentality_aggression           False
# mentality_positioning          False
# mentality_vision               False
# mentality_penalties            False
# mentality_composure            False
# defending_marking_awareness    False
# defending_sliding_tackle       False
# goalkeeping_diving             False
# goalkeeping_handling           False
# goalkeeping_kicking            False
# goalkeeping_positioning        False
# preferred_foot_Right           False
# dtype: bool

# %%
y, X = patsy.dmatrices("Q('value_eur') ~ age + international_reputation + Q('skill_moves') + attacking_crossing + attacking_finishing + attacking_heading_accuracy + attacking_volleys + skill_dribbling + skill_fk_accuracy + skill_long_passing + skill_ball_control + movement_acceleration + movement_sprint_speed + movement_agility + movement_reactions + movement_balance + power_shot_power + power_jumping + power_stamina + power_strength + power_long_shots + mentality_aggression + mentality_positioning + mentality_vision + mentality_penalties + mentality_composure + defending_marking_awareness + defending_sliding_tackle + goalkeeping_diving + goalkeeping_handling + goalkeeping_kicking + goalkeeping_positioning + preferred_foot_Right", 
                       data=players_22, return_type="dataframe")
model = sm.OLS(y, X)
fit = model.fit()
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Q('value_eur')   R-squared:                       0.528
# Model:                            OLS   Adj. R-squared:                  0.527
# Method:                 Least Squares   F-statistic:                     650.4
# Date:                Sat, 06 Aug 2022   Prob (F-statistic):               0.00
# Time:                        20:49:28   Log-Likelihood:            -3.2060e+05
# No. Observations:               19239   AIC:                         6.413e+05
# Df Residuals:                   19205   BIC:                         6.415e+05
# Df Model:                          33
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       -2e+07   4.09e+05    -48.865      0.000   -2.08e+07   -1.92e+07
# age                         -3.499e+05   8318.151    -42.068      0.000   -3.66e+05   -3.34e+05
# international_reputation     8.426e+06   9.27e+04     90.847      0.000    8.24e+06    8.61e+06
# Q('skill_moves')             5.214e+05   7.13e+04      7.313      0.000    3.82e+05    6.61e+05
# attacking_crossing           1.274e+04   4134.777      3.082      0.002    4640.459    2.08e+04
# attacking_finishing          3.711e+04   5530.867      6.711      0.000    2.63e+04     4.8e+04
# attacking_heading_accuracy   1.968e+04   4529.076      4.345      0.000    1.08e+04    2.86e+04
# attacking_volleys           -5390.6199   4702.308     -1.146      0.252   -1.46e+04    3826.316
# skill_dribbling             -1.138e+04   6852.763     -1.660      0.097   -2.48e+04    2053.396
# skill_fk_accuracy            4495.5822   3704.138      1.214      0.225   -2764.853    1.18e+04
# skill_long_passing           6407.3087   4668.833      1.372      0.170   -2744.012    1.56e+04
# skill_ball_control           2.652e+04   7663.059      3.461      0.001    1.15e+04    4.15e+04
# movement_acceleration        3701.4462   6254.658      0.592      0.554   -8558.231     1.6e+04
# movement_sprint_speed        2.647e+04   5555.175      4.765      0.000    1.56e+04    3.74e+04
# movement_agility            -1.734e+04   4722.224     -3.672      0.000   -2.66e+04   -8082.800
# movement_reactions           1.654e+05   6228.945     26.561      0.000    1.53e+05    1.78e+05
# movement_balance             1.248e+04   4038.742      3.090      0.002    4564.954    2.04e+04
# power_shot_power             -623.4116   4929.850     -0.126      0.899   -1.03e+04    9039.527
# power_jumping               -8715.7607   3241.587     -2.689      0.007   -1.51e+04   -2361.966
# power_stamina                 3.25e+04   3712.621      8.754      0.000    2.52e+04    3.98e+04
# power_strength               2.287e+04   3901.422      5.863      0.000    1.52e+04    3.05e+04
# power_long_shots            -2.207e+04   5174.364     -4.265      0.000   -3.22e+04   -1.19e+04
# mentality_aggression        -2998.7967   3550.120     -0.845      0.398   -9957.343    3959.750
# mentality_positioning       -9271.4250   5291.761     -1.752      0.080   -1.96e+04    1100.889
# mentality_vision             7281.1738   4821.184      1.510      0.131   -2168.768    1.67e+04
# mentality_penalties         -1.823e+04   4397.196     -4.145      0.000   -2.68e+04   -9607.067
# mentality_composure          2.469e+04   5070.645      4.869      0.000    1.48e+04    3.46e+04
# defending_marking_awareness  1.135e+04   4713.869      2.407      0.016    2108.806    2.06e+04
# defending_sliding_tackle    -2511.0479   4616.777     -0.544      0.587   -1.16e+04    6538.238
# goalkeeping_diving            2.68e+04   8964.635      2.990      0.003    9230.020    4.44e+04
# goalkeeping_handling         2.727e+04   9232.436      2.954      0.003    9176.597    4.54e+04
# goalkeeping_kicking          3.705e+04   8743.503      4.237      0.000    1.99e+04    5.42e+04
# goalkeeping_positioning       1.49e+04   8984.575      1.658      0.097   -2711.635    3.25e+04
# preferred_foot_Right        -1.172e+05   7.38e+04     -1.588      0.112   -2.62e+05    2.75e+04
# ==============================================================================
# Omnibus:                    23422.092   Durbin-Watson:                   0.876
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          7719578.354
# Skew:                           6.229   Prob(JB):                         0.00
# Kurtosis:                     100.338   Cond. No.                     3.88e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.88e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
players_22_norm = players_22.copy()

# %%
players_22_norm['value_eur'] = np.log1p(players_22['value_eur'])

# %%
players_22_norm
# Out:
#                    short_name  overall  potential  value_eur  age  \
# sofifa_id
# 158023               L. Messi       93         93  17.949076   34
# 188545         R. Lewandowski       92         92  18.375683   32
# 20801       Cristiano Ronaldo       91         91  17.399030   36
# 190871              Neymar Jr       91         91  18.452179   29
# 192985           K. De Bruyne       91         91  18.424673   30
# ...                       ...      ...        ...        ...  ...
# 261962              Song Defu       47         52  10.933125   22
# 262040              C. Porter       47         59  11.385103   19
# 262760               N. Logue       47         55  11.289794   21
# 262820              L. Rudden       47         60  11.385103   19
# 264540     E. Lalchhanchhuaha       47         60  11.385103   19
#
#            skill_moves  international_reputation  attacking_crossing  \
# sofifa_id
# 158023             4.0                         5                85.0
# 188545             4.0                         5                71.0
# 20801              5.0                         5                87.0
# 190871             5.0                         5                85.0
# 192985             4.0                         4                94.0
# ...                ...                       ...                 ...
# 261962             2.0                         1                46.0
# 262040             2.0                         1                54.0
# 262760             2.0                         1                39.0
# 262820             2.0                         1                29.0
# 264540             2.0                         1                39.0
#
#            attacking_finishing  attacking_heading_accuracy  ...  \
# sofifa_id                                                   ...
# 158023                    95.0                        70.0  ...
# 188545                    95.0                        90.0  ...
# 20801                     95.0                        90.0  ...
# 190871                    83.0                        63.0  ...
# 192985                    82.0                        55.0  ...
# ...                        ...                         ...  ...
# 261962                    32.0                        48.0  ...
# 262040                    33.0                        46.0  ...
# 262760                    32.0                        43.0  ...
# 262820                    49.0                        40.0  ...
# 264540                    32.0                        46.0  ...
#
#            mentality_vision  mentality_penalties  mentality_composure  \
# sofifa_id
# 158023                 95.0                 75.0                 96.0
# 188545                 81.0                 90.0                 88.0
# 20801                  76.0                 88.0                 95.0
# 190871                 90.0                 93.0                 93.0
# 192985                 94.0                 83.0                 89.0
# ...                     ...                  ...                  ...
# 261962                 43.0                 42.0                 37.0
# 262040                 49.0                 44.0                 47.0
# 262760                 46.0                 39.0                 36.0
# 262820                 40.0                 49.0                 47.0
# 264540                 46.0                 35.0                 36.0
#
#            defending_marking_awareness  defending_sliding_tackle  \
# sofifa_id
# 158023                            20.0                      24.0
# 188545                            35.0                      19.0
# 20801                             24.0                      24.0
# 190871                            35.0                      29.0
# 192985                            68.0                      53.0
# ...                                ...                       ...
# 261962                            38.0                      48.0
# 262040                            37.0                      47.0
# 262760                            38.0                      48.0
# 262820                            10.0                      11.0
# 264540                            33.0                      37.0
#
#            goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# sofifa_id
# 158023                    6.0                  11.0                 15.0
# 188545                   15.0                   6.0                 12.0
# 20801                     7.0                  11.0                 15.0
# 190871                    9.0                   9.0                 15.0
# 192985                   15.0                  13.0                  5.0
# ...                       ...                   ...                  ...
# 261962                    6.0                  10.0                  5.0
# 262040                   11.0                  12.0                  6.0
# 262760                    8.0                   6.0                  7.0
# 262820                    7.0                  10.0                  7.0
# 264540                    8.0                  13.0                 13.0
#
#            goalkeeping_positioning  preferred_foot_Right
# sofifa_id
# 158023                        14.0                     0
# 188545                         8.0                     1
# 20801                         14.0                     1
# 190871                        15.0                     1
# 192985                        10.0                     1
# ...                            ...                   ...
# 261962                        15.0                     1
# 262040                         8.0                     1
# 262760                        10.0                     1
# 262820                        14.0                     1
# 264540                         9.0                     1
#
# [19239 rows x 37 columns]

# %%
players_22_norm = players_22_norm.rename(columns={'value_eur':'Log Market Value'})

# %%
sns.set(font_scale=1,style='white')
corr_matrix = players_22_norm.corr()
fig = plt.figure(figsize=[21,9])
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
sns.heatmap(corr_matrix,cmap='seismic',linewidth=1.5,linecolor='white',vmax = 1, vmin=-1,mask=mask, annot=True,fmt='0.2f')
plt.title('Correlation Heatmap', weight='bold',fontsize=20)
plt.savefig('heatmap3.png',transparent=True, bbox_inches='tight')

# %%
#sns.set(style='white',font_scale=1.8)
#sns.pairplot(players_22_norm)
#plt.savefig('pairplot2.png',transparent=True, bbox_inches='tight')

# %%
y, X = patsy.dmatrices("Q('Log Market Value') ~ age + international_reputation + Q('skill_moves') + attacking_crossing + attacking_finishing + attacking_heading_accuracy + attacking_volleys + skill_dribbling + skill_fk_accuracy + skill_long_passing + skill_ball_control + movement_acceleration + movement_sprint_speed + movement_agility + movement_reactions + movement_balance + power_shot_power + power_jumping + power_stamina + power_strength + power_long_shots + mentality_aggression + mentality_positioning + mentality_vision + mentality_penalties + mentality_composure + defending_marking_awareness + defending_sliding_tackle + goalkeeping_diving + goalkeeping_handling + goalkeeping_kicking + goalkeeping_positioning + preferred_foot_Right", 
                       data=players_22_norm, return_type="dataframe")
model = sm.OLS(y, X)
fit = model.fit()
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     Q('Log Market Value')   R-squared:                       0.835
# Model:                               OLS   Adj. R-squared:                  0.835
# Method:                    Least Squares   F-statistic:                     2947.
# Date:                   Sat, 06 Aug 2022   Prob (F-statistic):               0.00
# Time:                           20:49:36   Log-Likelihood:                -13934.
# No. Observations:                  19239   AIC:                         2.794e+04
# Df Residuals:                      19205   BIC:                         2.820e+04
# Df Model:                             33
# Covariance Type:               nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       5.9964      0.049    122.575      0.000       5.900       6.092
# age                            -0.1130      0.001   -113.628      0.000      -0.115      -0.111
# international_reputation        0.4460      0.011     40.245      0.000       0.424       0.468
# Q('skill_moves')                0.2016      0.009     23.656      0.000       0.185       0.218
# attacking_crossing              0.0076      0.000     15.416      0.000       0.007       0.009
# attacking_finishing             0.0058      0.001      8.813      0.000       0.005       0.007
# attacking_heading_accuracy      0.0153      0.001     28.286      0.000       0.014       0.016
# attacking_volleys              -0.0015      0.001     -2.635      0.008      -0.003      -0.000
# skill_dribbling                 0.0053      0.001      6.466      0.000       0.004       0.007
# skill_fk_accuracy              -0.0005      0.000     -1.074      0.283      -0.001       0.000
# skill_long_passing              0.0020      0.001      3.666      0.000       0.001       0.003
# skill_ball_control              0.0331      0.001     36.148      0.000       0.031       0.035
# movement_acceleration           0.0043      0.001      5.779      0.000       0.003       0.006
# movement_sprint_speed           0.0051      0.001      7.744      0.000       0.004       0.006
# movement_agility               -0.0026      0.001     -4.691      0.000      -0.004      -0.002
# movement_reactions              0.0565      0.001     75.936      0.000       0.055       0.058
# movement_balance               -0.0030      0.000     -6.292      0.000      -0.004      -0.002
# power_shot_power                0.0081      0.001     13.799      0.000       0.007       0.009
# power_jumping                  -0.0004      0.000     -0.975      0.330      -0.001       0.000
# power_stamina                   0.0067      0.000     15.028      0.000       0.006       0.008
# power_strength                  0.0052      0.000     11.114      0.000       0.004       0.006
# power_long_shots               -0.0067      0.001    -10.758      0.000      -0.008      -0.005
# mentality_aggression        -7.382e-05      0.000     -0.174      0.862      -0.001       0.001
# mentality_positioning          -0.0082      0.001    -13.045      0.000      -0.009      -0.007
# mentality_vision               -0.0046      0.001     -8.023      0.000      -0.006      -0.003
# mentality_penalties            -0.0015      0.001     -2.802      0.005      -0.003      -0.000
# mentality_composure             0.0136      0.001     22.375      0.000       0.012       0.015
# defending_marking_awareness     0.0051      0.001      9.073      0.000       0.004       0.006
# defending_sliding_tackle        0.0008      0.001      1.405      0.160      -0.000       0.002
# goalkeeping_diving              0.0184      0.001     17.185      0.000       0.016       0.021
# goalkeeping_handling            0.0164      0.001     14.863      0.000       0.014       0.019
# goalkeeping_kicking             0.0080      0.001      7.617      0.000       0.006       0.010
# goalkeeping_positioning         0.0161      0.001     15.031      0.000       0.014       0.018
# preferred_foot_Right           -0.0401      0.009     -4.540      0.000      -0.057      -0.023
# ==============================================================================
# Omnibus:                     1348.360   Durbin-Watson:                   1.592
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5518.226
# Skew:                           0.238   Prob(JB):                         0.00
# Kurtosis:                       5.580   Cond. No.                     3.88e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.88e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
def diagnostic_plot(x, y):
    plt.figure(figsize=(20,5))
    
    rgr = LinearRegression()
    rgr.fit(x,y)
    pred = rgr.predict(x)

    plt.subplot(1, 3, 1)
    plt.scatter(pred,y,alpha=0.1)
    plt.plot(y, y, color='red',linewidth=1,)
    plt.title("Regression fit")
    plt.xlabel("Predicted y")
    plt.ylabel("y")
    
    plt.subplot(1, 3, 2)
    res = y - pred
    plt.scatter(pred, res,alpha=0.1)
    plt.title("Residual plot")
    plt.xlabel("prediction")
    plt.ylabel("residuals")
    
    plt.subplot(1, 3, 3)
    #Generates a probability plot of sample data against the quantiles of a 
    # specified theoretical distribution 
    stats.probplot(res, dist="norm", plot=plt,)
    plt.title("Normal Q-Q plot")
    
    lin_mse = mean_squared_error(y, pred)
    lin_rmse = np.sqrt(lin_mse)
    lin_rmse
    
    score = r2_score(y, pred)  
    print('Accuracy:',format(score*100,'.2f'),'%')

# %%
y = players_22_norm['Log Market Value']
X = players_22_norm.drop(['short_name','Log Market Value'],axis=1)

# %%
sns.distplot(y,kde=False)
# Out:
# C:\Users\Kiko\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Log Market Value'>

# %%
sns.set(style='darkgrid')
diagnostic_plot(X, y)
# Out:
# Accuracy: 95.96 %

# %% [markdown]
# # Analysis of the target variable

# %%
plt.subplots(figsize=(12,9))
sns.distplot(players_22['value_eur'], fit=stats.norm)

# Getting the fitted parameters used by the function:
(mu, sigma) = stats.norm.fit(players_22['value_eur'])

# plotting with the distribution:
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)], loc='best')
plt.ylabel('Frequency')

# Probablity plot:
fig = plt.figure()
stats.probplot(players_22['value_eur'], plot=plt)
plt.show()
# Out:
# C:\Users\Kiko\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# analysis of the kurtosis and the skewness to check the normality of the variable:
kurt = players_22['value_eur'].kurtosis()
skew = players_22['value_eur'].skew()
print('Death Kurtorsis {}'.format(kurt))
print('Death Skewness {}'.format(skew))
# Out:
# Death Kurtorsis 98.28700716867866
# Death Skewness 8.202130312464618

# %% [markdown]
# # Normalization

# %%
# Using log function for normalize the target variable:
#players_22_norm['Log Market Value'] = np.log(players_22_norm['Log Market Value'])

# Checking to see the  normal distribution of the variable now:

plt.subplots(figsize=(12,9))
sns.distplot(players_22_norm['Log Market Value'], fit=stats.norm)

# Getting the fitted parameters used by the function:

(mu, sigma) = stats.norm.fit(players_22_norm['Log Market Value'])

# plotting with the distribution now:

plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)], loc='best')
plt.ylabel('Frequency')

# Probablity plot:

fig = plt.figure()
stats.probplot(players_22_norm['Log Market Value'], plot=plt)
plt.show()
# Out:
# C:\Users\Kiko\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# after normalize the variable. we check again the analysis of the kurtosis and the skewness to check the normality of the variable:

kurt = players_22_norm['Log Market Value'].kurtosis()
skew = players_22_norm['Log Market Value'].skew()
print('Death Kurtorsis {}'.format(kurt))
print('Death Skewness {}'.format(skew))
# Out:
# Death Kurtorsis 0.8421533154160796
# Death Skewness 0.5806627737587468

# %%
X
# Out:
#            overall  potential  age  skill_moves  international_reputation  \
# sofifa_id
# 158023          93         93   34          4.0                         5
# 188545          92         92   32          4.0                         5
# 20801           91         91   36          5.0                         5
# 190871          91         91   29          5.0                         5
# 192985          91         91   30          4.0                         4
# ...            ...        ...  ...          ...                       ...
# 261962          47         52   22          2.0                         1
# 262040          47         59   19          2.0                         1
# 262760          47         55   21          2.0                         1
# 262820          47         60   19          2.0                         1
# 264540          47         60   19          2.0                         1
#
#            attacking_crossing  attacking_finishing  \
# sofifa_id
# 158023                   85.0                 95.0
# 188545                   71.0                 95.0
# 20801                    87.0                 95.0
# 190871                   85.0                 83.0
# 192985                   94.0                 82.0
# ...                       ...                  ...
# 261962                   46.0                 32.0
# 262040                   54.0                 33.0
# 262760                   39.0                 32.0
# 262820                   29.0                 49.0
# 264540                   39.0                 32.0
#
#            attacking_heading_accuracy  attacking_volleys  skill_dribbling  \
# sofifa_id
# 158023                           70.0               88.0             96.0
# 188545                           90.0               89.0             85.0
# 20801                            90.0               86.0             88.0
# 190871                           63.0               86.0             95.0
# 192985                           55.0               82.0             88.0
# ...                               ...                ...              ...
# 261962                           48.0               30.0             45.0
# 262040                           46.0               32.0             41.0
# 262760                           43.0               37.0             47.0
# 262820                           40.0               34.0             42.0
# 264540                           46.0               37.0             48.0
#
#            ...  mentality_vision  mentality_penalties  mentality_composure  \
# sofifa_id  ...
# 158023     ...              95.0                 75.0                 96.0
# 188545     ...              81.0                 90.0                 88.0
# 20801      ...              76.0                 88.0                 95.0
# 190871     ...              90.0                 93.0                 93.0
# 192985     ...              94.0                 83.0                 89.0
# ...        ...               ...                  ...                  ...
# 261962     ...              43.0                 42.0                 37.0
# 262040     ...              49.0                 44.0                 47.0
# 262760     ...              46.0                 39.0                 36.0
# 262820     ...              40.0                 49.0                 47.0
# 264540     ...              46.0                 35.0                 36.0
#
#            defending_marking_awareness  defending_sliding_tackle  \
# sofifa_id
# 158023                            20.0                      24.0
# 188545                            35.0                      19.0
# 20801                             24.0                      24.0
# 190871                            35.0                      29.0
# 192985                            68.0                      53.0
# ...                                ...                       ...
# 261962                            38.0                      48.0
# 262040                            37.0                      47.0
# 262760                            38.0                      48.0
# 262820                            10.0                      11.0
# 264540                            33.0                      37.0
#
#            goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# sofifa_id
# 158023                    6.0                  11.0                 15.0
# 188545                   15.0                   6.0                 12.0
# 20801                     7.0                  11.0                 15.0
# 190871                    9.0                   9.0                 15.0
# 192985                   15.0                  13.0                  5.0
# ...                       ...                   ...                  ...
# 261962                    6.0                  10.0                  5.0
# 262040                   11.0                  12.0                  6.0
# 262760                    8.0                   6.0                  7.0
# 262820                    7.0                  10.0                  7.0
# 264540                    8.0                  13.0                 13.0
#
#            goalkeeping_positioning  preferred_foot_Right
# sofifa_id
# 158023                        14.0                     0
# 188545                         8.0                     1
# 20801                         14.0                     1
# 190871                        15.0                     1
# 192985                        10.0                     1
# ...                            ...                   ...
# 261962                        15.0                     1
# 262040                         8.0                     1
# 262760                        10.0                     1
# 262820                        14.0                     1
# 264540                         9.0                     1
#
# [19239 rows x 35 columns]

# %%
players_22_norm.to_csv("players_22_norm.csv")

# %% [markdown]
# # Feature Selection

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import Lasso
from sklearn.preprocessing import MinMaxScaler
X_norm = MinMaxScaler().fit_transform(X)

sel_ = SelectFromModel(LinearRegression()) 
sel_.fit(X_norm, y)
# Out:
# SelectFromModel(estimator=LinearRegression())

# %%
sel_.get_support()
# Out:
# array([ True, False,  True, False,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False])

# %%
selected_feat = X.columns[(sel_.get_support())]

# let's print some stats
print('total features: {}'.format((X.shape[1])))
print('selected features: {}'.format(len(selected_feat)))
print('features with coefficients shrank to zero: {}'.format(
    np.sum(sel_.estimator_.coef_ == 0)))
# Out:
# total features: 35
# selected features: 3
# features with coefficients shrank to zero: 0

# %%
selected_feat
# Out:
# Index(['overall', 'age', 'international_reputation'], dtype='object')

# %% [markdown]
# # Modeling

# %%
X_model = X[selected_feat]
X_model.shape
# Out:
# (19239, 3)

# %%
X_train_val, X_test, y_train_val, y_test = train_test_split(X_model, y, test_size=0.20,random_state=42)
#X_train_val = X[3848:]
#X_test = X[:3848]
#y_train_val = y[3848:]
#y_test = y[:3848]

# %%
rgr = LinearRegression()
rgr.fit(X_train_val,y_train_val)
pred = rgr.predict(X_test)

# %%
plt.scatter(pred,y_test,alpha=0.1)
plt.plot(y_test, y_test, color='red',linewidth=1,label='Identity Line (Log Market Value)')
plt.title("Regression Fit on Test Set",weight='bold')
plt.xlabel("Log Predicted Market Value")
plt.ylabel("Log Market Value")
plt.legend(loc='lower right')
sns.despine()

# %%
lin_mse = mean_squared_error(pred, y_test)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 0.2757707113493766

# %%
score = r2_score(y_test, pred)  
print('Accuracy:',format(score*100,'.2f'),'%')
# Out:
# Accuracy: 94.84 %

# %%
print('Precisión del modelo:')
print(rgr.score(X_test, y_test))
# Out:
# Precisión del modelo:
# 0.94835426368256

# %%
# define some handy analysis support function
from sklearn.metrics import mean_squared_error, explained_variance_score, r2_score

def plot_prediction_analysis(y, y_pred, figsize=(10,4), title=''):
    fig, axs = plt.subplots(1, 2, figsize=figsize)
    axs[0].scatter(y, y_pred)
    mn = min(np.min(y), np.min(y_pred))
    mx = max(np.max(y), np.max(y_pred))
    axs[0].plot([mn, mx], [mn, mx], c='red')
    axs[0].set_xlabel('$y$')
    axs[0].set_ylabel('$\hat{y}$')
    rmse = np.sqrt(mean_squared_error(y, y_pred))
    evs = explained_variance_score(y, y_pred)
    r2 = r2_score(y, y_pred)
    axs[0].set_title('rmse = {:.2f}, evs = {:.2f}, r2 = {:,.2f}'.format(rmse, evs, r2))
    
    axs[1].hist(y-y_pred, bins=50)
    avg = np.mean(y-y_pred)
    std = np.std(y-y_pred)
    axs[1].set_xlabel('$y - \hat{y}$')
    axs[1].set_title('Histrogram prediction error, $\mu$ = {:.2f}, $\sigma$ = {:.2f}'.format(avg, std))
    
    if title!='':
        fig.suptitle(title)

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler, PolynomialFeatures

#model = LinearRegression()
model = Pipeline((
        ("standard_scaler", StandardScaler()),
        ("poly", PolynomialFeatures(degree=2)),
        ("lin_reg", Lasso(alpha=0.01))
    ))

model.fit(X_train_val, y_train_val)

y_train_pred = model.predict(X_train_val)

plot_prediction_analysis(y_train_val, y_train_pred, title='Polynomial Model - Trainingset')

y_test_pred = model.predict(X_test)
plot_prediction_analysis(y_test, y_test_pred, title='Polynomial Model - Testset')

# %%
X_model_10 = X[selected_feat]
X_model_10.shape
# Out:
# (19239, 3)

# %%
X_train_val_10, X_test_10, y_train_val_10, y_test_10 = train_test_split(X_model_10, y, test_size=0.10,random_state=42)
#X_train_val = X[3848:]
#X_test = X[:3848]
#y_train_val = y[3848:]
#y_test = y[:3848]

# %%
rgr_10 = LinearRegression()
rgr_10.fit(X_train_val_10,y_train_val_10)
pred_10 = rgr_10.predict(X_test_10)

# %%
lin_mse_10 = mean_squared_error(pred_10, y_test_10)
lin_rmse_10 = np.sqrt(lin_mse_10)
lin_rmse_10
# Out:
# 0.305277916161571

# %%
score_10 = r2_score(y_test_10, pred_10)  
print('Accuracy:',format(score_10*100,'.2f'),'%')
# Out:
# Accuracy: 93.48 %

# %%
print('Precisión del modelo:')
print(rgr_10.score(X_test_10, y_test_10))
# Out:
# Precisión del modelo:
# 0.934796492563502

# %%
X_model_30 = X[selected_feat]
X_model_30.shape
# Out:
# (19239, 3)

# %%
X_train_val_30, X_test_30, y_train_val_30, y_test_30 = train_test_split(X_model_30, y, test_size=0.30,random_state=42)
#X_train_val = X[3848:]
#X_test = X[:3848]
#y_train_val = y[3848:]
#y_test = y[:3848]

# %%
rgr_30 = LinearRegression()
rgr_30.fit(X_train_val_30,y_train_val_30)
pred_30 = rgr_30.predict(X_test_30)

# %%
lin_mse_30 = mean_squared_error(pred_30, y_test_30)
lin_rmse_30 = np.sqrt(lin_mse_30)
lin_rmse_30
# Out:
# 0.26452755481125956

# %%
score_30 = r2_score(y_test_30, pred_30)  
print('Accuracy:',format(score_30*100,'.2f'),'%')
# Out:
# Accuracy: 95.19 %

# %%
print('Precisión del modelo:')
print(rgr_30.score(X_test_30, y_test_30))
# Out:
# Precisión del modelo:
# 0.9518501678821851

# %% [markdown]
# # Cross-Validation in sklearn

# %%
# k-fold CV (using all the 13 variables)
lm = LinearRegression()
scores = cross_val_score(lm, X_train_val, y_train_val, scoring='r2', cv=5)
scores
# Out:
# array([0.95668685, 0.9551107 , 0.95557827, 0.95741594, 0.95210339])

# %%
# the other way of doing the same thing (more explicit)

# create a KFold object with 5 splits 
folds = KFold(n_splits = 5, shuffle = True, random_state = 100)
scores = cross_val_score(lm, X_train_val, y_train_val, scoring='r2', cv=folds)
scores
# Out:
# array([0.95474952, 0.96095346, 0.9536674 , 0.94932307, 0.95841083])

# %%
# can tune other metrics, such as MSE
scores = cross_val_score(lm, X_train_val, y_train_val, scoring='neg_mean_squared_error', cv=5)
scores
# Out:
# array([-0.06417762, -0.06919596, -0.06792237, -0.06465468, -0.07348996])

# %% [markdown]
# # LASSO

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import Lasso
from sklearn.preprocessing import MinMaxScaler
X_norm_lasso = MinMaxScaler().fit_transform(X)

sel_ = SelectFromModel(Lasso(alpha=.0001, random_state=42)) 
sel_.fit(X_norm_lasso, y)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.0001, random_state=42))

# %%
sel_.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True, False,  True,
#        False,  True, False,  True,  True,  True,  True,  True,  True,
#         True, False,  True,  True,  True,  True,  True, False,  True,
#         True,  True,  True, False, False,  True,  True,  True])

# %%
selected_feat = X.columns[(sel_.get_support())]

# let's print some stats
print('total features: {}'.format((X.shape[1])))
print('selected features: {}'.format(len(selected_feat)))
print('features with coefficients shrank to zero: {}'.format(
    np.sum(sel_.estimator_.coef_ == 0)))
# Out:
# total features: 35
# selected features: 28
# features with coefficients shrank to zero: 7

# %%
selected_feat
# Out:
# Index(['overall', 'potential', 'age', 'skill_moves',
#        'international_reputation', 'attacking_crossing', 'attacking_finishing',
#        'attacking_volleys', 'skill_fk_accuracy', 'skill_ball_control',
#        'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
#        'movement_reactions', 'movement_balance', 'power_shot_power',
#        'power_stamina', 'power_strength', 'power_long_shots',
#        'mentality_aggression', 'mentality_positioning', 'mentality_penalties',
#        'mentality_composure', 'defending_marking_awareness',
#        'defending_sliding_tackle', 'goalkeeping_kicking',
#        'goalkeeping_positioning', 'preferred_foot_Right'],
#       dtype='object')

# %%
X_model_lasso = X[selected_feat]
X_model_lasso.shape
# Out:
# (19239, 28)

# %%
X_train_val, X_test, y_train_val, y_test = train_test_split(X_model_lasso, y, test_size=0.25,random_state=42)
#X_train_val = X[3848:]
#X_test = X[:3848]
#y_train_val = y[3848:]
#y_test = y[:3848]

# %%
from sklearn.linear_model import Lasso
# Train model with default alpha=1
lasso_model = Lasso(alpha = 0.1)    
lasso_model.fit(X_train_val, y_train_val)
list(zip(selected_feat, lasso_model.coef_))
## doing feature selection with Lasso
# Out:
# [('overall', 0.16924684625992156),
#  ('potential', 0.018581084235874932),
#  ('age', -0.09291532599722684),
#  ('skill_moves', 0.0),
#  ('international_reputation', 0.0),
#  ('attacking_crossing', 0.0),
#  ('attacking_finishing', 0.000925549075333072),
#  ('attacking_volleys', 0.001406795580340701),
#  ('skill_fk_accuracy', 0.0),
#  ('skill_ball_control', 0.0002060931346992354),
#  ('movement_acceleration', 0.0),
#  ('movement_sprint_speed', 0.0),
#  ('movement_agility', -0.0),
#  ('movement_reactions', 0.0014900987092918087),
#  ('movement_balance', -0.0),
#  ('power_shot_power', 0.0),
#  ('power_stamina', 0.0005615388561259615),
#  ('power_strength', 0.0),
#  ('power_long_shots', 0.0),
#  ('mentality_aggression', 0.0),
#  ('mentality_positioning', 0.0011367517108744176),
#  ('mentality_penalties', 0.0),
#  ('mentality_composure', 0.0),
#  ('defending_marking_awareness', 0.0),
#  ('defending_sliding_tackle', -0.0),
#  ('goalkeeping_kicking', -0.0),
#  ('goalkeeping_positioning', -0.0017245793163863812),
#  ('preferred_foot_Right', 0.0)]

# %%
std = StandardScaler()
std.fit(X_train_val.values)
X_tr = std.transform(X_train_val.values)
X_te = std.transform(X_test.values)
## Scaling x values for lasso,ridge,elastic net

# %%
kf = KFold(n_splits=5, shuffle=True, random_state = 71)

# %%
alphavec = 10**np.linspace(-15,4,400)
lasso_model = LassoCV(alphas = alphavec, cv=kf)
lasso_model.fit(X_tr, y_train_val)
lasso_model.alpha_
## finding alpha value that gives lowest MAE for Lasso CV
# Out:
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20.643359401876523, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.881697362542127, tolerance: 1.7391765867728213
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41.12847421907634, tolerance: 1.7391765867728213
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47.08669784145076, tolerance: 1.7391765867728213
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 36.61416729107009, tolerance: 1.7676734537315724
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28.060495855106524, tolerance: 1.7676734537315724
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.376851717361433, tolerance: 1.7676734537315724
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.200101199473465, tolerance: 1.7872741278316915
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.716270639280538, tolerance: 1.7872741278316915
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14.513790799279036, tolerance: 1.7872741278316915
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.572679753842635, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.97414054148203, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21.739109911997957, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23.01631902700433, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.177440286555452, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# 0.00024040991835099645

# %%
test_predictions = lasso_model.predict(X_te)
test_mae = mean_absolute_error(test_predictions, y_test)
print("Validation MAE: {:,.0f}".format(test_mae))
# Out:
# Validation MAE: 0

# %%
score = r2_score(y_test, test_predictions)  
print('Accuracy:',format(score*100,'.2f'),'%')
# Out:
# Accuracy: 95.55 %

# %% [markdown]
# # RIDGE

# %%
alphavec = 10**np.linspace(-2,2,200)
ridge_model = RidgeCV(alphas = alphavec, cv=kf)
ridge_model.fit(X_tr, y_train_val)
ridge_model.alpha_
## finding alpha value that gives lowest MAE for Ridge CV
# Out:
# 1.175849554052157

# %%
list(zip(X_train_val.columns, ridge_model.coef_))
# finding coefficients for optimum alpha value for Ridge
# Out:
# [('overall', 1.2831661208929472),
#  ('potential', 0.022242549628063397),
#  ('age', -0.5449959456914704),
#  ('skill_moves', 0.027863036573084567),
#  ('international_reputation', 0.07463392467910802),
#  ('attacking_crossing', -0.002267627742032211),
#  ('attacking_finishing', 0.013877635074003187),
#  ('attacking_volleys', 0.013708016803123241),
#  ('skill_fk_accuracy', 0.014682313236231457),
#  ('skill_ball_control', -0.027373504092376162),
#  ('movement_acceleration', -0.010796790190403244),
#  ('movement_sprint_speed', 0.0015330570820669392),
#  ('movement_agility', -0.01580597760647545),
#  ('movement_reactions', 0.013743192291005794),
#  ('movement_balance', 0.0031843415725626412),
#  ('power_shot_power', -0.004232986312585521),
#  ('power_stamina', 0.01741697152858453),
#  ('power_strength', 0.00500977309191723),
#  ('power_long_shots', -0.00434095250882668),
#  ('mentality_aggression', 0.0034059982032843346),
#  ('mentality_positioning', 0.027921566309383444),
#  ('mentality_penalties', -0.012790937995449747),
#  ('mentality_composure', -0.016794037821214584),
#  ('defending_marking_awareness', 0.004455141037454195),
#  ('defending_sliding_tackle', -0.029751840572861062),
#  ('goalkeeping_kicking', -0.014417977304314206),
#  ('goalkeeping_positioning', -0.05743186983088952),
#  ('preferred_foot_Right', 0.0034763442046712775)]

# %%
ridge_model_final = Ridge(alpha = 0.9329304026284686) 
Mean_R2_Ridge_CV = np.mean(cross_val_score(ridge_model_final, X_tr, y_train_val, cv=kf, scoring='r2'))
Mean_R2_Ridge_CV
# scoring the Ridge model based on CV
# Out:
# 0.9604551101404594

# %%
Std_R2_Ridge_CV = np.std(cross_val_score(ridge_model_final, X_tr, y_train_val, cv=kf, scoring='r2'))
Std_R2_Ridge_CV
# Out:
# 0.0060749249612509

# %%
Mean_MAE_Ridge_CV = -np.mean(cross_val_score(ridge_model_final, X_tr, y_train_val, cv=kf, scoring='neg_mean_absolute_error'))
Mean_MAE_Ridge_CV
# scoring the Ridge model based on CV
# Out:
# 0.1655526211358257

# %%
Std_MAE_Ridge_CV = np.std(cross_val_score(ridge_model_final, X_tr, y_train_val, cv=kf, scoring='neg_mean_absolute_error'))
Std_MAE_Ridge_CV
# Out:
# 0.004644401084941005

# %%
from sklearn.model_selection import GridSearchCV

price_model_ridgecv = Ridge(random_state=1)
parameters = [{"alpha": [6000, 10000, 50000]}]

grid = GridSearchCV(estimator=price_model_ridgecv, param_grid=parameters, cv=kf)
grid.fit(X_tr, y_train_val)
print("Best estimator: ", grid.best_estimator_)
print("Best score: ", grid.best_score_)

price_model_ridgecv = Ridge(alpha=grid.best_params_["alpha"], random_state=1)
price_model_ridgecv.fit(X_tr, y_train_val)
test_predictions = price_model_ridgecv.predict(X_te)
test_mae = mean_absolute_error(test_predictions, y_test)
print("Validation MAE: {:,.0f}".format(test_mae))
#Best estimator:  Ridge(alpha=6000, random_state=1)
#Best score:  0.5252214885053264
#Validation MAE: 6,060,204
# Out:
# Best estimator:  Ridge(alpha=6000, random_state=1)
# Best score:  0.8913028556014428
# Validation MAE: 0

# %%
test_predictions_ridge = price_model_ridgecv.predict(X_te)
test_mae = mean_absolute_error(test_predictions_ridge, y_test)
print("Validation MAE: {:,.0f}".format(test_mae))
# Out:
# Validation MAE: 0

# %%
score = r2_score(y_test, test_predictions_ridge)  
print('Accuracy:',format(score*100,'.2f'),'%')
# Out:
# Accuracy: 89.74 %

# %% [markdown]
# # ElasticNetCV

# %%
alphavec = 10**np.linspace(-22,-17,300)
elastic_model = ElasticNetCV(alphas = alphavec, cv=kf)
elastic_model.fit(X_tr, y_train_val)
elastic_model.alpha_
## finding alpha value that gives lowest MAE for ElasticNet CV
# Out:
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.30887307799463, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 308.4593866811257, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 308.9473065735166, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 314.18258258747716, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 317.09107493169427, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 315.88791304417623, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 314.9650084657546, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 313.66799428140575, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 313.9522176907536, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 315.6665906557755, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 312.2343087230317, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 317.6056632976573, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 315.017039743246, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 315.257255046024, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 315.48856952389684, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 313.82336381249246, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 315.92484802617616, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319.3022348712072, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319.36472019551985, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 316.5691250653769, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 315.1443671044687, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 315.3808325393963, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 317.0528939743656, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 317.21755174664554, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 318.70231636941867, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 318.81834606251533, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 318.41858902787084, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319.01025733651204, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 317.94900210831526, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 316.972887045552, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 317.14076657652527, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319.64561426745803, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 315.557912968786, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.77307648099503, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.0341218153383, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319.6453916176922, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319.70614001701307, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 318.14783214828543, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319.83754982365537, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319.8968628130865, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319.95824732624305, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.012855075979, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.0617223393745, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319.4650760999921, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.16469863263615, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.6898118178274, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319.677032563793, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.57540931192045, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319.27131870548016, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.79084431692786, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.22084370351695, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319.9800318667112, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.6231590887007, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.52682797445567, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.3904093045969, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.4289103306218, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.46589372448886, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319.8968470147029, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.97253923352804, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.884502363407, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.6005112083647, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.43653971191617, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.4732674516574, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.8946047732559, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.71588207846503, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.9923462161532, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.8743233108461, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.02326393894225, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.6663144872393, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.93315276961033, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.03393040339125, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.87975423450484, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.98434110716886, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.00075523459793, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.82027498046114, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.8418511587956, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.6812841085602, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.8839204653765, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.15649697163536, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.92286722523454, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.94124517568986, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.18421595958574, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.12029031078947, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.99266707082137, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.1418854290108, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.02324045384563, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.0378255605135, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.05160651634145, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.1800891492164, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.078374274536, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.0908759039345, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.1029141707923, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.8195510887694, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.12547769007, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.13636519579484, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.14668254996354, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.2409241121082, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.2148413803202, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.0972952098846, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.22927448848327, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.2360826172708, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.2009068844423, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.30915873885607, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.2550092281123, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.2856039372117, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.2306885208003, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.18007825964526, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.24389231005466, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.25020380171367, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.2562224911538, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3505471982292, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.2675885729388, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3002768700716, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.2781128992055, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.24091414873993, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.28785687063066, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.29245466487527, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.31941827120045, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3372731779644, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.2704500398766, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.27570711478023, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3129656442439, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3166150370583, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3499380706549, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3522045714392, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.343321948751, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.32988528457184, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.33289579995744, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.37268853316624, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.37408225259344, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3640400780358, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.38328828083115, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3589773279488, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3608889737396, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3627283466148, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3344411021743, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.35536130083705, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.37479525151844, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3593748337747, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3773740738994, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.37859089102466, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3797635240997, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3665420176895, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3681678893531, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3936442847703, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3840205397559, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.39113563945904, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.39538392724126, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.36403316809344, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.38766995309436, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3779534969741, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3892952073451, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.39982361353634, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3814027947346, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3824688891374, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.38349320842656, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3844800863595, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.38542837860416, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# ...
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.22798242023686, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.22761114040213, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.22764033508, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.22802623397615, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2274659300771, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2280527547197, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.22787400420185, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.22789326977045, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.22759698520986, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2279296452815, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.22789822776787, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2278581454698, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.22797921635157, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.22805943022695, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2280716915665, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2279332141248, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2280370028546, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.228105766369, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2279823958621, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2281263920829, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.22801216568286, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.22802621226316, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2280397285159, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2281631699536, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.22795898434543, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.22813864061595, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2280888772415, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2281946981476, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2282158649377, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2281210773649, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.22818161654146, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2281057860628, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2282136583843, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.22815861397027, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2282600915647, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2282796819898, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2283037075306, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2281907925202, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.22826007527254, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.22829457878623, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2282463078668, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2282735990143, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.22827777072376, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2282306565498, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2282856474475, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.22828936407495, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.22831571564296, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2282788494466, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2283207798491, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.22830287873063, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.22829032508, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2283276812533, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.309e+02, tolerance: 2.200e+00
#   model = cd_fast.enet_coordinate_descent(
# 1e-17

# %%
y_pred = elastic_model.predict(X_te)

# %%
mean_squared_error = np.mean((y_pred - y_test)**2)

# %%
print("Mean Squared error on test set", mean_squared_error)
# Out:
# Mean Squared error on test set 0.0654274506691347

# %% [markdown]
# # Linear Regression

# %%
lm = LinearRegression()

Mean_R2_Linear_CV = np.mean(cross_val_score(lm, X_train_val, y_train_val, cv=kf, scoring='r2'))
Mean_R2_Linear_CV 
# scoring the LR model based on CV
# Out:
# 0.9604549130584632

# %%
Std_R2_Linear_CV = np.std(cross_val_score(lm, X_train_val, y_train_val, cv=kf, scoring='r2'))
Std_R2_Linear_CV
# Out:
# 0.00607932805605788

# %%
Mean_MAE_Linear_CV = - np.mean(cross_val_score(lm, X_train_val, y_train_val, cv=kf, scoring='neg_mean_absolute_error'))
Mean_MAE_Linear_CV
# Out:
# 0.16558962927148432

# %%
Std_MAE_Linear_CV = np.std(cross_val_score(lm, X_train_val, y_train_val, cv=kf, scoring='neg_mean_absolute_error'))
Std_MAE_Linear_CV
# Out:
# 0.004645566513263216

# %%
X_train_val = X_train_val.reset_index().drop('sofifa_id',axis=1)
y_train_val = y_train_val.reset_index().drop('sofifa_id',axis=1)

# %%
def diagnostic_plot2(x_train, y_train, x_test, y_test):
    plt.figure(figsize=(22,8))
    
  #  poly = make_pipeline(PolynomialFeatures(4), LinearRegression())
  #  poly.fit(x_train,y_train)
  #  pred = poly.predict(x_test)
    
    rgr = LinearRegression()
    rgr.fit(x_train,y_train)
    pred = rgr.predict(x_test)    

    plt.subplot(1, 2, 1)
    plt.scatter(pred,y_test,alpha=0.1)
    plt.plot(y_test, y_test, color='red',linewidth=1,label='Identity Line (Log Market Value)')
    plt.title("Regression Fit on Test Set",weight='bold')
    plt.xlabel("Log Predicted Market Value")
    plt.ylabel("Log Market Value")
    plt.legend(loc='lower right')
    sns.despine()
    
    plt.subplot(1, 2, 2)
    res = np.array(y_test).reshape(-1,1) - pred
    plt.scatter(pred, res,alpha=0.1)
    plt.title("Residual Plot on Test Set",weight='bold')
    plt.xlabel("Log Predicted Market Value")
    plt.ylabel("Residuals")
    sns.despine()
    
 #   plt.subplot(1, 3, 3)
 #   #Generates a probability plot of sample data against the quantiles of a 
 #   # specified theoretical distribution 
 #   stats.probplot(res.T[0], dist="norm", plot=plt,)
 #   plt.title("Normal Q-Q plot")

# %%
sns.set(style='white',font_scale=1.5)
diagnostic_plot2(X_train_val, y_train_val,X_test,y_test)
plt.savefig('regression1.png',transparent=True, bbox_inches='tight')

# %%
rgr = LinearRegression()
rgr.fit(X_train_val,y_train_val)
predicted = rgr.predict(X_test)    
predicted
# Out:
# array([[13.60159475],
#        [12.42015961],
#        [12.15021256],
#        ...,
#        [12.30332616],
#        [11.98340997],
#        [16.4419985 ]])

# %%
Test_Set = pd.DataFrame(y_test).join(X_test).join(pd.DataFrame(players_22_norm['short_name']))
Test_Set['Log Market Value'] = np.exp(Test_Set['Log Market Value'] )
Test_Set = Test_Set.rename(columns={'Log Market Value':'Market Value'})
Test_Set['Predicted Market Value'] = np.exp(predicted)
Test_Set = Test_Set.sort_values(by='Predicted Market Value',ascending=False)
#Test_Set['Market Value'] = Test_Set['Market Value'].apply(lambda x : "{:,}".format(int(x)))
#Test_Set['Predicted Market Value'] = Test_Set['Predicted Market Value'].apply(lambda x : "{:,}".format(int(x)))

# %%
Test_Set
# Out:
#            Market Value  overall  potential  age  skill_moves  \
# sofifa_id
# 231747     1.552000e+08       91         95   22          5.0
# 190871     1.032000e+08       91         91   29          5.0
# 158023     6.240000e+07       93         93   34          4.0
# 212622     8.640000e+07       89         90   26          3.0
# 209331     8.080000e+07       89         89   29          4.0
# ...                 ...      ...        ...  ...          ...
# 257934     5.600100e+04       48         53   24          2.0
# 258987     5.600100e+04       48         53   24          2.0
# 186838     1.600100e+04       57         57   39          1.0
# 262371     2.280362e+06       56         56   40          2.0
# 232473     1.600100e+04       57         57   40          1.0
#
#            international_reputation  attacking_crossing  attacking_finishing  \
# sofifa_id
# 231747                            4                78.0                 93.0
# 190871                            5                85.0                 83.0
# 158023                            5                85.0                 95.0
# 212622                            4                91.0                 68.0
# 209331                            4                79.0                 91.0
# ...                             ...                 ...                  ...
# 257934                            1                39.0                 32.0
# 258987                            1                38.0                 29.0
# 186838                            1                17.0                 11.0
# 262371                            1                34.0                 58.0
# 232473                            1                13.0                  9.0
#
#            attacking_volleys  skill_fk_accuracy  ...  mentality_positioning  \
# sofifa_id                                        ...
# 231747                  83.0               69.0  ...                   92.0
# 190871                  86.0               87.0  ...                   86.0
# 158023                  88.0               94.0  ...                   93.0
# 212622                  69.0               61.0  ...                   80.0
# 209331                  81.0               69.0  ...                   91.0
# ...                      ...                ...  ...                    ...
# 257934                  24.0               34.0  ...                   45.0
# 258987                  33.0               31.0  ...                   33.0
# 186838                  11.0               11.0  ...                   12.0
# 262371                  44.0               35.0  ...                   57.0
# 232473                  10.0               12.0  ...                    6.0
#
#            mentality_penalties  mentality_composure  \
# sofifa_id
# 231747                    79.0                 88.0
# 190871                    93.0                 93.0
# 158023                    75.0                 96.0
# 212622                    44.0                 85.0
# 209331                    86.0                 90.0
# ...                        ...                  ...
# 257934                    41.0                 40.0
# 258987                    43.0                 41.0
# 186838                    11.0                 29.0
# 262371                    56.0                 53.0
# 232473                    13.0                 26.0
#
#            defending_marking_awareness  defending_sliding_tackle  \
# sofifa_id
# 231747                            26.0                      32.0
# 190871                            35.0                      29.0
# 158023                            20.0                      24.0
# 212622                            85.0                      79.0
# 209331                            38.0                      41.0
# ...                                ...                       ...
# 257934                            43.0                      44.0
# 258987                            38.0                      44.0
# 186838                            18.0                       9.0
# 262371                            20.0                      16.0
# 232473                            21.0                      15.0
#
#            goalkeeping_kicking  goalkeeping_positioning  preferred_foot_Right  \
# sofifa_id
# 231747                     7.0                     11.0                     1
# 190871                    15.0                     15.0                     1
# 158023                    15.0                     14.0                     0
# 212622                     7.0                     15.0                     1
# 209331                     9.0                     11.0                     0
# ...                        ...                      ...                   ...
# 257934                     8.0                     11.0                     1
# 258987                    13.0                     11.0                     1
# 186838                    57.0                     55.0                     1
# 262371                    10.0                     12.0                     1
# 232473                    54.0                     66.0                     1
#
#               short_name  Predicted Market Value
# sofifa_id
# 231747         K. Mbappé            3.166810e+08
# 190871         Neymar Jr            1.611554e+08
# 158023          L. Messi            1.327423e+08
# 212622        J. Kimmich            1.191757e+08
# 209331          M. Salah            8.994891e+07
# ...                  ...                     ...
# 257934         Guo Yunqi            3.381104e+04
# 258987     Ruan Zhexiang            3.327284e+04
# 186838        G. Doherty            2.751665e+04
# 262371         C. Dundas            2.530548e+04
# 232473         H. Shiota            2.332576e+04
#
# [4810 rows x 31 columns]

# %%
Test_Set = Test_Set[['short_name','Market Value','Predicted Market Value','age','international_reputation','attacking_crossing', 'attacking_finishing',
       'attacking_volleys', 'skill_fk_accuracy', 'skill_ball_control',
       'movement_acceleration', 'movement_agility', 'movement_reactions',
       'movement_balance', 'power_shot_power', 'power_stamina',
       'power_strength', 'power_long_shots', 'mentality_aggression',
       'mentality_positioning', 'mentality_penalties', 'mentality_composure',
       'defending_marking_awareness', 'defending_sliding_tackle',
       'goalkeeping_kicking', 'goalkeeping_positioning', 'preferred_foot_Right']] #
Test_Set.reset_index(inplace=True)
Test_Set.drop('sofifa_id',axis=1,inplace=True)
Test_Set
# Out:
# C:\Users\Kiko\AppData\Local\Temp\ipykernel_22732\975138869.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_Set.drop('sofifa_id',axis=1,inplace=True)
#          short_name  Market Value  Predicted Market Value  age  \
# 0         K. Mbappé  1.552000e+08            3.166810e+08   22
# 1         Neymar Jr  1.032000e+08            1.611554e+08   29
# 2          L. Messi  6.240000e+07            1.327423e+08   34
# 3        J. Kimmich  8.640000e+07            1.191757e+08   26
# 4          M. Salah  8.080000e+07            8.994891e+07   29
# ...             ...           ...                     ...  ...
# 4805      Guo Yunqi  5.600100e+04            3.381104e+04   24
# 4806  Ruan Zhexiang  5.600100e+04            3.327284e+04   24
# 4807     G. Doherty  1.600100e+04            2.751665e+04   39
# 4808      C. Dundas  2.280362e+06            2.530548e+04   40
# 4809      H. Shiota  1.600100e+04            2.332576e+04   40
#
#       international_reputation  attacking_crossing  attacking_finishing  \
# 0                            4                78.0                 93.0
# 1                            5                85.0                 83.0
# 2                            5                85.0                 95.0
# 3                            4                91.0                 68.0
# 4                            4                79.0                 91.0
# ...                        ...                 ...                  ...
# 4805                         1                39.0                 32.0
# 4806                         1                38.0                 29.0
# 4807                         1                17.0                 11.0
# 4808                         1                34.0                 58.0
# 4809                         1                13.0                  9.0
#
#       attacking_volleys  skill_fk_accuracy  skill_ball_control  ...  \
# 0                  83.0               69.0                91.0  ...
# 1                  86.0               87.0                95.0  ...
# 2                  88.0               94.0                96.0  ...
# 3                  69.0               61.0                85.0  ...
# 4                  81.0               69.0                89.0  ...
# ...                 ...                ...                 ...  ...
# 4805               24.0               34.0                45.0  ...
# 4806               33.0               31.0                44.0  ...
# 4807               11.0               11.0                19.0  ...
# 4808               44.0               35.0                54.0  ...
# 4809               10.0               12.0                18.0  ...
#
#       power_long_shots  mentality_aggression  mentality_positioning  \
# 0                 82.0                  62.0                   92.0
# 1                 81.0                  63.0                   86.0
# 2                 94.0                  44.0                   93.0
# 3                 84.0                  89.0                   80.0
# 4                 84.0                  63.0                   91.0
# ...                ...                   ...                    ...
# 4805              34.0                  51.0                   45.0
# 4806              28.0                  52.0                   33.0
# 4807              13.0                  32.0                   12.0
# 4808              52.0                  42.0                   57.0
# 4809               6.0                  24.0                    6.0
#
#       mentality_penalties  mentality_composure  defending_marking_awareness  \
# 0                    79.0                 88.0                         26.0
# 1                    93.0                 93.0                         35.0
# 2                    75.0                 96.0                         20.0
# 3                    44.0                 85.0                         85.0
# 4                    86.0                 90.0                         38.0
# ...                   ...                  ...                          ...
# 4805                 41.0                 40.0                         43.0
# 4806                 43.0                 41.0                         38.0
# 4807                 11.0                 29.0                         18.0
# 4808                 56.0                 53.0                         20.0
# 4809                 13.0                 26.0                         21.0
#
#       defending_sliding_tackle  goalkeeping_kicking  goalkeeping_positioning  \
# 0                         32.0                  7.0                     11.0
# 1                         29.0                 15.0                     15.0
# 2                         24.0                 15.0                     14.0
# 3                         79.0                  7.0                     15.0
# 4                         41.0                  9.0                     11.0
# ...                        ...                  ...                      ...
# 4805                      44.0                  8.0                     11.0
# 4806                      44.0                 13.0                     11.0
# 4807                       9.0                 57.0                     55.0
# 4808                      16.0                 10.0                     12.0
# 4809                      15.0                 54.0                     66.0
#
#       preferred_foot_Right
# 0                        1
# 1                        1
# 2                        0
# 3                        1
# 4                        0
# ...                    ...
# 4805                     1
# 4806                     1
# 4807                     1
# 4808                     1
# 4809                     1
#
# [4810 rows x 27 columns]

# %%
mean_absolute_error(Test_Set['Market Value'],Test_Set['Predicted Market Value'])
# Out:
# 506315.1181951614

# %%
r2_score(Test_Set['Market Value'],Test_Set['Predicted Market Value'])
# Out:
# 0.7608919001435048

# %%
stats.kurtosis(Test_Set['Market Value']-Test_Set['Predicted Market Value'])
# Out:
# 1652.7503952872344

# %%
Test_Set.dtypes
# Out:
# short_name                      object
# Market Value                   float64
# Predicted Market Value         float64
# age                              int64
# international_reputation         int64
# attacking_crossing             float64
# attacking_finishing            float64
# attacking_volleys              float64
# skill_fk_accuracy              float64
# skill_ball_control             float64
# movement_acceleration          float64
# movement_agility               float64
# movement_reactions             float64
# movement_balance               float64
# power_shot_power               float64
# power_stamina                  float64
# power_strength                 float64
# power_long_shots               float64
# mentality_aggression           float64
# mentality_positioning          float64
# mentality_penalties            float64
# mentality_composure            float64
# defending_marking_awareness    float64
# defending_sliding_tackle       float64
# goalkeeping_kicking            float64
# goalkeeping_positioning        float64
# preferred_foot_Right             uint8
# dtype: object

# %%
Test_Set['Predicted Market Value']
# Out:
# 0       3.166810e+08
# 1       1.611554e+08
# 2       1.327423e+08
# 3       1.191757e+08
# 4       8.994891e+07
#             ...
# 4805    3.381104e+04
# 4806    3.327284e+04
# 4807    2.751665e+04
# 4808    2.530548e+04
# 4809    2.332576e+04
# Name: Predicted Market Value, Length: 4810, dtype: float64

# %%
Test_Set['Market Value'] = Test_Set['Market Value'].apply(lambda x : "{:,}".format(int(x)))
Test_Set['Predicted Market Value'] = Test_Set['Predicted Market Value'].apply(lambda x : "{:,}".format(int(x)))
# Out:
# C:\Users\Kiko\AppData\Local\Temp\ipykernel_22732\3522353445.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_Set['Market Value'] = Test_Set['Market Value'].apply(lambda x : "{:,}".format(int(x)))
# C:\Users\Kiko\AppData\Local\Temp\ipykernel_22732\3522353445.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_Set['Predicted Market Value'] = Test_Set['Predicted Market Value'].apply(lambda x : "{:,}".format(int(x)))

# %%
Test_Set
# Out:
#          short_name Market Value Predicted Market Value  age  \
# 0         K. Mbappé  155,200,001            316,680,950   22
# 1         Neymar Jr  103,200,000            161,155,429   29
# 2          L. Messi   62,400,000            132,742,258   34
# 3        J. Kimmich   86,400,001            119,175,697   26
# 4          M. Salah   80,800,000             89,948,910   29
# ...             ...          ...                    ...  ...
# 4805      Guo Yunqi       56,001                 33,811   24
# 4806  Ruan Zhexiang       56,001                 33,272   24
# 4807     G. Doherty       16,001                 27,516   39
# 4808      C. Dundas    2,280,362                 25,305   40
# 4809      H. Shiota       16,001                 23,325   40
#
#       international_reputation  attacking_crossing  attacking_finishing  \
# 0                            4                78.0                 93.0
# 1                            5                85.0                 83.0
# 2                            5                85.0                 95.0
# 3                            4                91.0                 68.0
# 4                            4                79.0                 91.0
# ...                        ...                 ...                  ...
# 4805                         1                39.0                 32.0
# 4806                         1                38.0                 29.0
# 4807                         1                17.0                 11.0
# 4808                         1                34.0                 58.0
# 4809                         1                13.0                  9.0
#
#       attacking_volleys  skill_fk_accuracy  skill_ball_control  ...  \
# 0                  83.0               69.0                91.0  ...
# 1                  86.0               87.0                95.0  ...
# 2                  88.0               94.0                96.0  ...
# 3                  69.0               61.0                85.0  ...
# 4                  81.0               69.0                89.0  ...
# ...                 ...                ...                 ...  ...
# 4805               24.0               34.0                45.0  ...
# 4806               33.0               31.0                44.0  ...
# 4807               11.0               11.0                19.0  ...
# 4808               44.0               35.0                54.0  ...
# 4809               10.0               12.0                18.0  ...
#
#       power_long_shots  mentality_aggression  mentality_positioning  \
# 0                 82.0                  62.0                   92.0
# 1                 81.0                  63.0                   86.0
# 2                 94.0                  44.0                   93.0
# 3                 84.0                  89.0                   80.0
# 4                 84.0                  63.0                   91.0
# ...                ...                   ...                    ...
# 4805              34.0                  51.0                   45.0
# 4806              28.0                  52.0                   33.0
# 4807              13.0                  32.0                   12.0
# 4808              52.0                  42.0                   57.0
# 4809               6.0                  24.0                    6.0
#
#       mentality_penalties  mentality_composure  defending_marking_awareness  \
# 0                    79.0                 88.0                         26.0
# 1                    93.0                 93.0                         35.0
# 2                    75.0                 96.0                         20.0
# 3                    44.0                 85.0                         85.0
# 4                    86.0                 90.0                         38.0
# ...                   ...                  ...                          ...
# 4805                 41.0                 40.0                         43.0
# 4806                 43.0                 41.0                         38.0
# 4807                 11.0                 29.0                         18.0
# 4808                 56.0                 53.0                         20.0
# 4809                 13.0                 26.0                         21.0
#
#       defending_sliding_tackle  goalkeeping_kicking  goalkeeping_positioning  \
# 0                         32.0                  7.0                     11.0
# 1                         29.0                 15.0                     15.0
# 2                         24.0                 15.0                     14.0
# 3                         79.0                  7.0                     15.0
# 4                         41.0                  9.0                     11.0
# ...                        ...                  ...                      ...
# 4805                      44.0                  8.0                     11.0
# 4806                      44.0                 13.0                     11.0
# 4807                       9.0                 57.0                     55.0
# 4808                      16.0                 10.0                     12.0
# 4809                      15.0                 54.0                     66.0
#
#       preferred_foot_Right
# 0                        1
# 1                        1
# 2                        0
# 3                        1
# 4                        0
# ...                    ...
# 4805                     1
# 4806                     1
# 4807                     1
# 4808                     1
# 4809                     1
#
# [4810 rows x 27 columns]

# %%
#Test_Set['Market Value'] = Test_Set['Market Value'].apply(lambda x : "{:,}".format(int(x)))
#Test_Set['Predicted Market Value'] = Test_Set['Predicted Market Value'].apply(lambda x : "{:,}".format(int(x)))
#Test_Set[['defending','passing','physic','shooting','goalkeeping']] = Test_Set[['defending','passing','physic','shooting','goalkeeping']].apply(lambda x: round(x,1)) #'international_reputation'
Test_Set = Test_Set.rename(columns={'Market Value':'Market Value (Euros)','Predicted Market Value': 'Predicted Market Value (Euros)'})
Test_Set
# Out:
#          short_name Market Value (Euros) Predicted Market Value (Euros)  age  \
# 0         K. Mbappé          155,200,001                    316,680,950   22
# 1         Neymar Jr          103,200,000                    161,155,429   29
# 2          L. Messi           62,400,000                    132,742,258   34
# 3        J. Kimmich           86,400,001                    119,175,697   26
# 4          M. Salah           80,800,000                     89,948,910   29
# ...             ...                  ...                            ...  ...
# 4805      Guo Yunqi               56,001                         33,811   24
# 4806  Ruan Zhexiang               56,001                         33,272   24
# 4807     G. Doherty               16,001                         27,516   39
# 4808      C. Dundas            2,280,362                         25,305   40
# 4809      H. Shiota               16,001                         23,325   40
#
#       international_reputation  attacking_crossing  attacking_finishing  \
# 0                            4                78.0                 93.0
# 1                            5                85.0                 83.0
# 2                            5                85.0                 95.0
# 3                            4                91.0                 68.0
# 4                            4                79.0                 91.0
# ...                        ...                 ...                  ...
# 4805                         1                39.0                 32.0
# 4806                         1                38.0                 29.0
# 4807                         1                17.0                 11.0
# 4808                         1                34.0                 58.0
# 4809                         1                13.0                  9.0
#
#       attacking_volleys  skill_fk_accuracy  skill_ball_control  ...  \
# 0                  83.0               69.0                91.0  ...
# 1                  86.0               87.0                95.0  ...
# 2                  88.0               94.0                96.0  ...
# 3                  69.0               61.0                85.0  ...
# 4                  81.0               69.0                89.0  ...
# ...                 ...                ...                 ...  ...
# 4805               24.0               34.0                45.0  ...
# 4806               33.0               31.0                44.0  ...
# 4807               11.0               11.0                19.0  ...
# 4808               44.0               35.0                54.0  ...
# 4809               10.0               12.0                18.0  ...
#
#       power_long_shots  mentality_aggression  mentality_positioning  \
# 0                 82.0                  62.0                   92.0
# 1                 81.0                  63.0                   86.0
# 2                 94.0                  44.0                   93.0
# 3                 84.0                  89.0                   80.0
# 4                 84.0                  63.0                   91.0
# ...                ...                   ...                    ...
# 4805              34.0                  51.0                   45.0
# 4806              28.0                  52.0                   33.0
# 4807              13.0                  32.0                   12.0
# 4808              52.0                  42.0                   57.0
# 4809               6.0                  24.0                    6.0
#
#       mentality_penalties  mentality_composure  defending_marking_awareness  \
# 0                    79.0                 88.0                         26.0
# 1                    93.0                 93.0                         35.0
# 2                    75.0                 96.0                         20.0
# 3                    44.0                 85.0                         85.0
# 4                    86.0                 90.0                         38.0
# ...                   ...                  ...                          ...
# 4805                 41.0                 40.0                         43.0
# 4806                 43.0                 41.0                         38.0
# 4807                 11.0                 29.0                         18.0
# 4808                 56.0                 53.0                         20.0
# 4809                 13.0                 26.0                         21.0
#
#       defending_sliding_tackle  goalkeeping_kicking  goalkeeping_positioning  \
# 0                         32.0                  7.0                     11.0
# 1                         29.0                 15.0                     15.0
# 2                         24.0                 15.0                     14.0
# 3                         79.0                  7.0                     15.0
# 4                         41.0                  9.0                     11.0
# ...                        ...                  ...                      ...
# 4805                      44.0                  8.0                     11.0
# 4806                      44.0                 13.0                     11.0
# 4807                       9.0                 57.0                     55.0
# 4808                      16.0                 10.0                     12.0
# 4809                      15.0                 54.0                     66.0
#
#       preferred_foot_Right
# 0                        1
# 1                        1
# 2                        0
# 3                        1
# 4                        0
# ...                    ...
# 4805                     1
# 4806                     1
# 4807                     1
# 4808                     1
# 4809                     1
#
# [4810 rows x 27 columns]

# %%
Test_Set.to_csv('prueba final_lr.csv')

# %% [markdown]
# # Modelo entero

# %%
rgr = LinearRegression()
rgr.fit(X_model,y)
predicted = rgr.predict(X_model)    
predicted
# Out:
# array([18.62610966, 18.67384116, 18.00605499, ..., 10.56794618,
#        10.80645206, 10.80645206])

# %%
Test_Set = pd.DataFrame(y).join(X_model).join(pd.DataFrame(players_22_norm['short_name']))
Test_Set['Log Market Value'] = np.exp(Test_Set['Log Market Value'] )
Test_Set = Test_Set.rename(columns={'Log Market Value':'Market Value'})
Test_Set['Predicted Market Value'] = np.exp(predicted)
Test_Set = Test_Set.sort_values(by='Predicted Market Value',ascending=False)
#Test_Set['Market Value'] = Test_Set['Market Value'].apply(lambda x : "{:,}".format(int(x)))
#Test_Set['Predicted Market Value'] = Test_Set['Predicted Market Value'].apply(lambda x : "{:,}".format(int(x)))

# %%
Test_Set.dtypes
# Out:
# Market Value                float64
# overall                       int64
# age                           int64
# international_reputation      int64
# short_name                   object
# Predicted Market Value      float64
# dtype: object

# %%
Test_Set = Test_Set[['short_name', 'overall', 'age', 'international_reputation','Market Value', 'Predicted Market Value']] #
#Test_Set.reset_index(inplace=True)
#Test_Set.drop('index',axis=1,inplace=True)
Test_Set
# Out:
#               short_name  overall  age  international_reputation  \
# sofifa_id
# 231747         K. Mbappé       91   22                         4
# 239085        E. Haaland       88   20                         4
# 230621     G. Donnarumma       89   22                         3
# 190871         Neymar Jr       91   29                         5
# 200389          J. Oblak       91   28                         4
# ...                  ...      ...  ...                       ...
# 255618         Gao Xiang       49   32                         1
# 149697     M. McChrystal       52   37                         1
# 245558          G. Maley       52   38                         1
# 157190        J. Russell       49   36                         1
# 254704          K. Miura       59   54                         1
#
#            Market Value  Predicted Market Value
# sofifa_id
# 231747     1.552000e+08            2.848259e+08
# 239085     1.100000e+08            2.039879e+08
# 230621     9.560000e+07            1.579253e+08
# 190871     1.032000e+08            1.522182e+08
# 200389     8.960000e+07            1.392625e+08
# ...                 ...                     ...
# 255618     2.800100e+04            1.533223e+04
# 149697     1.200100e+04            1.496951e+04
# 245558     7.201000e+03            1.328669e+04
# 157190     1.200100e+04            9.515723e+03
# 254704     2.280362e+06            7.494253e+03
#
# [19239 rows x 6 columns]

# %%
Test_Set['Market Value'] = Test_Set['Market Value'].apply(lambda x : "{:,}".format(int(x)))
Test_Set['Predicted Market Value'] = Test_Set['Predicted Market Value'].apply(lambda x : "{:,}".format(int(x)))

# %%
Test_Set.head(20)
# Out:
#                     short_name  overall  age  international_reputation  \
# sofifa_id
# 231747               K. Mbappé       91   22                         4
# 239085              E. Haaland       88   20                         4
# 230621           G. Donnarumma       89   22                         3
# 190871               Neymar Jr       91   29                         5
# 200389                J. Oblak       91   28                         4
# 202126                 H. Kane       90   27                         4
# 188545          R. Lewandowski       92   32                         5
# 158023                L. Messi       93   34                         5
# 233049               J. Sancho       87   21                         3
# 212622              J. Kimmich       89   26                         4
# 192985            K. De Bruyne       91   30                         4
# 231281     T. Alexander-Arnold       87   22                         3
# 192448           M. ter Stegen       90   29                         4
# 202652             R. Sterling       88   26                         4
# 200104                  H. Son       89   28                         4
# 215914                N. Kanté       90   30                         4
# 210257                 Ederson       89   27                         3
# 239818              Rúben Dias       87   24                         3
# 228702              F. de Jong       87   24                         3
# 209331                M. Salah       89   29                         4
#
#           Market Value Predicted Market Value
# sofifa_id
# 231747     155,200,001            284,825,921
# 239085     110,000,001            203,987,947
# 230621      95,600,001            157,925,271
# 190871     103,200,000            152,218,203
# 200389      89,600,001            139,262,484
# 202126     103,600,000            129,650,074
# 188545      95,600,001            128,808,988
# 158023      62,400,000            122,805,168
# 233049      93,200,001            121,489,291
# 212622      86,400,001            120,701,147
# 192985     100,400,001            109,711,549
# 231281      91,200,001            107,831,861
# 192448      79,200,001            102,138,853
# 202652      86,000,001             99,737,651
# 200104      83,200,000             95,088,853
# 215914      80,000,000             90,656,737
# 210257      75,200,000             86,995,573
# 239818      82,000,001             84,950,377
# 228702      95,600,001             84,950,377
# 209331      80,800,000             84,399,274

# %%
Test_Set = Test_Set.rename(columns={'Market Value':'Market Value (Euros)','Predicted Market Value': 'Predicted Market Value (Euros)'})
Test_Set
# Out:
#               short_name  overall  age  international_reputation  \
# sofifa_id
# 231747         K. Mbappé       91   22                         4
# 239085        E. Haaland       88   20                         4
# 230621     G. Donnarumma       89   22                         3
# 190871         Neymar Jr       91   29                         5
# 200389          J. Oblak       91   28                         4
# ...                  ...      ...  ...                       ...
# 255618         Gao Xiang       49   32                         1
# 149697     M. McChrystal       52   37                         1
# 245558          G. Maley       52   38                         1
# 157190        J. Russell       49   36                         1
# 254704          K. Miura       59   54                         1
#
#           Market Value (Euros) Predicted Market Value (Euros)
# sofifa_id
# 231747             155,200,001                    284,825,921
# 239085             110,000,001                    203,987,947
# 230621              95,600,001                    157,925,271
# 190871             103,200,000                    152,218,203
# 200389              89,600,001                    139,262,484
# ...                        ...                            ...
# 255618                  28,001                         15,332
# 149697                  12,000                         14,969
# 245558                   7,201                         13,286
# 157190                  12,000                          9,515
# 254704               2,280,362                          7,494
#
# [19239 rows x 6 columns]

# %%
Test_Set.to_csv('prueba final_lr_entero.csv')
