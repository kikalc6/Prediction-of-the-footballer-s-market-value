# %%
# Data manipulation
import pandas as pd
import numpy as np

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sb
from pandas.plotting import scatter_matrix

# Machine Learning Algorithms
import sklearn
from sklearn.linear_model import LinearRegression, Lasso, LassoCV, Ridge, RidgeCV, ElasticNet, ElasticNetCV
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.pipeline import make_pipeline

# Model Selection and Evaluation
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold


# Performance
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error

#decision tree
import sklearn.tree as sktree

# For Missing Values
from sklearn.impute import SimpleImputer

import statsmodels.api as sm
import patsy
# Out:
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,

# %%
import seaborn as sns #visualisation
import scipy
from scipy import stats
from scipy.stats.mstats import winsorize

# %% [markdown]
# # Get the data

# %%
players_22 = pd.read_csv('./FIFA/players_22.csv', index_col='sofifa_id')
# Out:
# C:\Users\Kiko\AppData\Local\Temp/ipykernel_12192/1465523920.py:1: DtypeWarning: Columns (25,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   players_22 = pd.read_csv('./FIFA/players_22.csv', index_col='sofifa_id')

# %%
players_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19239 entries, 158023 to 264540
# Columns: 109 entries, player_url to nation_flag_url
# dtypes: float64(16), int64(43), object(50)
# memory usage: 16.1+ MB

# %% [markdown]
# # Structure of the file

# %%
players_22.sort_values(by='value_eur', ascending=False).head(20)
# Out:
#                                                   player_url  \
# sofifa_id
# 231747     https://sofifa.com/player/231747/kylian-mbappe...
# 239085     https://sofifa.com/player/239085/erling-haalan...
# 202126     https://sofifa.com/player/202126/harry-kane/22...
# 190871     https://sofifa.com/player/190871/neymar-da-sil...
# 192985     https://sofifa.com/player/192985/kevin-de-bruy...
# 188545     https://sofifa.com/player/188545/robert-lewand...
# 228702     https://sofifa.com/player/228702/frenkie-de-jo...
# 230621     https://sofifa.com/player/230621/gianluigi-don...
# 233049     https://sofifa.com/player/233049/jadon-sancho/...
# 231281     https://sofifa.com/player/231281/trent-alexand...
# 200389     https://sofifa.com/player/200389/jan-oblak/220002
# 212622     https://sofifa.com/player/212622/joshua-kimmic...
# 212198     https://sofifa.com/player/212198/bruno-miguel-...
# 202652     https://sofifa.com/player/202652/raheem-sterli...
# 200104     https://sofifa.com/player/200104/heung-min-son...
# 239818     https://sofifa.com/player/239818/ruben-santos-...
# 209331     https://sofifa.com/player/209331/mohamed-salah...
# 208722     https://sofifa.com/player/208722/sadio-mane/22...
# 215914     https://sofifa.com/player/215914/ngolo-kante/2...
# 192448     https://sofifa.com/player/192448/marc-andre-te...
#
#                     short_name                         long_name  \
# sofifa_id
# 231747               K. Mbappé              Kylian Mbappé Lottin
# 239085              E. Haaland              Erling Braut Haaland
# 202126                 H. Kane                        Harry Kane
# 190871               Neymar Jr     Neymar da Silva Santos Júnior
# 192985            K. De Bruyne                   Kevin De Bruyne
# 188545          R. Lewandowski                Robert Lewandowski
# 228702              F. de Jong                   Frenkie de Jong
# 230621           G. Donnarumma              Gianluigi Donnarumma
# 233049               J. Sancho                      Jadon Sancho
# 231281     T. Alexander-Arnold            Trent Alexander-Arnold
# 200389                J. Oblak                         Jan Oblak
# 212622              J. Kimmich             Joshua Walter Kimmich
# 212198         Bruno Fernandes     Bruno Miguel Borges Fernandes
# 202652             R. Sterling                   Raheem Sterling
# 200104                  H. Son                           손흥민 孙兴慜
# 239818              Rúben Dias  Rúben dos Santos Gato Alves Dias
# 209331                M. Salah               Mohamed Salah Ghaly
# 208722                 S. Mané                        Sadio Mané
# 215914                N. Kanté                      N'Golo Kanté
# 192448           M. ter Stegen             Marc-André ter Stegen
#
#           player_positions  overall  potential    value_eur  wage_eur  age  \
# sofifa_id
# 231747              ST, LW       91         95  194000000.0  230000.0   22
# 239085                  ST       88         93  137500000.0  110000.0   20
# 202126                  ST       90         90  129500000.0  240000.0   27
# 190871             LW, CAM       91         91  129000000.0  270000.0   29
# 192985             CM, CAM       91         91  125500000.0  350000.0   30
# 188545                  ST       92         92  119500000.0  270000.0   32
# 228702         CM, CDM, CB       87         92  119500000.0  210000.0   24
# 230621                  GK       89         93  119500000.0  110000.0   22
# 233049          RM, CF, LM       87         91  116500000.0  150000.0   21
# 231281                  RB       87         92  114000000.0  150000.0   22
# 200389                  GK       91         93  112000000.0  130000.0   28
# 212622             CDM, RB       89         90  108000000.0  160000.0   26
# 212198                 CAM       88         89  107500000.0  250000.0   26
# 202652              LW, RW       88         89  107500000.0  290000.0   26
# 200104          LM, CF, LW       89         89  104000000.0  220000.0   28
# 239818                  CB       87         91  102500000.0  170000.0   24
# 209331                  RW       89         89  101000000.0  270000.0   29
# 208722                  LW       89         89  101000000.0  270000.0   29
# 215914             CDM, CM       90         90  100000000.0  230000.0   30
# 192448                  GK       90         92   99000000.0  250000.0   29
#
#                   dob  ...   lcb    cb   rcb    rb    gk  \
# sofifa_id              ...
# 231747     1998-12-20  ...  54+3  54+3  54+3  63+3  18+3
# 239085     2000-07-21  ...  60+3  60+3  60+3  60+3  19+3
# 202126     1993-07-28  ...  61+3  61+3  61+3  64+3  20+3
# 190871     1992-02-05  ...  50+3  50+3  50+3  62+3  20+3
# 192985     1991-06-28  ...  69+3  69+3  69+3  75+3  21+3
# 188545     1988-08-21  ...  60+3  60+3  60+3  61+3  19+3
# 228702     1997-05-12  ...  78+3  78+3  78+3  82+3  18+3
# 230621     1999-02-25  ...  31+3  31+3  31+3  31+3  87+3
# 233049     2000-03-25  ...  48+3  48+3  48+3  60+3  19+3
# 231281     1998-10-07  ...  78+3  78+3  78+3  83+3  19+3
# 200389     1993-01-07  ...  33+3  33+3  33+3  32+3  89+3
# 212622     1995-02-08  ...  81+3  81+3  81+3  83+3  21+3
# 212198     1994-09-08  ...  73+3  73+3  73+3  77+3  21+3
# 202652     1994-12-08  ...  55+3  55+3  55+3  65+3  21+3
# 200104     1992-07-08  ...  54+3  54+3  54+3  64+3  19+3
# 239818     1997-05-14  ...  86+3  86+3  86+3  80+3  17+3
# 209331     1992-06-15  ...  58+3  58+3  58+3  67+3  22+3
# 208722     1992-04-10  ...  59+3  59+3  59+3  65+3  19+3
# 215914     1991-03-29  ...  84+3  84+3  84+3  85+3  20+3
# 192448     1992-04-30  ...  33+3  33+3  33+3  31+3  88+3
#
#                                              player_face_url  \
# sofifa_id
# 231747     https://cdn.sofifa.net/players/231/747/22_120.png
# 239085     https://cdn.sofifa.net/players/239/085/22_120.png
# 202126     https://cdn.sofifa.net/players/202/126/22_120.png
# 190871     https://cdn.sofifa.net/players/190/871/22_120.png
# 192985     https://cdn.sofifa.net/players/192/985/22_120.png
# 188545     https://cdn.sofifa.net/players/188/545/22_120.png
# 228702     https://cdn.sofifa.net/players/228/702/22_120.png
# 230621     https://cdn.sofifa.net/players/230/621/22_120.png
# 233049     https://cdn.sofifa.net/players/233/049/22_120.png
# 231281     https://cdn.sofifa.net/players/231/281/22_120.png
# 200389     https://cdn.sofifa.net/players/200/389/22_120.png
# 212622     https://cdn.sofifa.net/players/212/622/22_120.png
# 212198     https://cdn.sofifa.net/players/212/198/22_120.png
# 202652     https://cdn.sofifa.net/players/202/652/22_120.png
# 200104     https://cdn.sofifa.net/players/200/104/22_120.png
# 239818     https://cdn.sofifa.net/players/239/818/22_120.png
# 209331     https://cdn.sofifa.net/players/209/331/22_120.png
# 208722     https://cdn.sofifa.net/players/208/722/22_120.png
# 215914     https://cdn.sofifa.net/players/215/914/22_120.png
# 192448     https://cdn.sofifa.net/players/192/448/22_120.png
#
#                                      club_logo_url  \
# sofifa_id
# 231747      https://cdn.sofifa.net/teams/73/60.png
# 239085      https://cdn.sofifa.net/teams/22/60.png
# 202126      https://cdn.sofifa.net/teams/18/60.png
# 190871      https://cdn.sofifa.net/teams/73/60.png
# 192985      https://cdn.sofifa.net/teams/10/60.png
# 188545      https://cdn.sofifa.net/teams/21/60.png
# 228702     https://cdn.sofifa.net/teams/241/60.png
# 230621      https://cdn.sofifa.net/teams/73/60.png
# 233049      https://cdn.sofifa.net/teams/11/60.png
# 231281       https://cdn.sofifa.net/teams/9/60.png
# 200389     https://cdn.sofifa.net/teams/240/60.png
# 212622      https://cdn.sofifa.net/teams/21/60.png
# 212198      https://cdn.sofifa.net/teams/11/60.png
# 202652      https://cdn.sofifa.net/teams/10/60.png
# 200104      https://cdn.sofifa.net/teams/18/60.png
# 239818      https://cdn.sofifa.net/teams/10/60.png
# 209331       https://cdn.sofifa.net/teams/9/60.png
# 208722       https://cdn.sofifa.net/teams/9/60.png
# 215914       https://cdn.sofifa.net/teams/5/60.png
# 192448     https://cdn.sofifa.net/teams/241/60.png
#
#                                      club_flag_url  \
# sofifa_id
# 231747         https://cdn.sofifa.net/flags/fr.png
# 239085         https://cdn.sofifa.net/flags/de.png
# 202126     https://cdn.sofifa.net/flags/gb-eng.png
# 190871         https://cdn.sofifa.net/flags/fr.png
# 192985     https://cdn.sofifa.net/flags/gb-eng.png
# 188545         https://cdn.sofifa.net/flags/de.png
# 228702         https://cdn.sofifa.net/flags/es.png
# 230621         https://cdn.sofifa.net/flags/fr.png
# 233049     https://cdn.sofifa.net/flags/gb-eng.png
# 231281     https://cdn.sofifa.net/flags/gb-eng.png
# 200389         https://cdn.sofifa.net/flags/es.png
# 212622         https://cdn.sofifa.net/flags/de.png
# 212198     https://cdn.sofifa.net/flags/gb-eng.png
# 202652     https://cdn.sofifa.net/flags/gb-eng.png
# 200104     https://cdn.sofifa.net/flags/gb-eng.png
# 239818     https://cdn.sofifa.net/flags/gb-eng.png
# 209331     https://cdn.sofifa.net/flags/gb-eng.png
# 208722     https://cdn.sofifa.net/flags/gb-eng.png
# 215914     https://cdn.sofifa.net/flags/gb-eng.png
# 192448         https://cdn.sofifa.net/flags/es.png
#
#                                       nation_logo_url  \
# sofifa_id
# 231747       https://cdn.sofifa.net/teams/1335/60.png
# 239085       https://cdn.sofifa.net/teams/1352/60.png
# 202126       https://cdn.sofifa.net/teams/1318/60.png
# 190871                                            NaN
# 192985       https://cdn.sofifa.net/teams/1325/60.png
# 188545       https://cdn.sofifa.net/teams/1353/60.png
# 228702     https://cdn.sofifa.net/teams/105035/60.png
# 230621       https://cdn.sofifa.net/teams/1343/60.png
# 233049       https://cdn.sofifa.net/teams/1318/60.png
# 231281       https://cdn.sofifa.net/teams/1318/60.png
# 200389                                            NaN
# 212622       https://cdn.sofifa.net/teams/1337/60.png
# 212198       https://cdn.sofifa.net/teams/1354/60.png
# 202652       https://cdn.sofifa.net/teams/1318/60.png
# 200104                                            NaN
# 239818       https://cdn.sofifa.net/teams/1354/60.png
# 209331                                            NaN
# 208722                                            NaN
# 215914       https://cdn.sofifa.net/teams/1335/60.png
# 192448                                            NaN
#
#                                    nation_flag_url
# sofifa_id
# 231747         https://cdn.sofifa.net/flags/fr.png
# 239085         https://cdn.sofifa.net/flags/no.png
# 202126     https://cdn.sofifa.net/flags/gb-eng.png
# 190871         https://cdn.sofifa.net/flags/br.png
# 192985         https://cdn.sofifa.net/flags/be.png
# 188545         https://cdn.sofifa.net/flags/pl.png
# 228702         https://cdn.sofifa.net/flags/nl.png
# 230621         https://cdn.sofifa.net/flags/it.png
# 233049     https://cdn.sofifa.net/flags/gb-eng.png
# 231281     https://cdn.sofifa.net/flags/gb-eng.png
# 200389         https://cdn.sofifa.net/flags/si.png
# 212622         https://cdn.sofifa.net/flags/de.png
# 212198         https://cdn.sofifa.net/flags/pt.png
# 202652     https://cdn.sofifa.net/flags/gb-eng.png
# 200104         https://cdn.sofifa.net/flags/kr.png
# 239818         https://cdn.sofifa.net/flags/pt.png
# 209331         https://cdn.sofifa.net/flags/eg.png
# 208722         https://cdn.sofifa.net/flags/sn.png
# 215914         https://cdn.sofifa.net/flags/fr.png
# 192448         https://cdn.sofifa.net/flags/de.png
#
# [20 rows x 109 columns]

# %%
players_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19239 entries, 158023 to 264540
# Columns: 109 entries, player_url to nation_flag_url
# dtypes: float64(16), int64(43), object(50)
# memory usage: 16.1+ MB

# %%
players_22.shape
# Out:
# (19239, 109)

# %% [markdown]
# # Data Cleaning

# %%
players_22.columns
# Out:
# Index(['player_url', 'short_name', 'long_name', 'player_positions', 'overall',
#        'potential', 'value_eur', 'wage_eur', 'age', 'dob',
#        ...
#        'lcb', 'cb', 'rcb', 'rb', 'gk', 'player_face_url', 'club_logo_url',
#        'club_flag_url', 'nation_logo_url', 'nation_flag_url'],
#       dtype='object', length=109)

# %%
players_22.head()
# Out:
#                                                   player_url  \
# sofifa_id
# 158023     https://sofifa.com/player/158023/lionel-messi/...
# 188545     https://sofifa.com/player/188545/robert-lewand...
# 20801      https://sofifa.com/player/20801/c-ronaldo-dos-...
# 190871     https://sofifa.com/player/190871/neymar-da-sil...
# 192985     https://sofifa.com/player/192985/kevin-de-bruy...
#
#                   short_name                            long_name  \
# sofifa_id
# 158023              L. Messi       Lionel Andrés Messi Cuccittini
# 188545        R. Lewandowski                   Robert Lewandowski
# 20801      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 190871             Neymar Jr        Neymar da Silva Santos Júnior
# 192985          K. De Bruyne                      Kevin De Bruyne
#
#           player_positions  overall  potential    value_eur  wage_eur  age  \
# sofifa_id
# 158023          RW, ST, CF       93         93   78000000.0  320000.0   34
# 188545                  ST       92         92  119500000.0  270000.0   32
# 20801               ST, LW       91         91   45000000.0  270000.0   36
# 190871             LW, CAM       91         91  129000000.0  270000.0   29
# 192985             CM, CAM       91         91  125500000.0  350000.0   30
#
#                   dob  ...   lcb    cb   rcb    rb    gk  \
# sofifa_id              ...
# 158023     1987-06-24  ...  50+3  50+3  50+3  61+3  19+3
# 188545     1988-08-21  ...  60+3  60+3  60+3  61+3  19+3
# 20801      1985-02-05  ...  53+3  53+3  53+3  60+3  20+3
# 190871     1992-02-05  ...  50+3  50+3  50+3  62+3  20+3
# 192985     1991-06-28  ...  69+3  69+3  69+3  75+3  21+3
#
#                                              player_face_url  \
# sofifa_id
# 158023     https://cdn.sofifa.net/players/158/023/22_120.png
# 188545     https://cdn.sofifa.net/players/188/545/22_120.png
# 20801      https://cdn.sofifa.net/players/020/801/22_120.png
# 190871     https://cdn.sofifa.net/players/190/871/22_120.png
# 192985     https://cdn.sofifa.net/players/192/985/22_120.png
#
#                                     club_logo_url  \
# sofifa_id
# 158023     https://cdn.sofifa.net/teams/73/60.png
# 188545     https://cdn.sofifa.net/teams/21/60.png
# 20801      https://cdn.sofifa.net/teams/11/60.png
# 190871     https://cdn.sofifa.net/teams/73/60.png
# 192985     https://cdn.sofifa.net/teams/10/60.png
#
#                                      club_flag_url  \
# sofifa_id
# 158023         https://cdn.sofifa.net/flags/fr.png
# 188545         https://cdn.sofifa.net/flags/de.png
# 20801      https://cdn.sofifa.net/flags/gb-eng.png
# 190871         https://cdn.sofifa.net/flags/fr.png
# 192985     https://cdn.sofifa.net/flags/gb-eng.png
#
#                                     nation_logo_url  \
# sofifa_id
# 158023     https://cdn.sofifa.net/teams/1369/60.png
# 188545     https://cdn.sofifa.net/teams/1353/60.png
# 20801      https://cdn.sofifa.net/teams/1354/60.png
# 190871                                          NaN
# 192985     https://cdn.sofifa.net/teams/1325/60.png
#
#                                nation_flag_url
# sofifa_id
# 158023     https://cdn.sofifa.net/flags/ar.png
# 188545     https://cdn.sofifa.net/flags/pl.png
# 20801      https://cdn.sofifa.net/flags/pt.png
# 190871     https://cdn.sofifa.net/flags/br.png
# 192985     https://cdn.sofifa.net/flags/be.png
#
# [5 rows x 109 columns]

# %%
#Keep only the target column and the columns which are not calculated using our target , or they can be calculated using the target and Item since we only have one item now
players_22 = players_22.drop(columns = ['player_url','long_name','club_loaned_from','club_contract_valid_until','club_joined','nation_team_id','nation_position','club_position','work_rate','body_type','real_face','player_tags','player_traits','player_face_url','club_logo_url','club_flag_url','nation_logo_url','nation_flag_url',
                                       'ls','st','rs','lw','lf','cf','rf','rw','lam','cam','ram','lm','lcm','cm','rcm','rm','lwb','ldm','cdm','rdm','rwb','lb','lcb','cb','rcb','rb','gk',
                                        'player_positions', 'dob', 'weak_foot', 'club_team_id',
                                        'club_name', 
                                        'league_name','league_level', 'club_jersey_number', 'nationality_id', 'nationality_name', 'nation_jersey_number',
                                        'wage_eur','height_cm','weight_kg','release_clause_eur',
                                        'pace','shooting','passing','dribbling','defending',
                                        'physic','attacking_short_passing','skill_curve',
                                        'mentality_interceptions','defending_standing_tackle',
                                        'goalkeeping_reflexes','goalkeeping_speed'])
                                        #'skill_moves', 'release_clause_eur', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy',
                                        #'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
                                        #'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
                                        #'movement_reactions', 'movement_balance', 'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots', 'attacking_short_passing',
                                        #'defending_marking_awareness','defending_sliding_tackle','defending_standing_tackle',
                                        #'defending'])
players_22
# Out:
#                    short_name  overall  potential    value_eur  age  \
# sofifa_id
# 158023               L. Messi       93         93   78000000.0   34
# 188545         R. Lewandowski       92         92  119500000.0   32
# 20801       Cristiano Ronaldo       91         91   45000000.0   36
# 190871              Neymar Jr       91         91  129000000.0   29
# 192985           K. De Bruyne       91         91  125500000.0   30
# ...                       ...      ...        ...          ...  ...
# 261962              Song Defu       47         52      70000.0   22
# 262040              C. Porter       47         59     110000.0   19
# 262760               N. Logue       47         55     100000.0   21
# 262820              L. Rudden       47         60     110000.0   19
# 264540     E. Lalchhanchhuaha       47         60     110000.0   19
#
#           preferred_foot  skill_moves  international_reputation  \
# sofifa_id
# 158023              Left            4                         5
# 188545             Right            4                         5
# 20801              Right            5                         5
# 190871             Right            5                         5
# 192985             Right            4                         4
# ...                  ...          ...                       ...
# 261962             Right            2                         1
# 262040             Right            2                         1
# 262760             Right            2                         1
# 262820             Right            2                         1
# 264540             Right            2                         1
#
#            attacking_crossing  attacking_finishing  ...  \
# sofifa_id                                           ...
# 158023                     85                   95  ...
# 188545                     71                   95  ...
# 20801                      87                   95  ...
# 190871                     85                   83  ...
# 192985                     94                   82  ...
# ...                       ...                  ...  ...
# 261962                     46                   32  ...
# 262040                     54                   33  ...
# 262760                     39                   32  ...
# 262820                     29                   49  ...
# 264540                     39                   32  ...
#
#            mentality_positioning  mentality_vision  mentality_penalties  \
# sofifa_id
# 158023                        93                95                   75
# 188545                        95                81                   90
# 20801                         95                76                   88
# 190871                        86                90                   93
# 192985                        88                94                   83
# ...                          ...               ...                  ...
# 261962                        38                43                   42
# 262040                        51                49                   44
# 262760                        45                46                   39
# 262820                        47                40                   49
# 264540                        47                46                   35
#
#            mentality_composure  defending_marking_awareness  \
# sofifa_id
# 158023                      96                           20
# 188545                      88                           35
# 20801                       95                           24
# 190871                      93                           35
# 192985                      89                           68
# ...                        ...                          ...
# 261962                      37                           38
# 262040                      47                           37
# 262760                      36                           38
# 262820                      47                           10
# 264540                      36                           33
#
#            defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# sofifa_id
# 158023                           24                   6                    11
# 188545                           19                  15                     6
# 20801                            24                   7                    11
# 190871                           29                   9                     9
# 192985                           53                  15                    13
# ...                             ...                 ...                   ...
# 261962                           48                   6                    10
# 262040                           47                  11                    12
# 262760                           48                   8                     6
# 262820                           11                   7                    10
# 264540                           37                   8                    13
#
#            goalkeeping_kicking  goalkeeping_positioning
# sofifa_id
# 158023                      15                       14
# 188545                      12                        8
# 20801                       15                       14
# 190871                      15                       15
# 192985                       5                       10
# ...                        ...                      ...
# 261962                       5                       15
# 262040                       6                        8
# 262760                       7                       10
# 262820                       7                       14
# 264540                      13                        9
#
# [19239 rows x 37 columns]

# %%
players_22.describe()
# Out:
#             overall     potential     value_eur           age   skill_moves  \
# count  19239.000000  19239.000000  1.916500e+04  19239.000000  19239.000000
# mean      65.772182     71.079370  2.850452e+06     25.210822      2.352461
# std        6.880232      6.086213  7.613700e+06      4.748235      0.767659
# min       47.000000     49.000000  9.000000e+03     16.000000      1.000000
# 25%       61.000000     67.000000  4.750000e+05     21.000000      2.000000
# 50%       66.000000     71.000000  9.750000e+05     25.000000      2.000000
# 75%       70.000000     75.000000  2.000000e+06     29.000000      3.000000
# max       93.000000     95.000000  1.940000e+08     54.000000      5.000000
#
#        international_reputation  attacking_crossing  attacking_finishing  \
# count              19239.000000        19239.000000         19239.000000
# mean                   1.094496           49.577421            45.894433
# std                    0.371998           18.034661            19.721023
# min                    1.000000            6.000000             2.000000
# 25%                    1.000000           38.000000            30.000000
# 50%                    1.000000           54.000000            50.000000
# 75%                    1.000000           63.000000            62.000000
# max                    5.000000           94.000000            95.000000
#
#        attacking_heading_accuracy  attacking_volleys  ...  \
# count                19239.000000       19239.000000  ...
# mean                    51.783877          42.463849  ...
# std                     17.294183          17.653329  ...
# min                      5.000000           3.000000  ...
# 25%                     44.000000          30.000000  ...
# 50%                     55.000000          43.000000  ...
# 75%                     64.000000          56.000000  ...
# max                     93.000000          90.000000  ...
#
#        mentality_positioning  mentality_vision  mentality_penalties  \
# count           19239.000000      19239.000000         19239.000000
# mean               50.330215         53.964603            47.858724
# std                19.621601         13.650481            15.768583
# min                 2.000000         10.000000             7.000000
# 25%                40.000000         45.000000            38.000000
# 50%                56.000000         55.000000            49.000000
# 75%                64.000000         64.000000            60.000000
# max                96.000000         95.000000            93.000000
#
#        mentality_composure  defending_marking_awareness  \
# count         19239.000000                 19239.000000
# mean             57.929830                    46.601746
# std              12.159326                    20.200807
# min              12.000000                     4.000000
# 25%              50.000000                    29.000000
# 50%              59.000000                    52.000000
# 75%              66.000000                    63.000000
# max              96.000000                    93.000000
#
#        defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# count              19239.000000        19239.000000          19239.000000
# mean                  45.906700           16.406102             16.192474
# std                   20.755683           17.574028             16.839528
# min                    5.000000            2.000000              2.000000
# 25%                   25.000000            8.000000              8.000000
# 50%                   53.000000           11.000000             11.000000
# 75%                   63.000000           14.000000             14.000000
# max                   92.000000           91.000000             92.000000
#
#        goalkeeping_kicking  goalkeeping_positioning
# count         19239.000000             19239.000000
# mean             16.055356                16.229274
# std              16.564554                17.059779
# min               2.000000                 2.000000
# 25%               8.000000                 8.000000
# 50%              11.000000                11.000000
# 75%              14.000000                14.000000
# max              93.000000                92.000000
#
# [8 rows x 35 columns]

# %%
players_22.dtypes
# Out:
# short_name                      object
# overall                          int64
# potential                        int64
# value_eur                      float64
# age                              int64
# preferred_foot                  object
# skill_moves                      int64
# international_reputation         int64
# attacking_crossing               int64
# attacking_finishing              int64
# attacking_heading_accuracy       int64
# attacking_volleys                int64
# skill_dribbling                  int64
# skill_fk_accuracy                int64
# skill_long_passing               int64
# skill_ball_control               int64
# movement_acceleration            int64
# movement_sprint_speed            int64
# movement_agility                 int64
# movement_reactions               int64
# movement_balance                 int64
# power_shot_power                 int64
# power_jumping                    int64
# power_stamina                    int64
# power_strength                   int64
# power_long_shots                 int64
# mentality_aggression             int64
# mentality_positioning            int64
# mentality_vision                 int64
# mentality_penalties              int64
# mentality_composure              int64
# defending_marking_awareness      int64
# defending_sliding_tackle         int64
# goalkeeping_diving               int64
# goalkeeping_handling             int64
# goalkeeping_kicking              int64
# goalkeeping_positioning          int64
# dtype: object

# %%
players_22 = pd.get_dummies(players_22,columns=['preferred_foot'],drop_first=True)

# %%
players_22['value_eur'] = players_22['value_eur']*0.8
players_22['value_eur'] = players_22['value_eur'].fillna(players_22['value_eur'].mean()).astype('float64')

# %%
players_22['value_eur'] = players_22['value_eur'].astype('float64')
players_22['skill_moves'] = players_22['skill_moves'].astype('float64')
players_22['attacking_crossing'] = players_22['attacking_crossing'].astype('float64')
players_22['attacking_finishing'] = players_22['attacking_finishing'].astype('float64')
players_22['attacking_heading_accuracy'] = players_22['attacking_heading_accuracy'].astype('float64')
players_22['attacking_volleys'] = players_22['attacking_volleys'].astype('float64')
players_22['skill_dribbling'] = players_22['skill_dribbling'].astype('float64')
players_22['skill_fk_accuracy'] = players_22['skill_fk_accuracy'].astype('float64')
players_22['skill_long_passing'] = players_22['skill_long_passing'].astype('float64')
players_22['skill_ball_control'] = players_22['skill_ball_control'].astype('float64')
players_22['movement_acceleration'] = players_22['movement_acceleration'].astype('float64')
players_22['movement_sprint_speed'] = players_22['movement_sprint_speed'].astype('float64')
players_22['movement_agility'] = players_22['movement_agility'].astype('float64')
players_22['movement_reactions'] = players_22['movement_reactions'].astype('float64')
players_22['movement_balance'] = players_22['movement_balance'].astype('float64')
players_22['power_shot_power'] = players_22['power_shot_power'].astype('float64')
players_22['power_jumping'] = players_22['power_jumping'].astype('float64')
players_22['power_stamina'] = players_22['power_stamina'].astype('float64')
players_22['power_strength'] = players_22['power_strength'].astype('float64')
players_22['power_long_shots'] = players_22['power_long_shots'].astype('float64')
players_22['mentality_aggression'] = players_22['mentality_aggression'].astype('float64')
players_22['mentality_positioning'] = players_22['mentality_positioning'].astype('float64')
players_22['mentality_vision'] = players_22['mentality_vision'].astype('float64')
players_22['mentality_penalties'] = players_22['mentality_penalties'].astype('float64')
players_22['mentality_composure'] = players_22['mentality_composure'].astype('float64')
players_22['defending_marking_awareness'] = players_22['defending_marking_awareness'].astype('float64')
players_22['defending_sliding_tackle'] = players_22['defending_sliding_tackle'].astype('float64')
players_22['goalkeeping_diving'] = players_22['goalkeeping_diving'].astype('float64')
players_22['goalkeeping_handling'] = players_22['goalkeeping_handling'].astype('float64')
players_22['goalkeeping_kicking'] = players_22['goalkeeping_kicking'].astype('float64')
players_22['goalkeeping_positioning'] = players_22['goalkeeping_positioning'].astype('float64')

# %%
x = players_22['age']
plt.figure(figsize=(10,8))
ax = sns.countplot(x,color='#00ffff')
ax.set_xlabel(xlabel = 'Age of the Players', fontsize = 16)
ax.set_title(label = 'Distribution of Age of the Players', fontsize = 20)
plt.show()
# Out:
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#players_22.set_index('sofifa_id', inplace = True)

# %%
players_show = players_22.copy()
players_show['value_eur'] = players_show['value_eur'].apply(lambda x : "{:,}".format(int(x)))

# %%
players_show.columns
# Out:
# Index(['short_name', 'overall', 'potential', 'value_eur', 'age', 'skill_moves',
#        'international_reputation', 'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_volleys', 'skill_dribbling',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
#        'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
#        'movement_reactions', 'movement_balance', 'power_shot_power',
#        'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
#        'mentality_aggression', 'mentality_positioning', 'mentality_vision',
#        'mentality_penalties', 'mentality_composure',
#        'defending_marking_awareness', 'defending_sliding_tackle',
#        'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking',
#        'goalkeeping_positioning', 'preferred_foot_Right'],
#       dtype='object')

# %%
players_show [['skill_moves',
       'attacking_crossing', 'attacking_finishing',
       'attacking_heading_accuracy', 'attacking_volleys', 'skill_dribbling',
       'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
       'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
       'movement_reactions', 'movement_balance', 'power_shot_power',
       'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
       'mentality_aggression', 'mentality_positioning', 'mentality_vision',
       'mentality_penalties', 'mentality_composure',
       'defending_marking_awareness', 'defending_sliding_tackle',
       'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking',
       'goalkeeping_positioning', 'preferred_foot_Right']] = players_show[['skill_moves',
       'attacking_crossing', 'attacking_finishing',
       'attacking_heading_accuracy', 'attacking_volleys', 'skill_dribbling',
       'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
       'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
       'movement_reactions', 'movement_balance', 'power_shot_power',
       'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
       'mentality_aggression', 'mentality_positioning', 'mentality_vision',
       'mentality_penalties', 'mentality_composure',
       'defending_marking_awareness', 'defending_sliding_tackle',
       'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking',
       'goalkeeping_positioning', 'preferred_foot_Right']].apply(lambda x: round(x,1))
players_show = players_show.rename(columns={'value_eur':'Market Value (Euros)'})
players_show
# Out:
#                    short_name  overall  potential Market Value (Euros)  age  \
# sofifa_id
# 158023               L. Messi       93         93           62,400,000   34
# 188545         R. Lewandowski       92         92           95,600,000   32
# 20801       Cristiano Ronaldo       91         91           36,000,000   36
# 190871              Neymar Jr       91         91          103,200,000   29
# 192985           K. De Bruyne       91         91          100,400,000   30
# ...                       ...      ...        ...                  ...  ...
# 261962              Song Defu       47         52               56,000   22
# 262040              C. Porter       47         59               88,000   19
# 262760               N. Logue       47         55               80,000   21
# 262820              L. Rudden       47         60               88,000   19
# 264540     E. Lalchhanchhuaha       47         60               88,000   19
#
#            skill_moves  international_reputation  attacking_crossing  \
# sofifa_id
# 158023             4.0                         5                85.0
# 188545             4.0                         5                71.0
# 20801              5.0                         5                87.0
# 190871             5.0                         5                85.0
# 192985             4.0                         4                94.0
# ...                ...                       ...                 ...
# 261962             2.0                         1                46.0
# 262040             2.0                         1                54.0
# 262760             2.0                         1                39.0
# 262820             2.0                         1                29.0
# 264540             2.0                         1                39.0
#
#            attacking_finishing  attacking_heading_accuracy  ...  \
# sofifa_id                                                   ...
# 158023                    95.0                        70.0  ...
# 188545                    95.0                        90.0  ...
# 20801                     95.0                        90.0  ...
# 190871                    83.0                        63.0  ...
# 192985                    82.0                        55.0  ...
# ...                        ...                         ...  ...
# 261962                    32.0                        48.0  ...
# 262040                    33.0                        46.0  ...
# 262760                    32.0                        43.0  ...
# 262820                    49.0                        40.0  ...
# 264540                    32.0                        46.0  ...
#
#            mentality_vision  mentality_penalties  mentality_composure  \
# sofifa_id
# 158023                 95.0                 75.0                 96.0
# 188545                 81.0                 90.0                 88.0
# 20801                  76.0                 88.0                 95.0
# 190871                 90.0                 93.0                 93.0
# 192985                 94.0                 83.0                 89.0
# ...                     ...                  ...                  ...
# 261962                 43.0                 42.0                 37.0
# 262040                 49.0                 44.0                 47.0
# 262760                 46.0                 39.0                 36.0
# 262820                 40.0                 49.0                 47.0
# 264540                 46.0                 35.0                 36.0
#
#            defending_marking_awareness  defending_sliding_tackle  \
# sofifa_id
# 158023                            20.0                      24.0
# 188545                            35.0                      19.0
# 20801                             24.0                      24.0
# 190871                            35.0                      29.0
# 192985                            68.0                      53.0
# ...                                ...                       ...
# 261962                            38.0                      48.0
# 262040                            37.0                      47.0
# 262760                            38.0                      48.0
# 262820                            10.0                      11.0
# 264540                            33.0                      37.0
#
#            goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# sofifa_id
# 158023                    6.0                  11.0                 15.0
# 188545                   15.0                   6.0                 12.0
# 20801                     7.0                  11.0                 15.0
# 190871                    9.0                   9.0                 15.0
# 192985                   15.0                  13.0                  5.0
# ...                       ...                   ...                  ...
# 261962                    6.0                  10.0                  5.0
# 262040                   11.0                  12.0                  6.0
# 262760                    8.0                   6.0                  7.0
# 262820                    7.0                  10.0                  7.0
# 264540                    8.0                  13.0                 13.0
#
#            goalkeeping_positioning  preferred_foot_Right
# sofifa_id
# 158023                        14.0                     0
# 188545                         8.0                     1
# 20801                         14.0                     1
# 190871                        15.0                     1
# 192985                        10.0                     1
# ...                            ...                   ...
# 261962                        15.0                     1
# 262040                         8.0                     1
# 262760                        10.0                     1
# 262820                        14.0                     1
# 264540                         9.0                     1
#
# [19239 rows x 37 columns]

# %%
players_22.dtypes
# Out:
# short_name                      object
# overall                          int64
# potential                        int64
# value_eur                      float64
# age                              int64
# skill_moves                    float64
# international_reputation         int64
# attacking_crossing             float64
# attacking_finishing            float64
# attacking_heading_accuracy     float64
# attacking_volleys              float64
# skill_dribbling                float64
# skill_fk_accuracy              float64
# skill_long_passing             float64
# skill_ball_control             float64
# movement_acceleration          float64
# movement_sprint_speed          float64
# movement_agility               float64
# movement_reactions             float64
# movement_balance               float64
# power_shot_power               float64
# power_jumping                  float64
# power_stamina                  float64
# power_strength                 float64
# power_long_shots               float64
# mentality_aggression           float64
# mentality_positioning          float64
# mentality_vision               float64
# mentality_penalties            float64
# mentality_composure            float64
# defending_marking_awareness    float64
# defending_sliding_tackle       float64
# goalkeeping_diving             float64
# goalkeeping_handling           float64
# goalkeeping_kicking            float64
# goalkeeping_positioning        float64
# preferred_foot_Right             uint8
# dtype: object

# %%
corr_matrix = players_22.corr()
corr_matrix
# Out:
#                               overall  potential  value_eur       age  \
# overall                      1.000000   0.644275   0.553823  0.459451
# potential                    0.644275   1.000000   0.526853 -0.264142
# value_eur                    0.553823   0.526853   1.000000  0.042617
# age                          0.459451  -0.264142   0.042617  1.000000
# skill_moves                  0.376226   0.283746   0.256689  0.074076
# international_reputation     0.470815   0.358773   0.632008  0.230269
# attacking_crossing           0.401356   0.243757   0.226934  0.132175
# attacking_finishing          0.338746   0.230814   0.217244  0.088754
# attacking_heading_accuracy   0.343901   0.192825   0.165578  0.154516
# attacking_volleys            0.380942   0.235766   0.237853  0.148109
# skill_dribbling              0.384351   0.311396   0.240459  0.030402
# skill_fk_accuracy            0.381030   0.207769   0.214177  0.191301
# skill_long_passing           0.498216   0.324791   0.278150  0.191542
# skill_ball_control           0.460411   0.347172   0.269295  0.092112
# movement_acceleration        0.194044   0.232621   0.157269 -0.147650
# movement_sprint_speed        0.205736   0.235577   0.164218 -0.139581
# movement_agility             0.270279   0.223385   0.176192 -0.010749
# movement_reactions           0.871823   0.522483   0.491689  0.453298
# movement_balance             0.123700   0.136890   0.117698 -0.066938
# power_shot_power             0.561180   0.332292   0.301176  0.279673
# power_jumping                0.284689   0.096992   0.118007  0.219382
# power_stamina                0.385150   0.199743   0.198277  0.131455
# power_strength               0.364366   0.073567   0.128450  0.348811
# power_long_shots             0.410010   0.243294   0.231083  0.164977
# mentality_aggression         0.400161   0.191501   0.182830  0.241968
# mentality_positioning        0.358562   0.233070   0.223637  0.101573
# mentality_vision             0.523025   0.345298   0.323736  0.209636
# mentality_penalties          0.343690   0.208062   0.195743  0.151951
# mentality_composure          0.708867   0.426790   0.388250  0.359076
# defending_marking_awareness  0.312093   0.161288   0.140712  0.163583
# defending_sliding_tackle     0.233589   0.140869   0.103281  0.089482
# goalkeeping_diving          -0.010990  -0.043093  -0.022038  0.109490
# goalkeeping_handling        -0.011080  -0.044989  -0.022424  0.112420
# goalkeeping_kicking         -0.012986  -0.047030  -0.021551  0.112025
# goalkeeping_positioning     -0.002485  -0.040184  -0.021243  0.120686
# preferred_foot_Right        -0.048961  -0.042915  -0.019993  0.003021
#
#                              skill_moves  international_reputation  \
# overall                         0.376226                  0.470815
# potential                       0.283746                  0.358773
# value_eur                       0.256689                  0.632008
# age                             0.074076                  0.230269
# skill_moves                     1.000000                  0.208460
# international_reputation        0.208460                  1.000000
# attacking_crossing              0.721700                  0.181290
# attacking_finishing             0.740851                  0.168329
# attacking_heading_accuracy      0.439020                  0.147754
# attacking_volleys               0.741924                  0.223521
# skill_dribbling                 0.799155                  0.173629
# skill_fk_accuracy               0.696867                  0.201054
# skill_long_passing              0.593681                  0.239392
# skill_ball_control              0.773110                  0.208671
# movement_acceleration           0.639940                  0.041494
# movement_sprint_speed           0.604364                  0.043598
# movement_agility                0.684825                  0.098850
# movement_reactions              0.366579                  0.427838
# movement_balance                0.584267                  0.059886
# power_shot_power                0.564069                  0.281576
# power_jumping                   0.097420                  0.117165
# power_stamina                   0.552131                  0.093096
# power_strength                 -0.012836                  0.124676
# power_long_shots                0.742904                  0.196104
# mentality_aggression            0.359648                  0.166746
# mentality_positioning           0.765659                  0.172763
# mentality_vision                0.646033                  0.279634
# mentality_penalties             0.693156                  0.191203
# mentality_composure             0.605913                  0.360000
# defending_marking_awareness     0.234671                  0.117593
# defending_sliding_tackle        0.177433                  0.078671
# goalkeeping_diving             -0.604961                  0.010358
# goalkeeping_handling           -0.603081                  0.010937
# goalkeeping_kicking            -0.601639                  0.010236
# goalkeeping_positioning        -0.601882                  0.013484
# preferred_foot_Right           -0.090886                 -0.001520
#
#                              attacking_crossing  attacking_finishing  \
# overall                                0.401356             0.338746
# potential                              0.243757             0.230814
# value_eur                              0.226934             0.217244
# age                                    0.132175             0.088754
# skill_moves                            0.721700             0.740851
# international_reputation               0.181290             0.168329
# attacking_crossing                     1.000000             0.682982
# attacking_finishing                    0.682982             1.000000
# attacking_heading_accuracy             0.493130             0.496748
# attacking_volleys                      0.698748             0.900288
# skill_dribbling                        0.863184             0.840807
# skill_fk_accuracy                      0.764766             0.721055
# skill_long_passing                     0.744209             0.544287
# skill_ball_control                     0.837386             0.801521
# movement_acceleration                  0.682473             0.623394
# movement_sprint_speed                  0.651720             0.600298
# movement_agility                       0.721440             0.667306
# movement_reactions                     0.386875             0.361212
# movement_balance                       0.642271             0.549800
# power_shot_power                       0.528963             0.738760
# power_jumping                          0.126229             0.089098
# power_stamina                          0.680769             0.540296
# power_strength                        -0.008280             0.027346
# power_long_shots                       0.749193             0.903280
# mentality_aggression                   0.499103             0.295009
# mentality_positioning                  0.803924             0.904531
# mentality_vision                       0.681170             0.713155
# mentality_penalties                    0.660510             0.852509
# mentality_composure                    0.627092             0.607211
# defending_marking_awareness            0.465374             0.057259
# defending_sliding_tackle               0.431552            -0.014740
# goalkeeping_diving                    -0.677740            -0.605657
# goalkeeping_handling                  -0.675595            -0.604279
# goalkeeping_kicking                   -0.675874            -0.601335
# goalkeeping_positioning               -0.674395            -0.601135
# preferred_foot_Right                  -0.199483            -0.028673
#
#                              attacking_heading_accuracy  attacking_volleys  \
# overall                                        0.343901           0.380942
# potential                                      0.192825           0.235766
# value_eur                                      0.165578           0.237853
# age                                            0.154516           0.148109
# skill_moves                                    0.439020           0.741924
# international_reputation                       0.147754           0.223521
# attacking_crossing                             0.493130           0.698748
# attacking_finishing                            0.496748           0.900288
# attacking_heading_accuracy                     1.000000           0.531206
# attacking_volleys                              0.531206           1.000000
# skill_dribbling                                0.592342           0.817436
# skill_fk_accuracy                              0.421178           0.753069
# skill_long_passing                             0.543108           0.577257
# skill_ball_control                             0.694926           0.797739
# movement_acceleration                          0.368015           0.586531
# movement_sprint_speed                          0.424833           0.564254
# movement_agility                               0.292908           0.642956
# movement_reactions                             0.375754           0.406562
# movement_balance                               0.207419           0.532501
# power_shot_power                               0.363491           0.749894
# power_jumping                                  0.454348           0.125415
# power_stamina                                  0.657005           0.543252
# power_strength                                 0.512679           0.068351
# power_long_shots                               0.520755           0.880530
# mentality_aggression                           0.717347           0.361252
# mentality_positioning                          0.561948           0.863984
# mentality_vision                               0.282120           0.698189
# mentality_penalties                            0.578952           0.850715
# mentality_composure                            0.569060           0.649909
# defending_marking_awareness                    0.591080           0.132471
# defending_sliding_tackle                       0.544579           0.058476
# goalkeeping_diving                            -0.748750          -0.603146
# goalkeeping_handling                          -0.749095          -0.601622
# goalkeeping_kicking                           -0.745486          -0.598669
# goalkeeping_positioning                       -0.744552          -0.598384
# preferred_foot_Right                          -0.044867          -0.040161
#
#                              ...  mentality_vision  mentality_penalties  \
# overall                      ...          0.523025             0.343690
# potential                    ...          0.345298             0.208062
# value_eur                    ...          0.323736             0.195743
# age                          ...          0.209636             0.151951
# skill_moves                  ...          0.646033             0.693156
# international_reputation     ...          0.279634             0.191203
# attacking_crossing           ...          0.681170             0.660510
# attacking_finishing          ...          0.713155             0.852509
# attacking_heading_accuracy   ...          0.282120             0.578952
# attacking_volleys            ...          0.698189             0.850715
# skill_dribbling              ...          0.727194             0.783188
# skill_fk_accuracy            ...          0.716379             0.744128
# skill_long_passing           ...          0.700809             0.561086
# skill_ball_control           ...          0.704409             0.780347
# movement_acceleration        ...          0.459908             0.549156
# movement_sprint_speed        ...          0.417537             0.533230
# movement_agility             ...          0.607565             0.580854
# movement_reactions           ...          0.527072             0.374661
# movement_balance             ...          0.501937             0.498835
# power_shot_power             ...          0.690942             0.682600
# power_jumping                ...          0.050740             0.144679
# power_stamina                ...          0.487237             0.541220
# power_strength               ...         -0.009577             0.100958
# power_long_shots             ...          0.765232             0.827723
# mentality_aggression         ...          0.325146             0.374987
# mentality_positioning        ...          0.742685             0.818198
# mentality_vision             ...          1.000000             0.633861
# mentality_penalties          ...          0.633861             1.000000
# mentality_composure          ...          0.682060             0.623061
# defending_marking_awareness  ...          0.200737             0.168848
# defending_sliding_tackle     ...          0.134847             0.097101
# goalkeeping_diving           ...         -0.362421            -0.629375
# goalkeeping_handling         ...         -0.358788            -0.628892
# goalkeeping_kicking          ...         -0.356522            -0.624459
# goalkeeping_positioning      ...         -0.355112            -0.624415
# preferred_foot_Right         ...         -0.051223            -0.047491
#
#                              mentality_composure  defending_marking_awareness  \
# overall                                 0.708867                     0.312093
# potential                               0.426790                     0.161288
# value_eur                               0.388250                     0.140712
# age                                     0.359076                     0.163583
# skill_moves                             0.605913                     0.234671
# international_reputation                0.360000                     0.117593
# attacking_crossing                      0.627092                     0.465374
# attacking_finishing                     0.607211                     0.057259
# attacking_heading_accuracy              0.569060                     0.591080
# attacking_volleys                       0.649909                     0.132471
# skill_dribbling                         0.681339                     0.376025
# skill_fk_accuracy                       0.628787                     0.321562
# skill_long_passing                      0.705187                     0.631930
# skill_ball_control                      0.743459                     0.490070
# movement_acceleration                   0.416577                     0.225918
# movement_sprint_speed                   0.414051                     0.243217
# movement_agility                        0.505192                     0.205738
# movement_reactions                      0.697543                     0.334779
# movement_balance                        0.384773                     0.218342
# power_shot_power                        0.637367                     0.058185
# power_jumping                           0.284075                     0.331472
# power_stamina                           0.588383                     0.623218
# power_strength                          0.301446                     0.340599
# power_long_shots                        0.674166                     0.222339
# mentality_aggression                    0.568585                     0.754726
# mentality_positioning                   0.653477                     0.239840
# mentality_vision                        0.682060                     0.200737
# mentality_penalties                     0.623061                     0.168848
# mentality_composure                     1.000000                     0.443772
# defending_marking_awareness             0.443772                     1.000000
# defending_sliding_tackle                0.359157                     0.933001
# goalkeeping_diving                     -0.449580                    -0.553614
# goalkeeping_handling                   -0.446860                    -0.553478
# goalkeeping_kicking                    -0.445416                    -0.552878
# goalkeeping_positioning                -0.441137                    -0.550999
# preferred_foot_Right                   -0.054276                    -0.110440
#
#                              defending_sliding_tackle  goalkeeping_diving  \
# overall                                      0.233589           -0.010990
# potential                                    0.140869           -0.043093
# value_eur                                    0.103281           -0.022038
# age                                          0.089482            0.109490
# skill_moves                                  0.177433           -0.604961
# international_reputation                     0.078671            0.010358
# attacking_crossing                           0.431552           -0.677740
# attacking_finishing                         -0.014740           -0.605657
# attacking_heading_accuracy                   0.544579           -0.748750
# attacking_volleys                            0.058476           -0.603146
# skill_dribbling                              0.327172           -0.774698
# skill_fk_accuracy                            0.270130           -0.563347
# skill_long_passing                           0.593760           -0.605294
# skill_ball_control                           0.430614           -0.804037
# movement_acceleration                        0.202282           -0.630308
# movement_sprint_speed                        0.217606           -0.633539
# movement_agility                             0.164887           -0.556989
# movement_reactions                           0.251561           -0.079749
# movement_balance                             0.200700           -0.533571
# power_shot_power                            -0.016338           -0.275670
# power_jumping                                0.301937           -0.211172
# power_stamina                                0.574866           -0.708093
# power_strength                               0.290818           -0.120404
# power_long_shots                             0.152482           -0.618455
# mentality_aggression                         0.729947           -0.598693
# mentality_positioning                        0.177224           -0.701519
# mentality_vision                             0.134847           -0.362421
# mentality_penalties                          0.097101           -0.629375
# mentality_composure                          0.359157           -0.449580
# defending_marking_awareness                  0.933001           -0.553614
# defending_sliding_tackle                     1.000000           -0.531952
# goalkeeping_diving                          -0.531952            1.000000
# goalkeeping_handling                        -0.531655            0.971585
# goalkeeping_kicking                         -0.531363            0.968414
# goalkeeping_positioning                     -0.530015            0.971219
# preferred_foot_Right                        -0.122015            0.100158
#
#                              goalkeeping_handling  goalkeeping_kicking  \
# overall                                 -0.011080            -0.012986
# potential                               -0.044989            -0.047030
# value_eur                               -0.022424            -0.021551
# age                                      0.112420             0.112025
# skill_moves                             -0.603081            -0.601639
# international_reputation                 0.010937             0.010236
# attacking_crossing                      -0.675595            -0.675874
# attacking_finishing                     -0.604279            -0.601335
# attacking_heading_accuracy              -0.749095            -0.745486
# attacking_volleys                       -0.601622            -0.598669
# skill_dribbling                         -0.772985            -0.770454
# skill_fk_accuracy                       -0.562174            -0.559885
# skill_long_passing                      -0.603459            -0.599891
# skill_ball_control                      -0.802568            -0.799088
# movement_acceleration                   -0.630237            -0.628466
# movement_sprint_speed                   -0.633607            -0.631737
# movement_agility                        -0.556642            -0.554608
# movement_reactions                      -0.080684            -0.081403
# movement_balance                        -0.532446            -0.530836
# power_shot_power                        -0.275181            -0.266944
# power_jumping                           -0.211013            -0.209847
# power_stamina                           -0.706221            -0.703382
# power_strength                          -0.122316            -0.119934
# power_long_shots                        -0.616621            -0.613442
# mentality_aggression                    -0.597210            -0.595690
# mentality_positioning                   -0.699802            -0.696555
# mentality_vision                        -0.358788            -0.356522
# mentality_penalties                     -0.628892            -0.624459
# mentality_composure                     -0.446860            -0.445416
# defending_marking_awareness             -0.553478            -0.552878
# defending_sliding_tackle                -0.531655            -0.531363
# goalkeeping_diving                       0.971585             0.968414
# goalkeeping_handling                     1.000000             0.968049
# goalkeeping_kicking                      0.968049             1.000000
# goalkeeping_positioning                  0.970705             0.967259
# preferred_foot_Right                     0.099322             0.102845
#
#                              goalkeeping_positioning  preferred_foot_Right
# overall                                    -0.002485             -0.048961
# potential                                  -0.040184             -0.042915
# value_eur                                  -0.021243             -0.019993
# age                                         0.120686              0.003021
# skill_moves                                -0.601882             -0.090886
# international_reputation                    0.013484             -0.001520
# attacking_crossing                         -0.674395             -0.199483
# attacking_finishing                        -0.601135             -0.028673
# attacking_heading_accuracy                 -0.744552             -0.044867
# attacking_volleys                          -0.598384             -0.040161
# skill_dribbling                            -0.769348             -0.120627
# skill_fk_accuracy                          -0.560211             -0.133982
# skill_long_passing                         -0.601133             -0.094901
# skill_ball_control                         -0.798632             -0.105706
# movement_acceleration                      -0.626919             -0.117393
# movement_sprint_speed                      -0.629623             -0.115139
# movement_agility                           -0.554221             -0.100907
# movement_reactions                         -0.073168             -0.017345
# movement_balance                           -0.529101             -0.086864
# power_shot_power                           -0.271049             -0.019632
# power_jumping                              -0.206477              0.019277
# power_stamina                              -0.704100             -0.089153
# power_strength                             -0.116784              0.027425
# power_long_shots                           -0.612976             -0.065733
# mentality_aggression                       -0.594173             -0.060398
# mentality_positioning                      -0.695813             -0.083620
# mentality_vision                           -0.355112             -0.051223
# mentality_penalties                        -0.624415             -0.047491
# mentality_composure                        -0.441137             -0.054276
# defending_marking_awareness                -0.550999             -0.110440
# defending_sliding_tackle                   -0.530015             -0.122015
# goalkeeping_diving                          0.971219              0.100158
# goalkeeping_handling                        0.970705              0.099322
# goalkeeping_kicking                         0.967259              0.102845
# goalkeeping_positioning                     1.000000              0.102036
# preferred_foot_Right                        0.102036              1.000000
#
# [36 rows x 36 columns]

# %%
fig = plt.figure(figsize=[21,9])
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
sns.heatmap(corr_matrix,cmap='seismic',linewidth=1,linecolor='white',vmax = 1, vmin=-1,mask=mask, annot=True,fmt='0.2f')
plt.title('Correlation Heatmap', weight='bold',fontsize=20)
#plt.savefig('heatmap1.png',transparent=True, bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
list_features = ['skill_moves',
       'attacking_crossing', 'attacking_finishing',
       'attacking_heading_accuracy', 'attacking_volleys', 'skill_dribbling',
       'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
       'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
       'movement_reactions', 'movement_balance', 'power_shot_power',
       'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
       'mentality_aggression', 'mentality_positioning', 'mentality_vision',
       'mentality_penalties', 'mentality_composure',
       'defending_marking_awareness', 'defending_sliding_tackle',
       'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking',
       'goalkeeping_positioning', 'preferred_foot_Right']

# %%
fig = plt.figure(figsize=[12,8])
sns.set(style = 'white', font_scale=1.4)
players_22[list_features].boxplot(showfliers=False)
plt.grid(False)
plt.xlabel('Skills Category',fontsize=20,weight='bold')
plt.ylabel('Score Ratings',fontsize=20,weight='bold')
plt.title('Distribution of Score Ratings',fontsize=20,weight='bold')
sns.despine()

# %%
#players_22 = players_22.drop(['preferred_foot_Right'],axis=1)

# %%
#sns.set(style='white',font_scale=1.8)
#sns.pairplot(players_22)
#plt.savefig('pairplot1.png',transparent=True, bbox_inches='tight')

# %%
l = list(players_22['value_eur'] == 0)
print('Zeros in output label: ',len([v for v in l if v==True] ))
print('\nNaN values in following features:')
players_22.isnull().any()
# Out:
# Zeros in output label:  0
#
# NaN values in following features:
# short_name                     False
# overall                        False
# potential                      False
# value_eur                      False
# age                            False
# skill_moves                    False
# international_reputation       False
# attacking_crossing             False
# attacking_finishing            False
# attacking_heading_accuracy     False
# attacking_volleys              False
# skill_dribbling                False
# skill_fk_accuracy              False
# skill_long_passing             False
# skill_ball_control             False
# movement_acceleration          False
# movement_sprint_speed          False
# movement_agility               False
# movement_reactions             False
# movement_balance               False
# power_shot_power               False
# power_jumping                  False
# power_stamina                  False
# power_strength                 False
# power_long_shots               False
# mentality_aggression           False
# mentality_positioning          False
# mentality_vision               False
# mentality_penalties            False
# mentality_composure            False
# defending_marking_awareness    False
# defending_sliding_tackle       False
# goalkeeping_diving             False
# goalkeeping_handling           False
# goalkeeping_kicking            False
# goalkeeping_positioning        False
# preferred_foot_Right           False
# dtype: bool

# %%
y, X = patsy.dmatrices("Q('value_eur') ~ age + international_reputation + Q('skill_moves') + attacking_crossing + attacking_finishing + attacking_heading_accuracy + attacking_volleys + skill_dribbling + skill_fk_accuracy + skill_long_passing + skill_ball_control + movement_acceleration + movement_sprint_speed + movement_agility + movement_reactions + movement_balance + power_shot_power + power_jumping + power_stamina + power_strength + power_long_shots + mentality_aggression + mentality_positioning + mentality_vision + mentality_penalties + mentality_composure + defending_marking_awareness + defending_sliding_tackle + goalkeeping_diving + goalkeeping_handling + goalkeeping_kicking + goalkeeping_positioning + preferred_foot_Right", 
                       data=players_22, return_type="dataframe")
model = sm.OLS(y, X)
fit = model.fit()
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Q('value_eur')   R-squared:                       0.529
# Model:                            OLS   Adj. R-squared:                  0.528
# Method:                 Least Squares   F-statistic:                     653.0
# Date:                Mon, 18 Jul 2022   Prob (F-statistic):               0.00
# Time:                        07:21:26   Log-Likelihood:            -3.2058e+05
# No. Observations:               19239   AIC:                         6.412e+05
# Df Residuals:                   19205   BIC:                         6.415e+05
# Df Model:                          33
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                   -1.999e+07   4.09e+05    -48.872      0.000   -2.08e+07   -1.92e+07
# age                         -3.499e+05   8309.381    -42.111      0.000   -3.66e+05   -3.34e+05
# international_reputation     8.443e+06   9.26e+04     91.166      0.000    8.26e+06    8.62e+06
# Q('skill_moves')             5.243e+05   7.12e+04      7.361      0.000    3.85e+05    6.64e+05
# attacking_crossing           1.276e+04   4130.406      3.090      0.002    4667.235    2.09e+04
# attacking_finishing            3.7e+04   5525.010      6.697      0.000    2.62e+04    4.78e+04
# attacking_heading_accuracy   1.957e+04   4524.332      4.325      0.000    1.07e+04    2.84e+04
# attacking_volleys           -5442.0806   4697.328     -1.159      0.247   -1.46e+04    3765.094
# skill_dribbling             -1.115e+04   6845.541     -1.629      0.103   -2.46e+04    2265.973
# skill_fk_accuracy            4502.5863   3700.233      1.217      0.224   -2750.194    1.18e+04
# skill_long_passing           6452.1527   4663.900      1.383      0.167   -2689.499    1.56e+04
# skill_ball_control           2.636e+04   7655.013      3.444      0.001    1.14e+04    4.14e+04
# movement_acceleration        3932.4401   6248.089      0.629      0.529   -8314.362    1.62e+04
# movement_sprint_speed        2.625e+04   5549.341      4.731      0.000    1.54e+04    3.71e+04
# movement_agility            -1.749e+04   4717.172     -3.708      0.000   -2.67e+04   -8247.212
# movement_reactions           1.653e+05   6222.325     26.563      0.000    1.53e+05    1.77e+05
# movement_balance             1.241e+04   4034.490      3.076      0.002    4501.959    2.03e+04
# power_shot_power             -630.0011   4924.652     -0.128      0.898   -1.03e+04    9022.748
# power_jumping               -8688.3166   3238.153     -2.683      0.007    -1.5e+04   -2341.254
# power_stamina                3.263e+04   3708.753      8.797      0.000    2.54e+04    3.99e+04
# power_strength               2.284e+04   3897.296      5.859      0.000    1.52e+04    3.05e+04
# power_long_shots            -2.201e+04   5168.911     -4.258      0.000   -3.21e+04   -1.19e+04
# mentality_aggression        -2943.0896   3546.374     -0.830      0.407   -9894.293    4008.114
# mentality_positioning       -9296.1420   5286.180     -1.759      0.079   -1.97e+04    1065.234
# mentality_vision             7126.2881   4816.136      1.480      0.139   -2313.761    1.66e+04
# mentality_penalties         -1.821e+04   4392.553     -4.145      0.000   -2.68e+04   -9597.083
# mentality_composure          2.459e+04   5065.319      4.854      0.000    1.47e+04    3.45e+04
# defending_marking_awareness  1.132e+04   4708.902      2.404      0.016    2088.572    2.05e+04
# defending_sliding_tackle    -2650.4079   4611.926     -0.575      0.566   -1.17e+04    6389.370
# goalkeeping_diving           2.679e+04   8955.180      2.991      0.003    9233.309    4.43e+04
# goalkeeping_handling          2.69e+04   9222.770      2.916      0.004    8820.186     4.5e+04
# goalkeeping_kicking          3.731e+04   8734.243      4.271      0.000    2.02e+04    5.44e+04
# goalkeeping_positioning      1.474e+04   8975.120      1.643      0.100   -2847.431    3.23e+04
# preferred_foot_Right        -1.166e+05   7.38e+04     -1.581      0.114   -2.61e+05     2.8e+04
# ==============================================================================
# Omnibus:                    23345.438   Durbin-Watson:                   0.882
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          7643930.138
# Skew:                           6.192   Prob(JB):                         0.00
# Kurtosis:                      99.862   Cond. No.                     3.88e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.88e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
players_22_norm = players_22.copy()

# %%
players_22_norm['value_eur'] = np.log1p(players_22['value_eur'])

# %%
players_22_norm
# Out:
#                    short_name  overall  potential  value_eur  age  \
# sofifa_id
# 158023               L. Messi       93         93  17.949076   34
# 188545         R. Lewandowski       92         92  18.375683   32
# 20801       Cristiano Ronaldo       91         91  17.399030   36
# 190871              Neymar Jr       91         91  18.452179   29
# 192985           K. De Bruyne       91         91  18.424673   30
# ...                       ...      ...        ...        ...  ...
# 261962              Song Defu       47         52  10.933125   22
# 262040              C. Porter       47         59  11.385103   19
# 262760               N. Logue       47         55  11.289794   21
# 262820              L. Rudden       47         60  11.385103   19
# 264540     E. Lalchhanchhuaha       47         60  11.385103   19
#
#            skill_moves  international_reputation  attacking_crossing  \
# sofifa_id
# 158023             4.0                         5                85.0
# 188545             4.0                         5                71.0
# 20801              5.0                         5                87.0
# 190871             5.0                         5                85.0
# 192985             4.0                         4                94.0
# ...                ...                       ...                 ...
# 261962             2.0                         1                46.0
# 262040             2.0                         1                54.0
# 262760             2.0                         1                39.0
# 262820             2.0                         1                29.0
# 264540             2.0                         1                39.0
#
#            attacking_finishing  attacking_heading_accuracy  ...  \
# sofifa_id                                                   ...
# 158023                    95.0                        70.0  ...
# 188545                    95.0                        90.0  ...
# 20801                     95.0                        90.0  ...
# 190871                    83.0                        63.0  ...
# 192985                    82.0                        55.0  ...
# ...                        ...                         ...  ...
# 261962                    32.0                        48.0  ...
# 262040                    33.0                        46.0  ...
# 262760                    32.0                        43.0  ...
# 262820                    49.0                        40.0  ...
# 264540                    32.0                        46.0  ...
#
#            mentality_vision  mentality_penalties  mentality_composure  \
# sofifa_id
# 158023                 95.0                 75.0                 96.0
# 188545                 81.0                 90.0                 88.0
# 20801                  76.0                 88.0                 95.0
# 190871                 90.0                 93.0                 93.0
# 192985                 94.0                 83.0                 89.0
# ...                     ...                  ...                  ...
# 261962                 43.0                 42.0                 37.0
# 262040                 49.0                 44.0                 47.0
# 262760                 46.0                 39.0                 36.0
# 262820                 40.0                 49.0                 47.0
# 264540                 46.0                 35.0                 36.0
#
#            defending_marking_awareness  defending_sliding_tackle  \
# sofifa_id
# 158023                            20.0                      24.0
# 188545                            35.0                      19.0
# 20801                             24.0                      24.0
# 190871                            35.0                      29.0
# 192985                            68.0                      53.0
# ...                                ...                       ...
# 261962                            38.0                      48.0
# 262040                            37.0                      47.0
# 262760                            38.0                      48.0
# 262820                            10.0                      11.0
# 264540                            33.0                      37.0
#
#            goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# sofifa_id
# 158023                    6.0                  11.0                 15.0
# 188545                   15.0                   6.0                 12.0
# 20801                     7.0                  11.0                 15.0
# 190871                    9.0                   9.0                 15.0
# 192985                   15.0                  13.0                  5.0
# ...                       ...                   ...                  ...
# 261962                    6.0                  10.0                  5.0
# 262040                   11.0                  12.0                  6.0
# 262760                    8.0                   6.0                  7.0
# 262820                    7.0                  10.0                  7.0
# 264540                    8.0                  13.0                 13.0
#
#            goalkeeping_positioning  preferred_foot_Right
# sofifa_id
# 158023                        14.0                     0
# 188545                         8.0                     1
# 20801                         14.0                     1
# 190871                        15.0                     1
# 192985                        10.0                     1
# ...                            ...                   ...
# 261962                        15.0                     1
# 262040                         8.0                     1
# 262760                        10.0                     1
# 262820                        14.0                     1
# 264540                         9.0                     1
#
# [19239 rows x 37 columns]

# %%
players_22_norm = players_22_norm.rename(columns={'value_eur':'Log Market Value'})

# %%
sns.set(font_scale=1,style='white')
corr_matrix = players_22_norm.corr()
fig = plt.figure(figsize=[21,9])
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
sns.heatmap(corr_matrix,cmap='seismic',linewidth=1.5,linecolor='white',vmax = 1, vmin=-1,mask=mask, annot=True,fmt='0.2f')
plt.title('Correlation Heatmap', weight='bold',fontsize=20)
plt.savefig('heatmap3.png',transparent=True, bbox_inches='tight')

# %%
#sns.set(style='white',font_scale=1.8)
#sns.pairplot(players_22_norm)
#plt.savefig('pairplot2.png',transparent=True, bbox_inches='tight')

# %%
y, X = patsy.dmatrices("Q('Log Market Value') ~ age + international_reputation + Q('skill_moves') + attacking_crossing + attacking_finishing + attacking_heading_accuracy + attacking_volleys + skill_dribbling + skill_fk_accuracy + skill_long_passing + skill_ball_control + movement_acceleration + movement_sprint_speed + movement_agility + movement_reactions + movement_balance + power_shot_power + power_jumping + power_stamina + power_strength + power_long_shots + mentality_aggression + mentality_positioning + mentality_vision + mentality_penalties + mentality_composure + defending_marking_awareness + defending_sliding_tackle + goalkeeping_diving + goalkeeping_handling + goalkeeping_kicking + goalkeeping_positioning + preferred_foot_Right", 
                       data=players_22_norm, return_type="dataframe")
model = sm.OLS(y, X)
fit = model.fit()
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     Q('Log Market Value')   R-squared:                       0.835
# Model:                               OLS   Adj. R-squared:                  0.835
# Method:                    Least Squares   F-statistic:                     2947.
# Date:                   Mon, 18 Jul 2022   Prob (F-statistic):               0.00
# Time:                           07:21:35   Log-Likelihood:                -13934.
# No. Observations:                  19239   AIC:                         2.794e+04
# Df Residuals:                      19205   BIC:                         2.820e+04
# Df Model:                             33
# Covariance Type:               nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       5.9972      0.049    122.587      0.000       5.901       6.093
# age                            -0.1130      0.001   -113.624      0.000      -0.115      -0.111
# international_reputation        0.4457      0.011     40.231      0.000       0.424       0.467
# Q('skill_moves')                0.2018      0.009     23.683      0.000       0.185       0.219
# attacking_crossing              0.0076      0.000     15.420      0.000       0.007       0.009
# attacking_finishing             0.0058      0.001      8.802      0.000       0.005       0.007
# attacking_heading_accuracy      0.0153      0.001     28.278      0.000       0.014       0.016
# attacking_volleys              -0.0015      0.001     -2.632      0.008      -0.003      -0.000
# skill_dribbling                 0.0053      0.001      6.481      0.000       0.004       0.007
# skill_fk_accuracy              -0.0005      0.000     -1.074      0.283      -0.001       0.000
# skill_long_passing              0.0020      0.001      3.672      0.000       0.001       0.003
# skill_ball_control              0.0331      0.001     36.141      0.000       0.031       0.035
# movement_acceleration           0.0043      0.001      5.794      0.000       0.003       0.006
# movement_sprint_speed           0.0051      0.001      7.728      0.000       0.004       0.006
# movement_agility               -0.0027      0.001     -4.709      0.000      -0.004      -0.002
# movement_reactions              0.0565      0.001     75.939      0.000       0.055       0.058
# movement_balance               -0.0030      0.000     -6.298      0.000      -0.004      -0.002
# power_shot_power                0.0081      0.001     13.800      0.000       0.007       0.009
# power_jumping                  -0.0004      0.000     -0.968      0.333      -0.001       0.000
# power_stamina                   0.0067      0.000     15.030      0.000       0.006       0.008
# power_strength                  0.0052      0.000     11.107      0.000       0.004       0.006
# power_long_shots               -0.0067      0.001    -10.758      0.000      -0.008      -0.005
# mentality_aggression        -7.063e-05      0.000     -0.166      0.868      -0.001       0.001
# mentality_positioning          -0.0083      0.001    -13.048      0.000      -0.009      -0.007
# mentality_vision               -0.0046      0.001     -8.034      0.000      -0.006      -0.003
# mentality_penalties            -0.0015      0.001     -2.798      0.005      -0.003      -0.000
# mentality_composure             0.0136      0.001     22.373      0.000       0.012       0.015
# defending_marking_awareness     0.0051      0.001      9.072      0.000       0.004       0.006
# defending_sliding_tackle        0.0008      0.001      1.393      0.164      -0.000       0.002
# goalkeeping_diving              0.0184      0.001     17.186      0.000       0.016       0.021
# goalkeeping_handling            0.0164      0.001     14.847      0.000       0.014       0.019
# goalkeeping_kicking             0.0080      0.001      7.632      0.000       0.006       0.010
# goalkeeping_positioning         0.0161      0.001     15.025      0.000       0.014       0.018
# preferred_foot_Right           -0.0400      0.009     -4.535      0.000      -0.057      -0.023
# ==============================================================================
# Omnibus:                     1348.102   Durbin-Watson:                   1.592
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5513.320
# Skew:                           0.239   Prob(JB):                         0.00
# Kurtosis:                       5.579   Cond. No.                     3.88e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.88e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
def diagnostic_plot(x, y):
    plt.figure(figsize=(20,5))
    
    rgr = LinearRegression()
    rgr.fit(x,y)
    pred = rgr.predict(x)

    plt.subplot(1, 3, 1)
    plt.scatter(pred,y,alpha=0.1)
    plt.plot(y, y, color='red',linewidth=1,)
    plt.title("Regression fit")
    plt.xlabel("Predicted y")
    plt.ylabel("y")
    
    plt.subplot(1, 3, 2)
    res = y - pred
    plt.scatter(pred, res,alpha=0.1)
    plt.title("Residual plot")
    plt.xlabel("prediction")
    plt.ylabel("residuals")
    
    plt.subplot(1, 3, 3)
    #Generates a probability plot of sample data against the quantiles of a 
    # specified theoretical distribution 
    stats.probplot(res, dist="norm", plot=plt,)
    plt.title("Normal Q-Q plot")
    
    lin_mse = mean_squared_error(y, pred)
    lin_rmse = np.sqrt(lin_mse)
    lin_rmse
    
    score = r2_score(y, pred)  
    print('Accuracy:',format(score*100,'.2f'),'%')

# %%
y = players_22_norm['Log Market Value']
X = players_22_norm.drop(['short_name','Log Market Value'],axis=1)

# %%
sns.distplot(y,kde=False)
# Out:
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Log Market Value'>

# %%
sns.set(style='darkgrid')
diagnostic_plot(X, y)
# Out:
# Accuracy: 95.96 %

# %% [markdown]
# # Analysis of the target variable

# %%
plt.subplots(figsize=(12,9))
sns.distplot(players_22['value_eur'], fit=stats.norm)

# Getting the fitted parameters used by the function:
(mu, sigma) = stats.norm.fit(players_22['value_eur'])

# plotting with the distribution:
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)], loc='best')
plt.ylabel('Frequency')

# Probablity plot:
fig = plt.figure()
stats.probplot(players_22['value_eur'], plot=plt)
plt.show()
# Out:
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# analysis of the kurtosis and the skewness to check the normality of the variable:
kurt = players_22['value_eur'].kurtosis()
skew = players_22['value_eur'].skew()
print('Death Kurtorsis {}'.format(kurt))
print('Death Skewness {}'.format(skew))
# Out:
# Death Kurtorsis 98.28700716867866
# Death Skewness 8.202130312464618

# %% [markdown]
# # Normalization

# %%
# Using log function for normalize the target variable:
#players_22_norm['Log Market Value'] = np.log(players_22_norm['Log Market Value'])

# Checking to see the  normal distribution of the variable now:

plt.subplots(figsize=(12,9))
sns.distplot(players_22_norm['Log Market Value'], fit=stats.norm)

# Getting the fitted parameters used by the function:

(mu, sigma) = stats.norm.fit(players_22_norm['Log Market Value'])

# plotting with the distribution now:

plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)], loc='best')
plt.ylabel('Frequency')

# Probablity plot:

fig = plt.figure()
stats.probplot(players_22_norm['Log Market Value'], plot=plt)
plt.show()
# Out:
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# after normalize the variable. we check again the analysis of the kurtosis and the skewness to check the normality of the variable:

kurt = players_22_norm['Log Market Value'].kurtosis()
skew = players_22_norm['Log Market Value'].skew()
print('Death Kurtorsis {}'.format(kurt))
print('Death Skewness {}'.format(skew))
# Out:
# Death Kurtorsis 0.8421533154160796
# Death Skewness 0.5806627737587468

# %%
X
# Out:
#            overall  potential  age  skill_moves  international_reputation  \
# sofifa_id
# 158023          93         93   34          4.0                         5
# 188545          92         92   32          4.0                         5
# 20801           91         91   36          5.0                         5
# 190871          91         91   29          5.0                         5
# 192985          91         91   30          4.0                         4
# ...            ...        ...  ...          ...                       ...
# 261962          47         52   22          2.0                         1
# 262040          47         59   19          2.0                         1
# 262760          47         55   21          2.0                         1
# 262820          47         60   19          2.0                         1
# 264540          47         60   19          2.0                         1
#
#            attacking_crossing  attacking_finishing  \
# sofifa_id
# 158023                   85.0                 95.0
# 188545                   71.0                 95.0
# 20801                    87.0                 95.0
# 190871                   85.0                 83.0
# 192985                   94.0                 82.0
# ...                       ...                  ...
# 261962                   46.0                 32.0
# 262040                   54.0                 33.0
# 262760                   39.0                 32.0
# 262820                   29.0                 49.0
# 264540                   39.0                 32.0
#
#            attacking_heading_accuracy  attacking_volleys  skill_dribbling  \
# sofifa_id
# 158023                           70.0               88.0             96.0
# 188545                           90.0               89.0             85.0
# 20801                            90.0               86.0             88.0
# 190871                           63.0               86.0             95.0
# 192985                           55.0               82.0             88.0
# ...                               ...                ...              ...
# 261962                           48.0               30.0             45.0
# 262040                           46.0               32.0             41.0
# 262760                           43.0               37.0             47.0
# 262820                           40.0               34.0             42.0
# 264540                           46.0               37.0             48.0
#
#            ...  mentality_vision  mentality_penalties  mentality_composure  \
# sofifa_id  ...
# 158023     ...              95.0                 75.0                 96.0
# 188545     ...              81.0                 90.0                 88.0
# 20801      ...              76.0                 88.0                 95.0
# 190871     ...              90.0                 93.0                 93.0
# 192985     ...              94.0                 83.0                 89.0
# ...        ...               ...                  ...                  ...
# 261962     ...              43.0                 42.0                 37.0
# 262040     ...              49.0                 44.0                 47.0
# 262760     ...              46.0                 39.0                 36.0
# 262820     ...              40.0                 49.0                 47.0
# 264540     ...              46.0                 35.0                 36.0
#
#            defending_marking_awareness  defending_sliding_tackle  \
# sofifa_id
# 158023                            20.0                      24.0
# 188545                            35.0                      19.0
# 20801                             24.0                      24.0
# 190871                            35.0                      29.0
# 192985                            68.0                      53.0
# ...                                ...                       ...
# 261962                            38.0                      48.0
# 262040                            37.0                      47.0
# 262760                            38.0                      48.0
# 262820                            10.0                      11.0
# 264540                            33.0                      37.0
#
#            goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# sofifa_id
# 158023                    6.0                  11.0                 15.0
# 188545                   15.0                   6.0                 12.0
# 20801                     7.0                  11.0                 15.0
# 190871                    9.0                   9.0                 15.0
# 192985                   15.0                  13.0                  5.0
# ...                       ...                   ...                  ...
# 261962                    6.0                  10.0                  5.0
# 262040                   11.0                  12.0                  6.0
# 262760                    8.0                   6.0                  7.0
# 262820                    7.0                  10.0                  7.0
# 264540                    8.0                  13.0                 13.0
#
#            goalkeeping_positioning  preferred_foot_Right
# sofifa_id
# 158023                        14.0                     0
# 188545                         8.0                     1
# 20801                         14.0                     1
# 190871                        15.0                     1
# 192985                        10.0                     1
# ...                            ...                   ...
# 261962                        15.0                     1
# 262040                         8.0                     1
# 262760                        10.0                     1
# 262820                        14.0                     1
# 264540                         9.0                     1
#
# [19239 rows x 35 columns]

# %%
players_22_norm.to_csv("players_22_norm.csv")

# %% [markdown]
# # Feature Selection

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import Lasso
from sklearn.preprocessing import MinMaxScaler
X_norm = MinMaxScaler().fit_transform(X)

sel_ = SelectFromModel(LinearRegression()) 
sel_.fit(X_norm, y)
# Out:
# SelectFromModel(estimator=LinearRegression())

# %%
sel_.get_support()
# Out:
# array([ True, False,  True, False,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False])

# %%
selected_feat = X.columns[(sel_.get_support())]

# let's print some stats
print('total features: {}'.format((X.shape[1])))
print('selected features: {}'.format(len(selected_feat)))
print('features with coefficients shrank to zero: {}'.format(
    np.sum(sel_.estimator_.coef_ == 0)))
# Out:
# total features: 35
# selected features: 3
# features with coefficients shrank to zero: 0

# %%
selected_feat
# Out:
# Index(['overall', 'age', 'international_reputation'], dtype='object')

# %% [markdown]
# # Modeling

# %%
X_model = X[selected_feat]
X_model.shape
# Out:
# (19239, 3)

# %%
X_train_val, X_test, y_train_val, y_test = train_test_split(X_model, y, test_size=0.25,random_state=42)
#X_train_val = X[3848:]
#X_test = X[:3848]
#y_train_val = y[3848:]
#y_test = y[:3848]

# %%
rgr = LinearRegression()
rgr.fit(X_train_val,y_train_val)
pred = rgr.predict(X_test)

# %%
plt.scatter(pred,y_test,alpha=0.1)
plt.plot(y_test, y_test, color='red',linewidth=1,label='Identity Line (Log Market Value)')
plt.title("Regression Fit on Test Set",weight='bold')
plt.xlabel("Log Predicted Market Value")
plt.ylabel("Log Market Value")
plt.legend(loc='lower right')
sns.despine()

# %%
lin_mse = mean_squared_error(pred, y_test)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 0.2722827570443607

# %%
score = r2_score(y_test, pred)  
print('Accuracy:',format(score*100,'.2f'),'%')
# Out:
# Accuracy: 94.96 %

# %%
print('Precisión del modelo:')
print(rgr.score(X_test, y_test))
# Out:
# Precisión del modelo:
# 0.9496199304823063

# %%
# define some handy analysis support function
from sklearn.metrics import mean_squared_error, explained_variance_score, r2_score

def plot_prediction_analysis(y, y_pred, figsize=(10,4), title=''):
    fig, axs = plt.subplots(1, 2, figsize=figsize)
    axs[0].scatter(y, y_pred)
    mn = min(np.min(y), np.min(y_pred))
    mx = max(np.max(y), np.max(y_pred))
    axs[0].plot([mn, mx], [mn, mx], c='red')
    axs[0].set_xlabel('$y$')
    axs[0].set_ylabel('$\hat{y}$')
    rmse = np.sqrt(mean_squared_error(y, y_pred))
    evs = explained_variance_score(y, y_pred)
    r2 = r2_score(y, y_pred)
    axs[0].set_title('rmse = {:.2f}, evs = {:.2f}, r2 = {:,.2f}'.format(rmse, evs, r2))
    
    axs[1].hist(y-y_pred, bins=50)
    avg = np.mean(y-y_pred)
    std = np.std(y-y_pred)
    axs[1].set_xlabel('$y - \hat{y}$')
    axs[1].set_title('Histrogram prediction error, $\mu$ = {:.2f}, $\sigma$ = {:.2f}'.format(avg, std))
    
    if title!='':
        fig.suptitle(title)

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler, PolynomialFeatures

#model = LinearRegression()
model = Pipeline((
        ("standard_scaler", StandardScaler()),
        ("poly", PolynomialFeatures(degree=2)),
        ("lin_reg", Lasso(alpha=0.01))
    ))

model.fit(X_train_val, y_train_val)

y_train_pred = model.predict(X_train_val)

plot_prediction_analysis(y_train_val, y_train_pred, title='Polynomial Model - Trainingset')

y_test_pred = model.predict(X_test)
plot_prediction_analysis(y_test, y_test_pred, title='Polynomial Model - Testset')

# %% [markdown]
# # LASSO

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import Lasso
from sklearn.preprocessing import MinMaxScaler
X_norm_lasso = MinMaxScaler().fit_transform(X)

sel_ = SelectFromModel(Lasso(alpha=.0001, random_state=42)) 
sel_.fit(X_norm_lasso, y)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.0001, random_state=42))

# %%
sel_.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True, False,  True,
#        False,  True, False,  True,  True, False,  True,  True,  True,
#         True, False,  True,  True,  True,  True,  True, False,  True,
#         True,  True,  True, False, False,  True,  True,  True])

# %%
selected_feat = X.columns[(sel_.get_support())]

# let's print some stats
print('total features: {}'.format((X.shape[1])))
print('selected features: {}'.format(len(selected_feat)))
print('features with coefficients shrank to zero: {}'.format(
    np.sum(sel_.estimator_.coef_ == 0)))
# Out:
# total features: 35
# selected features: 27
# features with coefficients shrank to zero: 8

# %%
selected_feat
# Out:
# Index(['overall', 'potential', 'age', 'skill_moves',
#        'international_reputation', 'attacking_crossing', 'attacking_finishing',
#        'attacking_volleys', 'skill_fk_accuracy', 'skill_ball_control',
#        'movement_acceleration', 'movement_agility', 'movement_reactions',
#        'movement_balance', 'power_shot_power', 'power_stamina',
#        'power_strength', 'power_long_shots', 'mentality_aggression',
#        'mentality_positioning', 'mentality_penalties', 'mentality_composure',
#        'defending_marking_awareness', 'defending_sliding_tackle',
#        'goalkeeping_kicking', 'goalkeeping_positioning',
#        'preferred_foot_Right'],
#       dtype='object')

# %%
X_model_lasso = X[selected_feat]
X_model_lasso.shape
# Out:
# (19239, 27)

# %%
X_train_val, X_test, y_train_val, y_test = train_test_split(X_model_lasso, y, test_size=0.25,random_state=42)
#X_train_val = X[3848:]
#X_test = X[:3848]
#y_train_val = y[3848:]
#y_test = y[:3848]

# %%
#############SEGUIR AQUI

# %%
from sklearn.linear_model import Lasso
# Train model with default alpha=1
lasso_model = Lasso(alpha = 0.1)    
lasso_model.fit(X_train_val, y_train_val)
list(zip(selected_feat, lasso_model.coef_))
## doing feature selection with Lasso
# Out:
# [('overall', 0.16924806013355392),
#  ('potential', 0.018581025368317357),
#  ('age', -0.09291538278023011),
#  ('skill_moves', 0.0),
#  ('international_reputation', 0.0),
#  ('attacking_crossing', 0.0),
#  ('attacking_finishing', 0.0009255775163952073),
#  ('attacking_volleys', 0.0014066624112178624),
#  ('skill_fk_accuracy', 0.0),
#  ('skill_ball_control', 0.00020538053909497752),
#  ('movement_acceleration', 0.0),
#  ('movement_agility', -0.0),
#  ('movement_reactions', 0.0014897820505778926),
#  ('movement_balance', -0.0),
#  ('power_shot_power', 0.0),
#  ('power_stamina', 0.0005613415230456829),
#  ('power_strength', 0.0),
#  ('power_long_shots', 0.0),
#  ('mentality_aggression', 0.0),
#  ('mentality_positioning', 0.0011370584089018087),
#  ('mentality_penalties', 0.0),
#  ('mentality_composure', 0.0),
#  ('defending_marking_awareness', 0.0),
#  ('defending_sliding_tackle', -0.0),
#  ('goalkeeping_kicking', -0.0),
#  ('goalkeeping_positioning', -0.0017250938735167117),
#  ('preferred_foot_Right', 0.0)]

# %%
std = StandardScaler()
std.fit(X_train_val.values)
X_tr = std.transform(X_train_val.values)
X_te = std.transform(X_test.values)
## Scaling x values for lasso,ridge,elastic net

# %%
kf = KFold(n_splits=5, shuffle=True, random_state = 71)

# %%
alphavec = 10**np.linspace(-15,4,400)
lasso_model = LassoCV(alphas = alphavec, cv=kf)
lasso_model.fit(X_tr, y_train_val)
lasso_model.alpha_
## finding alpha value that gives lowest MAE for Lasso CV
# Out:
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27.9527463606845, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.054107489585135, tolerance: 1.7391765867728213
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.524068057307545, tolerance: 1.7391765867728213
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22.648411810212224, tolerance: 1.7391765867728213
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.9386134795439602, tolerance: 1.7676734537315724
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19.247749068886947, tolerance: 1.7676734537315724
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.76589104708603, tolerance: 1.7676734537315724
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29.52109072542885, tolerance: 1.7872741278316915
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.949350429055812, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.08417638249091, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.628734749877822, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.882325743098022, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# 0.00024040991835099645

# %%
test_predictions = lasso_model.predict(X_te)
test_mae = mean_absolute_error(test_predictions, y_test)
print("Validation MAE: {:,.0f}".format(test_mae))
# Out:
# Validation MAE: 0

# %%
score = r2_score(y_test, test_predictions)  
print('Accuracy:',format(score*100,'.2f'),'%')
# Out:
# Accuracy: 95.55 %

# %% [markdown]
# # RIDGE

# %%
alphavec = 10**np.linspace(-2,2,200)
ridge_model = RidgeCV(alphas = alphavec, cv=kf)
ridge_model.fit(X_tr, y_train_val)
ridge_model.alpha_
## finding alpha value that gives lowest MAE for Ridge CV
# Out:
# 1.1226677735108135

# %%
list(zip(X_train_val.columns, ridge_model.coef_))
# finding coefficients for optimum alpha value for Ridge
# Out:
# [('overall', 1.2833594965471307),
#  ('potential', 0.022203805613428437),
#  ('age', -0.5450782777289849),
#  ('skill_moves', 0.027942958988821504),
#  ('international_reputation', 0.07464492467119323),
#  ('attacking_crossing', -0.002178643869242146),
#  ('attacking_finishing', 0.013802785876486267),
#  ('attacking_volleys', 0.013716689725880908),
#  ('skill_fk_accuracy', 0.014603689888122749),
#  ('skill_ball_control', -0.02745666898213154),
#  ('movement_acceleration', -0.009484539998981642),
#  ('movement_agility', -0.015811485902073038),
#  ('movement_reactions', 0.01369158111827288),
#  ('movement_balance', 0.003133919353698247),
#  ('power_shot_power', -0.004202627964621327),
#  ('power_stamina', 0.01748361550002134),
#  ('power_strength', 0.005074931347129497),
#  ('power_long_shots', -0.004398028495677699),
#  ('mentality_aggression', 0.0034204553305591237),
#  ('mentality_positioning', 0.02794713295428091),
#  ('mentality_penalties', -0.012768937728240837),
#  ('mentality_composure', -0.01682940951977193),
#  ('defending_marking_awareness', 0.004413644577825516),
#  ('defending_sliding_tackle', -0.02985946264540417),
#  ('goalkeeping_kicking', -0.014461804459757716),
#  ('goalkeeping_positioning', -0.057697030307611974),
#  ('preferred_foot_Right', 0.003476758570763104)]

# %%
ridge_model_final = Ridge(alpha = 0.9329304026284686) 
Mean_R2_Ridge_CV = np.mean(cross_val_score(ridge_model_final, X_tr, y_train_val, cv=kf, scoring='r2'))
Mean_R2_Ridge_CV
# scoring the Ridge model based on CV
# Out:
# 0.9604602880053733

# %%
Std_R2_Ridge_CV = np.std(cross_val_score(ridge_model_final, X_tr, y_train_val, cv=kf, scoring='r2'))
Std_R2_Ridge_CV
# Out:
# 0.0060794424330485155

# %%
Mean_MAE_Ridge_CV = -np.mean(cross_val_score(ridge_model_final, X_tr, y_train_val, cv=kf, scoring='neg_mean_absolute_error'))
Mean_MAE_Ridge_CV
# scoring the Ridge model based on CV
# Out:
# 0.16556451060233288

# %%
Std_MAE_Ridge_CV = np.std(cross_val_score(ridge_model_final, X_tr, y_train_val, cv=kf, scoring='neg_mean_absolute_error'))
Std_MAE_Ridge_CV
# Out:
# 0.004666251487467423

# %%
from sklearn.model_selection import GridSearchCV

price_model_ridgecv = Ridge(random_state=1)
parameters = [{"alpha": [6000, 10000, 50000]}]

grid = GridSearchCV(estimator=price_model_ridgecv, param_grid=parameters, cv=kf)
grid.fit(X_tr, y_train_val)
print("Best estimator: ", grid.best_estimator_)
print("Best score: ", grid.best_score_)

price_model_ridgecv = Ridge(alpha=grid.best_params_["alpha"], random_state=1)
price_model_ridgecv.fit(X_tr, y_train_val)
test_predictions = price_model_ridgecv.predict(X_te)
test_mae = mean_absolute_error(test_predictions, y_test)
print("Validation MAE: {:,.0f}".format(test_mae))
#Best estimator:  Ridge(alpha=6000, random_state=1)
#Best score:  0.5252214885053264
#Validation MAE: 6,060,204
# Out:
# Best estimator:  Ridge(alpha=6000, random_state=1)
# Best score:  0.8909395209728771
# Validation MAE: 0

# %%
test_predictions_ridge = price_model_ridgecv.predict(X_te)
test_mae = mean_absolute_error(test_predictions_ridge, y_test)
print("Validation MAE: {:,.0f}".format(test_mae))
# Out:
# Validation MAE: 0

# %%
score = r2_score(y_test, test_predictions_ridge)  
print('Accuracy:',format(score*100,'.2f'),'%')
# Out:
# Accuracy: 89.69 %

# %% [markdown]
# # ElasticNetCV

# %%
alphavec = 10**np.linspace(-22,-17,300)
elastic_model = ElasticNetCV(alphas = alphavec, cv=kf)
elastic_model.fit(X_tr, y_train_val)
elastic_model.alpha_
## finding alpha value that gives lowest MAE for ElasticNet CV
# Out:
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.2969812107251, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 316.5168396908862, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 315.21886562556455, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 312.54430295749864, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 312.72382806321787, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 313.05011273869985, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 313.4895198640485, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 313.664619304649, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 311.4941774477623, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 314.23320085860064, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 316.7525503008602, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 312.56418333725134, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 315.09351548262936, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 315.2516273180794, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 315.4839118354107, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 318.54927678667116, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 316.26522907452994, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 317.1798717530552, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 318.86050119196494, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 316.51734434648284, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 316.7013010098902, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 317.78119007643346, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 317.048382107259, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 318.62247625893457, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 317.3709569948205, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 318.29706232396296, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 318.9113434135469, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 317.80954547380185, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 317.9444065060897, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 318.07493810779476, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 318.8402462796732, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319.8611410641575, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 318.43714532611193, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319.49977386168086, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319.57151194332033, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319.64073751132264, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319.70732534668923, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 318.14186717548506, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319.0485840577677, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319.12689373370205, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319.9535687910182, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319.30506939996286, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319.78789325696084, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319.46803820683715, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 318.91151706355606, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319.60444368247107, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.71032404702225, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.2929451551688, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319.80045042389423, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.3731403426872, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.41215997404834, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319.64327333819534, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.48582306188104, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.3457758592104, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.5569139777335, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 318.9566584341253, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.2254887788044, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.4968273518648, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.53113053450033, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.0041525090186, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.0678810882808, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.756060231352, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.78054936836145, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.5039842210973, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.53796803801157, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.5706701744135, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.8702077780997, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.37533833594244, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.7441790478511, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.68971505726034, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.7167020292956, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.96333824380514, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.895064372496, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.9960587678213, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.01180262147454, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.8371693585548, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.0406393200789, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.0541494783684, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.89907010484495, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.9181741421339, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.17067560810546, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.9542382557155, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.9712501922183, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.98762865431166, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.00337476232596, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.1472953098582, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.0744268425471, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.1663849874506, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.232758395853, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.1840589392575, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.24551451968375, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.99604871786823, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.1688073181422, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.21557806885824, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.1316681035354, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3172562671724, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.06760644420456, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.16158629713215, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.21749873725946, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.10439479539895, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.2602987900348, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.1962090894935, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.2710157240422, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.2761044996897, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.2189708746265, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.1664205467032, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.26717227063415, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.18405265341084, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.24550483660795, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3282131136222, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.306483881582, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3102190191885, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.26825463787657, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3391471170993, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3205459535194, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.32373170610606, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3111800728475, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.329735094463, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.2602930318596, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3005324194817, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3044753146526, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3565748366735, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.34290470074217, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3154273379946, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.318806795781, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.34966009232323, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3783201986553, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.35375886467864, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3310931124863, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3102137542675, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3365623555006, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.35229127045244, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.36271236665607, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.37010254795445, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3756018468348, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3726806411873, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3506559727476, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.36314053925076, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3546753731163, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3662345781426, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3738950096743, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3793240757264, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3761902783385, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3772726349471, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3650359837524, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.36654109886393, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.36798661365765, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.36938045763367, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.37071921331597, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3720120568069, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321.3795802382435, tolerance: 1.7503618312630373
#   model = cd_fast.enet_coordinate_descent_gram(
# ...
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2364898762862, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2360875287595, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2358926761506, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.23635108727206, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2363986030901, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2363825914858, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2358673150333, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.23641176005304, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2363554019371, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.23637129400794, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2364515097967, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.23654186081706, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.23632529032585, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.23655922456044, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.23649784701513, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2362405885762, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.23638964526845, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.23640424386946, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.23653757027034, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2364318075989, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2366104711685, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2364573283289, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2365716231413, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2366580602109, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.23649210693776, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2365939331098, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.23660081511093, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.23652309151316, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2366787371092, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2365418463537, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.23659578247157, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.23655921115034, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.236567404739, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.23657528885, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.23651845729825, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.23661083644225, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2366329848934, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2366900432069, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2366932949595, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.23669642380463, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2366994344414, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.23662853407103, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2366814489949, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.23668502538965, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2366446355204, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2366496024058, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.23669496401055, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.23671755456235, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:526: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355.2366634054291, tolerance: 1.75541012982956
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Kiko\anaconda3\anaconda3_new\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 430.8873614827497, tolerance: 2.1999808358390527
#   model = cd_fast.enet_coordinate_descent(
# 1e-17

# %% [markdown]
# # Linear Regression

# %%
lm = LinearRegression()

Mean_R2_Linear_CV = np.mean(cross_val_score(lm, X_train_val, y_train_val, cv=kf, scoring='r2'))
Mean_R2_Linear_CV 
# scoring the LR model based on CV
# Out:
# 0.9604601022675523

# %%
Std_R2_Linear_CV = np.std(cross_val_score(lm, X_train_val, y_train_val, cv=kf, scoring='r2'))
Std_R2_Linear_CV
# Out:
# 0.006083765935645038

# %%
Mean_MAE_Linear_CV = - np.mean(cross_val_score(lm, X_train_val, y_train_val, cv=kf, scoring='neg_mean_absolute_error'))
Mean_MAE_Linear_CV
# Out:
# 0.1656013757409353

# %%
Std_MAE_Linear_CV = np.std(cross_val_score(lm, X_train_val, y_train_val, cv=kf, scoring='neg_mean_absolute_error'))
Std_MAE_Linear_CV
# Out:
# 0.0046670662837472

# %%
X_train_val = X_train_val.reset_index().drop('sofifa_id',axis=1)
y_train_val = y_train_val.reset_index().drop('sofifa_id',axis=1)

# %%
err_vector = []

for degree in range(2,5):
    mae = []
    for train_index, test_index in kf.split(X_train_val):
    #for sofifa_id in kf.split(X_train_val):
        
        X_train1, X_test1 = X_train_val.loc[train_index], X_train_val.loc[test_index]
        y_train1, y_test1 = y_train_val.loc[train_index], y_train_val.loc[test_index]

        #X_train1, X_test1 = X_train_val.loc[sofifa_id], X_train_val.loc[sofifa_id]
        #y_train1, y_test1 = y_train_val.loc[sofifa_id], y_train_val.loc[sofifa_id]         
        
        poly = make_pipeline(PolynomialFeatures(degree), LinearRegression())
        poly.fit(X_train1,y_train1)
        
        predict = poly.predict(X_test1)
        mae.append(mean_absolute_error(y_test1, predict))
    err_vector.append(np.mean(mae))
    print(degree)
# Out:
# 2
# 3
# 4

# %%
err_vector
# Out:
# [0.11510647800404632, 0.1381588779190755, 0.41216984857172967]

# %%
poly = make_pipeline(PolynomialFeatures(4), LinearRegression())

Mean_R2_Poly_CV = np.mean(cross_val_score(poly, X_train_val, y_train_val, cv=kf, scoring='r2'))
Mean_R2_Poly_CV
# Out:
# 0.6880079931353491

# %%
Std_R2_Poly_CV = np.std(cross_val_score(poly, X_train_val, y_train_val, cv=kf, scoring='r2'))
Std_R2_Poly_CV
# Out:
# 0.01643340900128889

# %%
Mean_MAE_Poly_CV =  - np.mean(cross_val_score(poly, X_train_val, y_train_val, cv=kf, scoring='neg_mean_absolute_error'))
Mean_MAE_Poly_CV
# Out:
# 0.41216984857172967

# %%
Std_MAE_Poly_CV = np.std(cross_val_score(poly, X_train_val, y_train_val, cv=kf, scoring='neg_mean_absolute_error'))
Std_MAE_Poly_CV
# Out:
# 0.015284981599489182

# %%
print(f'Mean R2 Linear is: {Mean_R2_Linear_CV:.3f} +- {Std_R2_Linear_CV:.3f}')
print(f'Mean R2 Ridge is: {Mean_R2_Ridge_CV:.3f} +- {Std_R2_Ridge_CV:.3f}')
print(f'Mean R2 Poly is: {Mean_R2_Poly_CV:.3f} +- {Std_R2_Poly_CV:.3f}')
# Out:
# Mean R2 Linear is: 0.960 +- 0.006
# Mean R2 Ridge is: 0.960 +- 0.006
# Mean R2 Poly is: 0.688 +- 0.016

# %%
print(f'Mean MAE Linear is: {Mean_MAE_Linear_CV:.3f} +- {Std_MAE_Linear_CV:.3f}')
print(f'Mean MAE Ridge is: {Mean_MAE_Ridge_CV:.3f} +- {Std_MAE_Ridge_CV:.3f}')
print(f'Mean MAE Poly is: {Mean_MAE_Poly_CV:.3f} +- {Std_MAE_Poly_CV:.3f}')
# Out:
# Mean MAE Linear is: 0.166 +- 0.005
# Mean MAE Ridge is: 0.166 +- 0.005
# Mean MAE Poly is: 0.412 +- 0.015

# %%
poly = make_pipeline(PolynomialFeatures(4), LinearRegression())
poly.fit(X_train_val,y_train_val)
predicted = poly.predict(X_test)
print('R2 score on test set is: {}'.format(r2_score(y_test, predicted)))
print('MSE score on test set is: {}'.format(mean_absolute_error(y_test, predicted)))
# Out:
# R2 score on test set is: 0.48137827058518257
# MSE score on test set is: 0.47826264678141195

# %%
def diagnostic_plot2(x_train, y_train, x_test, y_test):
    plt.figure(figsize=(22,8))
    
  #  poly = make_pipeline(PolynomialFeatures(4), LinearRegression())
  #  poly.fit(x_train,y_train)
  #  pred = poly.predict(x_test)
    
    rgr = LinearRegression()
    rgr.fit(x_train,y_train)
    pred = rgr.predict(x_test)    

    plt.subplot(1, 2, 1)
    plt.scatter(pred,y_test,alpha=0.1)
    plt.plot(y_test, y_test, color='red',linewidth=1,label='Identity Line (Log Market Value)')
    plt.title("Regression Fit on Test Set",weight='bold')
    plt.xlabel("Log Predicted Market Value")
    plt.ylabel("Log Market Value")
    plt.legend(loc='lower right')
    sns.despine()
    
    plt.subplot(1, 2, 2)
    res = np.array(y_test).reshape(-1,1) - pred
    plt.scatter(pred, res,alpha=0.1)
    plt.title("Residual Plot on Test Set",weight='bold')
    plt.xlabel("Log Predicted Market Value")
    plt.ylabel("Residuals")
    sns.despine()
    
 #   plt.subplot(1, 3, 3)
 #   #Generates a probability plot of sample data against the quantiles of a 
 #   # specified theoretical distribution 
 #   stats.probplot(res.T[0], dist="norm", plot=plt,)
 #   plt.title("Normal Q-Q plot")

# %%
sns.set(style='white',font_scale=1.5)
diagnostic_plot2(X_train_val, y_train_val,X_test,y_test)
plt.savefig('regression1.png',transparent=True, bbox_inches='tight')

# %%
poly = make_pipeline(PolynomialFeatures(4), LinearRegression())
poly.fit(X_train_val,y_train_val)
predicted = poly.predict(X_test)
predicted
# Out:
# array([[13.66149472],
#        [12.35810834],
#        [13.42018179],
#        ...,
#        [12.30523666],
#        [11.82917953],
#        [16.13225876]])

# %%
rgr = LinearRegression()
rgr.fit(X_train_val,y_train_val)
predicted = rgr.predict(X_test)    
predicted
# Out:
# array([[13.60182565],
#        [12.4206518 ],
#        [12.15018346],
#        ...,
#        [12.30362652],
#        [11.98446658],
#        [16.44117193]])

# %%
Test_Set = pd.DataFrame(y_test).join(X_test).join(pd.DataFrame(players_22_norm['short_name']))
Test_Set['Log Market Value'] = np.exp(Test_Set['Log Market Value'] )
Test_Set = Test_Set.rename(columns={'Log Market Value':'Market Value'})
Test_Set['Predicted Market Value'] = np.exp(predicted)
Test_Set = Test_Set.sort_values(by='Predicted Market Value',ascending=False)
#Test_Set['Market Value'] = Test_Set['Market Value'].apply(lambda x : "{:,}".format(int(x)))
#Test_Set['Predicted Market Value'] = Test_Set['Predicted Market Value'].apply(lambda x : "{:,}".format(int(x)))

# %%
Test_Set
# Out:
#            Market Value  overall  potential  age  skill_moves  \
# sofifa_id
# 231747     1.552000e+08       91         95   22          5.0
# 190871     1.032000e+08       91         91   29          5.0
# 158023     6.240000e+07       93         93   34          4.0
# 212622     8.640000e+07       89         90   26          3.0
# 209331     8.080000e+07       89         89   29          4.0
# ...                 ...      ...        ...  ...          ...
# 257934     5.600100e+04       48         53   24          2.0
# 258987     5.600100e+04       48         53   24          2.0
# 186838     1.600100e+04       57         57   39          1.0
# 262371     2.280362e+06       56         56   40          2.0
# 232473     1.600100e+04       57         57   40          1.0
#
#            international_reputation  attacking_crossing  attacking_finishing  \
# sofifa_id
# 231747                            4                78.0                 93.0
# 190871                            5                85.0                 83.0
# 158023                            5                85.0                 95.0
# 212622                            4                91.0                 68.0
# 209331                            4                79.0                 91.0
# ...                             ...                 ...                  ...
# 257934                            1                39.0                 32.0
# 258987                            1                38.0                 29.0
# 186838                            1                17.0                 11.0
# 262371                            1                34.0                 58.0
# 232473                            1                13.0                  9.0
#
#            attacking_volleys  skill_fk_accuracy  ...  mentality_positioning  \
# sofifa_id                                        ...
# 231747                  83.0               69.0  ...                   92.0
# 190871                  86.0               87.0  ...                   86.0
# 158023                  88.0               94.0  ...                   93.0
# 212622                  69.0               61.0  ...                   80.0
# 209331                  81.0               69.0  ...                   91.0
# ...                      ...                ...  ...                    ...
# 257934                  24.0               34.0  ...                   45.0
# 258987                  33.0               31.0  ...                   33.0
# 186838                  11.0               11.0  ...                   12.0
# 262371                  44.0               35.0  ...                   57.0
# 232473                  10.0               12.0  ...                    6.0
#
#            mentality_penalties  mentality_composure  \
# sofifa_id
# 231747                    79.0                 88.0
# 190871                    93.0                 93.0
# 158023                    75.0                 96.0
# 212622                    44.0                 85.0
# 209331                    86.0                 90.0
# ...                        ...                  ...
# 257934                    41.0                 40.0
# 258987                    43.0                 41.0
# 186838                    11.0                 29.0
# 262371                    56.0                 53.0
# 232473                    13.0                 26.0
#
#            defending_marking_awareness  defending_sliding_tackle  \
# sofifa_id
# 231747                            26.0                      32.0
# 190871                            35.0                      29.0
# 158023                            20.0                      24.0
# 212622                            85.0                      79.0
# 209331                            38.0                      41.0
# ...                                ...                       ...
# 257934                            43.0                      44.0
# 258987                            38.0                      44.0
# 186838                            18.0                       9.0
# 262371                            20.0                      16.0
# 232473                            21.0                      15.0
#
#            goalkeeping_kicking  goalkeeping_positioning  preferred_foot_Right  \
# sofifa_id
# 231747                     7.0                     11.0                     1
# 190871                    15.0                     15.0                     1
# 158023                    15.0                     14.0                     0
# 212622                     7.0                     15.0                     1
# 209331                     9.0                     11.0                     0
# ...                        ...                      ...                   ...
# 257934                     8.0                     11.0                     1
# 258987                    13.0                     11.0                     1
# 186838                    57.0                     55.0                     1
# 262371                    10.0                     12.0                     1
# 232473                    54.0                     66.0                     1
#
#               short_name  Predicted Market Value
# sofifa_id
# 231747         K. Mbappé            3.166617e+08
# 190871         Neymar Jr            1.611545e+08
# 158023          L. Messi            1.328067e+08
# 212622        J. Kimmich            1.192781e+08
# 209331          M. Salah            8.990725e+07
# ...                  ...                     ...
# 257934         Guo Yunqi            3.380983e+04
# 258987     Ruan Zhexiang            3.325141e+04
# 186838        G. Doherty            2.751444e+04
# 262371         C. Dundas            2.528957e+04
# 232473         H. Shiota            2.333004e+04
#
# [4810 rows x 30 columns]

# %%
Test_Set = Test_Set[['short_name','Market Value','Predicted Market Value','age','international_reputation','attacking_crossing', 'attacking_finishing',
       'attacking_volleys', 'skill_fk_accuracy', 'skill_ball_control',
       'movement_acceleration', 'movement_agility', 'movement_reactions',
       'movement_balance', 'power_shot_power', 'power_stamina',
       'power_strength', 'power_long_shots', 'mentality_aggression',
       'mentality_positioning', 'mentality_penalties', 'mentality_composure',
       'defending_marking_awareness', 'defending_sliding_tackle',
       'goalkeeping_kicking', 'goalkeeping_positioning', 'preferred_foot_Right']] #
Test_Set.reset_index(inplace=True)
Test_Set.drop('sofifa_id',axis=1,inplace=True)
Test_Set
# Out:
# C:\Users\Kiko\AppData\Local\Temp/ipykernel_12192/975138869.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_Set.drop('sofifa_id',axis=1,inplace=True)
#          short_name  Market Value  Predicted Market Value  age  \
# 0         K. Mbappé  1.552000e+08            3.166617e+08   22
# 1         Neymar Jr  1.032000e+08            1.611545e+08   29
# 2          L. Messi  6.240000e+07            1.328067e+08   34
# 3        J. Kimmich  8.640000e+07            1.192781e+08   26
# 4          M. Salah  8.080000e+07            8.990725e+07   29
# ...             ...           ...                     ...  ...
# 4805      Guo Yunqi  5.600100e+04            3.380983e+04   24
# 4806  Ruan Zhexiang  5.600100e+04            3.325141e+04   24
# 4807     G. Doherty  1.600100e+04            2.751444e+04   39
# 4808      C. Dundas  2.280362e+06            2.528957e+04   40
# 4809      H. Shiota  1.600100e+04            2.333004e+04   40
#
#       international_reputation  attacking_crossing  attacking_finishing  \
# 0                            4                78.0                 93.0
# 1                            5                85.0                 83.0
# 2                            5                85.0                 95.0
# 3                            4                91.0                 68.0
# 4                            4                79.0                 91.0
# ...                        ...                 ...                  ...
# 4805                         1                39.0                 32.0
# 4806                         1                38.0                 29.0
# 4807                         1                17.0                 11.0
# 4808                         1                34.0                 58.0
# 4809                         1                13.0                  9.0
#
#       attacking_volleys  skill_fk_accuracy  skill_ball_control  ...  \
# 0                  83.0               69.0                91.0  ...
# 1                  86.0               87.0                95.0  ...
# 2                  88.0               94.0                96.0  ...
# 3                  69.0               61.0                85.0  ...
# 4                  81.0               69.0                89.0  ...
# ...                 ...                ...                 ...  ...
# 4805               24.0               34.0                45.0  ...
# 4806               33.0               31.0                44.0  ...
# 4807               11.0               11.0                19.0  ...
# 4808               44.0               35.0                54.0  ...
# 4809               10.0               12.0                18.0  ...
#
#       power_long_shots  mentality_aggression  mentality_positioning  \
# 0                 82.0                  62.0                   92.0
# 1                 81.0                  63.0                   86.0
# 2                 94.0                  44.0                   93.0
# 3                 84.0                  89.0                   80.0
# 4                 84.0                  63.0                   91.0
# ...                ...                   ...                    ...
# 4805              34.0                  51.0                   45.0
# 4806              28.0                  52.0                   33.0
# 4807              13.0                  32.0                   12.0
# 4808              52.0                  42.0                   57.0
# 4809               6.0                  24.0                    6.0
#
#       mentality_penalties  mentality_composure  defending_marking_awareness  \
# 0                    79.0                 88.0                         26.0
# 1                    93.0                 93.0                         35.0
# 2                    75.0                 96.0                         20.0
# 3                    44.0                 85.0                         85.0
# 4                    86.0                 90.0                         38.0
# ...                   ...                  ...                          ...
# 4805                 41.0                 40.0                         43.0
# 4806                 43.0                 41.0                         38.0
# 4807                 11.0                 29.0                         18.0
# 4808                 56.0                 53.0                         20.0
# 4809                 13.0                 26.0                         21.0
#
#       defending_sliding_tackle  goalkeeping_kicking  goalkeeping_positioning  \
# 0                         32.0                  7.0                     11.0
# 1                         29.0                 15.0                     15.0
# 2                         24.0                 15.0                     14.0
# 3                         79.0                  7.0                     15.0
# 4                         41.0                  9.0                     11.0
# ...                        ...                  ...                      ...
# 4805                      44.0                  8.0                     11.0
# 4806                      44.0                 13.0                     11.0
# 4807                       9.0                 57.0                     55.0
# 4808                      16.0                 10.0                     12.0
# 4809                      15.0                 54.0                     66.0
#
#       preferred_foot_Right
# 0                        1
# 1                        1
# 2                        0
# 3                        1
# 4                        0
# ...                    ...
# 4805                     1
# 4806                     1
# 4807                     1
# 4808                     1
# 4809                     1
#
# [4810 rows x 27 columns]

# %%
mean_absolute_error(Test_Set['Market Value'],Test_Set['Predicted Market Value'])
# Out:
# 506438.74691185326

# %%
r2_score(Test_Set['Market Value'],Test_Set['Predicted Market Value'])
# Out:
# 0.7608329703484619

# %%
stats.kurtosis(Test_Set['Market Value']-Test_Set['Predicted Market Value'])
# Out:
# 1651.4284416440748

# %%
def diagnostic_plot3(x_train, y_train, x_test, y_test):
    plt.figure(figsize=(22,8))
    
    poly = make_pipeline(PolynomialFeatures(4), LinearRegression())
    poly.fit(x_train,y_train)
    pred = poly.predict(x_test)

    plt.subplot(1, 2, 1)
    plt.scatter(np.exp(pred),np.exp(y_test),alpha=0.1)
    plt.plot(np.exp(y_test), np.exp(y_test), color='red',linewidth=1,label='Identity Line (Market Value)')
    plt.title("Regression Fit on Test Set",weight='bold')
    plt.xlabel("Predicted Market Value")
    plt.ylabel("Market Value")
    plt.legend()
    sns.despine()
    
    plt.subplot(1, 2, 2)
    res = np.exp(np.array(y_test)).reshape(-1,1) - np.exp(pred)
    plt.scatter(np.exp(pred), res,alpha=0.1)
    plt.title("Residual Plot on Test Set",weight='bold')
    plt.xlabel("Predicted Market Value")
    plt.ylabel("Residuals")
    sns.despine()

# %%
sns.set(style='white',font_scale=1.5)
diagnostic_plot3(X_train_val, y_train_val,X_test,y_test)
plt.savefig('regression2.png',transparent=True, bbox_inches='tight')

# %%
Test_Set.dtypes
# Out:
# short_name                      object
# Market Value                   float64
# Predicted Market Value         float64
# age                              int64
# international_reputation         int64
# attacking_crossing             float64
# attacking_finishing            float64
# attacking_volleys              float64
# skill_fk_accuracy              float64
# skill_ball_control             float64
# movement_acceleration          float64
# movement_agility               float64
# movement_reactions             float64
# movement_balance               float64
# power_shot_power               float64
# power_stamina                  float64
# power_strength                 float64
# power_long_shots               float64
# mentality_aggression           float64
# mentality_positioning          float64
# mentality_penalties            float64
# mentality_composure            float64
# defending_marking_awareness    float64
# defending_sliding_tackle       float64
# goalkeeping_kicking            float64
# goalkeeping_positioning        float64
# preferred_foot_Right             uint8
# dtype: object

# %%
Test_Set['Predicted Market Value']
# Out:
# 0       3.166617e+08
# 1       1.611545e+08
# 2       1.328067e+08
# 3       1.192781e+08
# 4       8.990725e+07
#             ...
# 4805    3.380983e+04
# 4806    3.325141e+04
# 4807    2.751444e+04
# 4808    2.528957e+04
# 4809    2.333004e+04
# Name: Predicted Market Value, Length: 4810, dtype: float64

# %%
Test_Set['Market Value'] = Test_Set['Market Value'].apply(lambda x : "{:,}".format(int(x)))
Test_Set['Predicted Market Value'] = Test_Set['Predicted Market Value'].apply(lambda x : "{:,}".format(int(x)))
# Out:
# C:\Users\Kiko\AppData\Local\Temp/ipykernel_12192/3522353445.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_Set['Market Value'] = Test_Set['Market Value'].apply(lambda x : "{:,}".format(int(x)))
# C:\Users\Kiko\AppData\Local\Temp/ipykernel_12192/3522353445.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_Set['Predicted Market Value'] = Test_Set['Predicted Market Value'].apply(lambda x : "{:,}".format(int(x)))

# %%
Test_Set
# Out:
#          short_name Market Value Predicted Market Value  age  \
# 0         K. Mbappé  155,200,001            316,661,690   22
# 1         Neymar Jr  103,200,000            161,154,536   29
# 2          L. Messi   62,400,000            132,806,745   34
# 3        J. Kimmich   86,400,001            119,278,095   26
# 4          M. Salah   80,800,000             89,907,253   29
# ...             ...          ...                    ...  ...
# 4805      Guo Yunqi       56,001                 33,809   24
# 4806  Ruan Zhexiang       56,001                 33,251   24
# 4807     G. Doherty       16,001                 27,514   39
# 4808      C. Dundas    2,280,362                 25,289   40
# 4809      H. Shiota       16,001                 23,330   40
#
#       international_reputation  attacking_crossing  attacking_finishing  \
# 0                            4                78.0                 93.0
# 1                            5                85.0                 83.0
# 2                            5                85.0                 95.0
# 3                            4                91.0                 68.0
# 4                            4                79.0                 91.0
# ...                        ...                 ...                  ...
# 4805                         1                39.0                 32.0
# 4806                         1                38.0                 29.0
# 4807                         1                17.0                 11.0
# 4808                         1                34.0                 58.0
# 4809                         1                13.0                  9.0
#
#       attacking_volleys  skill_fk_accuracy  skill_ball_control  ...  \
# 0                  83.0               69.0                91.0  ...
# 1                  86.0               87.0                95.0  ...
# 2                  88.0               94.0                96.0  ...
# 3                  69.0               61.0                85.0  ...
# 4                  81.0               69.0                89.0  ...
# ...                 ...                ...                 ...  ...
# 4805               24.0               34.0                45.0  ...
# 4806               33.0               31.0                44.0  ...
# 4807               11.0               11.0                19.0  ...
# 4808               44.0               35.0                54.0  ...
# 4809               10.0               12.0                18.0  ...
#
#       power_long_shots  mentality_aggression  mentality_positioning  \
# 0                 82.0                  62.0                   92.0
# 1                 81.0                  63.0                   86.0
# 2                 94.0                  44.0                   93.0
# 3                 84.0                  89.0                   80.0
# 4                 84.0                  63.0                   91.0
# ...                ...                   ...                    ...
# 4805              34.0                  51.0                   45.0
# 4806              28.0                  52.0                   33.0
# 4807              13.0                  32.0                   12.0
# 4808              52.0                  42.0                   57.0
# 4809               6.0                  24.0                    6.0
#
#       mentality_penalties  mentality_composure  defending_marking_awareness  \
# 0                    79.0                 88.0                         26.0
# 1                    93.0                 93.0                         35.0
# 2                    75.0                 96.0                         20.0
# 3                    44.0                 85.0                         85.0
# 4                    86.0                 90.0                         38.0
# ...                   ...                  ...                          ...
# 4805                 41.0                 40.0                         43.0
# 4806                 43.0                 41.0                         38.0
# 4807                 11.0                 29.0                         18.0
# 4808                 56.0                 53.0                         20.0
# 4809                 13.0                 26.0                         21.0
#
#       defending_sliding_tackle  goalkeeping_kicking  goalkeeping_positioning  \
# 0                         32.0                  7.0                     11.0
# 1                         29.0                 15.0                     15.0
# 2                         24.0                 15.0                     14.0
# 3                         79.0                  7.0                     15.0
# 4                         41.0                  9.0                     11.0
# ...                        ...                  ...                      ...
# 4805                      44.0                  8.0                     11.0
# 4806                      44.0                 13.0                     11.0
# 4807                       9.0                 57.0                     55.0
# 4808                      16.0                 10.0                     12.0
# 4809                      15.0                 54.0                     66.0
#
#       preferred_foot_Right
# 0                        1
# 1                        1
# 2                        0
# 3                        1
# 4                        0
# ...                    ...
# 4805                     1
# 4806                     1
# 4807                     1
# 4808                     1
# 4809                     1
#
# [4810 rows x 27 columns]

# %%
#Test_Set['Market Value'] = Test_Set['Market Value'].apply(lambda x : "{:,}".format(int(x)))
#Test_Set['Predicted Market Value'] = Test_Set['Predicted Market Value'].apply(lambda x : "{:,}".format(int(x)))
#Test_Set[['defending','passing','physic','shooting','goalkeeping']] = Test_Set[['defending','passing','physic','shooting','goalkeeping']].apply(lambda x: round(x,1)) #'international_reputation'
Test_Set = Test_Set.rename(columns={'Market Value':'Market Value (Euros)','Predicted Market Value': 'Predicted Market Value (Euros)'})
Test_Set
# Out:
#          short_name Market Value (Euros) Predicted Market Value (Euros)  age  \
# 0         K. Mbappé          155,200,001                    316,661,690   22
# 1         Neymar Jr          103,200,000                    161,154,536   29
# 2          L. Messi           62,400,000                    132,806,745   34
# 3        J. Kimmich           86,400,001                    119,278,095   26
# 4          M. Salah           80,800,000                     89,907,253   29
# ...             ...                  ...                            ...  ...
# 4805      Guo Yunqi               56,001                         33,809   24
# 4806  Ruan Zhexiang               56,001                         33,251   24
# 4807     G. Doherty               16,001                         27,514   39
# 4808      C. Dundas            2,280,362                         25,289   40
# 4809      H. Shiota               16,001                         23,330   40
#
#       international_reputation  attacking_crossing  attacking_finishing  \
# 0                            4                78.0                 93.0
# 1                            5                85.0                 83.0
# 2                            5                85.0                 95.0
# 3                            4                91.0                 68.0
# 4                            4                79.0                 91.0
# ...                        ...                 ...                  ...
# 4805                         1                39.0                 32.0
# 4806                         1                38.0                 29.0
# 4807                         1                17.0                 11.0
# 4808                         1                34.0                 58.0
# 4809                         1                13.0                  9.0
#
#       attacking_volleys  skill_fk_accuracy  skill_ball_control  ...  \
# 0                  83.0               69.0                91.0  ...
# 1                  86.0               87.0                95.0  ...
# 2                  88.0               94.0                96.0  ...
# 3                  69.0               61.0                85.0  ...
# 4                  81.0               69.0                89.0  ...
# ...                 ...                ...                 ...  ...
# 4805               24.0               34.0                45.0  ...
# 4806               33.0               31.0                44.0  ...
# 4807               11.0               11.0                19.0  ...
# 4808               44.0               35.0                54.0  ...
# 4809               10.0               12.0                18.0  ...
#
#       power_long_shots  mentality_aggression  mentality_positioning  \
# 0                 82.0                  62.0                   92.0
# 1                 81.0                  63.0                   86.0
# 2                 94.0                  44.0                   93.0
# 3                 84.0                  89.0                   80.0
# 4                 84.0                  63.0                   91.0
# ...                ...                   ...                    ...
# 4805              34.0                  51.0                   45.0
# 4806              28.0                  52.0                   33.0
# 4807              13.0                  32.0                   12.0
# 4808              52.0                  42.0                   57.0
# 4809               6.0                  24.0                    6.0
#
#       mentality_penalties  mentality_composure  defending_marking_awareness  \
# 0                    79.0                 88.0                         26.0
# 1                    93.0                 93.0                         35.0
# 2                    75.0                 96.0                         20.0
# 3                    44.0                 85.0                         85.0
# 4                    86.0                 90.0                         38.0
# ...                   ...                  ...                          ...
# 4805                 41.0                 40.0                         43.0
# 4806                 43.0                 41.0                         38.0
# 4807                 11.0                 29.0                         18.0
# 4808                 56.0                 53.0                         20.0
# 4809                 13.0                 26.0                         21.0
#
#       defending_sliding_tackle  goalkeeping_kicking  goalkeeping_positioning  \
# 0                         32.0                  7.0                     11.0
# 1                         29.0                 15.0                     15.0
# 2                         24.0                 15.0                     14.0
# 3                         79.0                  7.0                     15.0
# 4                         41.0                  9.0                     11.0
# ...                        ...                  ...                      ...
# 4805                      44.0                  8.0                     11.0
# 4806                      44.0                 13.0                     11.0
# 4807                       9.0                 57.0                     55.0
# 4808                      16.0                 10.0                     12.0
# 4809                      15.0                 54.0                     66.0
#
#       preferred_foot_Right
# 0                        1
# 1                        1
# 2                        0
# 3                        1
# 4                        0
# ...                    ...
# 4805                     1
# 4806                     1
# 4807                     1
# 4808                     1
# 4809                     1
#
# [4810 rows x 27 columns]

# %%
Test_Set.to_csv('prueba final_lr.csv')

# %%
def diagnostic_plot4(x_train, y_train, x_test, y_test):
    plt.figure(figsize=(22,8))
    
    poly = make_pipeline(PolynomialFeatures(4), LinearRegression())
    poly.fit(x_train,y_train)
    pred = poly.predict(x_test)
    
  #  rgr = LinearRegression()
  #  rgr.fit(x_train,y_train)
  #  pred = rgr.predict(x_test)    

    plt.subplot(1, 2, 1)
    plt.scatter(pred,y_test,alpha=0.1)
    plt.plot(y_test, y_test, color='red',linewidth=1,label='Identity Line (Log Market Value)')
    plt.title("Regression Fit on Test Set",weight='bold')
    plt.xlabel("Log Predicted Market Value")
    plt.ylabel("Log Market Value")
    plt.legend(loc='lower right')
    sns.despine()
    
    plt.subplot(1, 2, 2)
    res = np.array(y_test).reshape(-1,1) - pred
    plt.scatter(pred, res,alpha=0.1)
    plt.title("Residual Plot on Test Set",weight='bold')
    plt.xlabel("Log Predicted Market Value")
    plt.ylabel("Residuals")
    sns.despine()
    
 #   plt.subplot(1, 3, 3)
 #   #Generates a probability plot of sample data against the quantiles of a 
 #   # specified theoretical distribution 
 #   stats.probplot(res.T[0], dist="norm", plot=plt,)
 #   plt.title("Normal Q-Q plot")

# %%
poly = make_pipeline(PolynomialFeatures(4), LinearRegression())
poly.fit(X_train_val,y_train_val)
predicted = poly.predict(X_test)
predicted
# Out:
# array([[13.66149472],
#        [12.35810834],
#        [13.42018179],
#        ...,
#        [12.30523666],
#        [11.82917953],
#        [16.13225876]])

# %%
Test_Set_2 = pd.DataFrame(y_test).join(X_test).join(pd.DataFrame(players_22_norm['short_name']))
Test_Set_2['Log Market Value'] = np.exp(Test_Set_2['Log Market Value'] )
Test_Set_2 = Test_Set_2.rename(columns={'Log Market Value':'Market Value'})
Test_Set_2['Predicted Market Value'] = np.exp(predicted)
Test_Set_2 = Test_Set_2.sort_values(by='Predicted Market Value',ascending=False)
#Test_Set['Market Value'] = Test_Set['Market Value'].apply(lambda x : "{:,}".format(int(x)))
#Test_Set['Predicted Market Value'] = Test_Set['Predicted Market Value'].apply(lambda x : "{:,}".format(int(x)))

# %%
Test_Set_2 = Test_Set_2[['short_name','Market Value','Predicted Market Value','age','international_reputation','attacking_crossing', 'attacking_finishing',
       'attacking_volleys', 'skill_fk_accuracy', 'skill_ball_control',
       'movement_acceleration', 'movement_agility', 'movement_reactions',
       'movement_balance', 'power_shot_power', 'power_stamina',
       'power_strength', 'power_long_shots', 'mentality_aggression',
       'mentality_positioning', 'mentality_penalties', 'mentality_composure',
       'defending_marking_awareness', 'defending_sliding_tackle',
       'goalkeeping_kicking', 'goalkeeping_positioning', 'preferred_foot_Right']]
Test_Set_2.reset_index(inplace=True)
Test_Set_2.drop('index',axis=1,inplace=True)
Test_Set_2
# Out:
# C:\Users\Kiko\AppData\Local\Temp/ipykernel_12192/3650533176.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_Set_2.drop('index',axis=1,inplace=True)
#           short_name  Market Value  Predicted Market Value  age  \
# 0     Juli Freitinho     4800001.0            2.004169e+09   21
# 1           M. Simon      136001.0            9.289909e+08   35
# 2           L. Messi    62400001.0            6.471879e+08   34
# 3         S. de Vrij    36000001.0            6.154914e+08   29
# 4           M. Salah    80800001.0            4.948285e+08   29
# ...              ...           ...                     ...  ...
# 4805   Ivo Gonçalves      104001.0            2.044585e+02   37
# 4806     C. Verfurth      480001.0            5.464104e+01   25
# 4807    C. Lucchetti      200001.0            7.385631e+00   43
# 4808        I. Khune      260001.0            5.454550e+00   34
# 4809    M. Dmitrović    12800001.0            4.448853e-02   29
#
#       international_reputation  attacking_crossing  attacking_finishing  \
# 0                            1                54.0                 44.0
# 1                            1                48.0                 64.0
# 2                            5                85.0                 95.0
# 3                            3                49.0                 25.0
# 4                            4                79.0                 91.0
# ...                        ...                 ...                  ...
# 4805                         1                25.0                 12.0
# 4806                         1                22.0                 38.0
# 4807                         1                23.0                 13.0
# 4808                         2                20.0                 16.0
# 4809                         1                30.0                 20.0
#
#       attacking_volleys  skill_fk_accuracy  skill_ball_control  ...  \
# 0                  35.0               50.0                63.0  ...
# 1                  36.0               29.0                61.0  ...
# 2                  88.0               94.0                96.0  ...
# 3                  27.0               16.0                75.0  ...
# 4                  81.0               69.0                89.0  ...
# ...                 ...                ...                 ...  ...
# 4805               15.0                9.0                24.0  ...
# 4806               22.0               18.0                65.0  ...
# 4807               18.0               30.0                35.0  ...
# 4808               13.0               38.0                32.0  ...
# 4809               20.0               18.0                 9.0  ...
#
#       power_long_shots  mentality_aggression  mentality_positioning  \
# 0                 45.0                  82.0                   67.0
# 1                 58.0                  93.0                   63.0
# 2                 94.0                  44.0                   93.0
# 3                 60.0                  77.0                   31.0
# 4                 84.0                  63.0                   91.0
# ...                ...                   ...                    ...
# 4805              11.0                  38.0                   18.0
# 4806              59.0                  43.0                   53.0
# 4807              16.0                  45.0                   16.0
# 4808              20.0                  32.0                   14.0
# 4809              17.0                  20.0                    9.0
#
#       mentality_penalties  mentality_composure  defending_marking_awareness  \
# 0                    63.0                 71.0                         82.0
# 1                    66.0                 64.0                         29.0
# 2                    75.0                 96.0                         20.0
# 3                    41.0                 85.0                         89.0
# 4                    86.0                 90.0                         38.0
# ...                   ...                  ...                          ...
# 4805                 17.0                 57.0                          9.0
# 4806                 71.0                 59.0                         60.0
# 4807                 54.0                 41.0                         21.0
# 4808                 49.0                 41.0                         17.0
# 4809                 58.0                 59.0                         19.0
#
#       defending_sliding_tackle  goalkeeping_kicking  goalkeeping_positioning  \
# 0                         75.0                 14.0                     13.0
# 1                         39.0                 11.0                     16.0
# 2                         24.0                 15.0                     14.0
# 3                         85.0                  7.0                     14.0
# 4                         41.0                  9.0                     11.0
# ...                        ...                  ...                      ...
# 4805                      13.0                 64.0                     70.0
# 4806                      58.0                  6.0                     13.0
# 4807                      13.0                 77.0                     69.0
# 4808                      15.0                 90.0                     64.0
# 4809                      20.0                 78.0                     80.0
#
#       preferred_foot_Right
# 0                        1
# 1                        1
# 2                        0
# 3                        1
# 4                        0
# ...                    ...
# 4805                     1
# 4806                     1
# 4807                     1
# 4808                     1
# 4809                     0
#
# [4810 rows x 27 columns]

# %%
mean_absolute_error(Test_Set_2['Market Value'],Test_Set_2['Predicted Market Value'])
# Out:
# 2866340.1128624855

# %%
r2_score(Test_Set_2['Market Value'],Test_Set_2['Predicted Market Value'])
# Out:
# -32.73863349715972

# %%
stats.kurtosis(Test_Set_2['Market Value']-Test_Set_2['Predicted Market Value'])
# Out:
# 1958.4360295615522

# %%
sns.set(style='white',font_scale=1.5)
diagnostic_plot4(X_train_val, y_train_val,X_test,y_test)
plt.savefig('regression2.png',transparent=True, bbox_inches='tight')

# %%
Test_Set_2['Market Value'] = Test_Set_2['Market Value'].apply(lambda x : "{:,}".format(int(x)))
Test_Set_2['Predicted Market Value'] = Test_Set_2['Predicted Market Value'].apply(lambda x : "{:,}".format(int(x)))
# Out:
# C:\Users\Kiko\AppData\Local\Temp/ipykernel_12192/2950278558.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_Set_2['Market Value'] = Test_Set_2['Market Value'].apply(lambda x : "{:,}".format(int(x)))
# C:\Users\Kiko\AppData\Local\Temp/ipykernel_12192/2950278558.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test_Set_2['Predicted Market Value'] = Test_Set_2['Predicted Market Value'].apply(lambda x : "{:,}".format(int(x)))

# %%
#Test_Set['Market Value'] = Test_Set['Market Value'].apply(lambda x : "{:,}".format(int(x)))
#Test_Set['Predicted Market Value'] = Test_Set['Predicted Market Value'].apply(lambda x : "{:,}".format(int(x)))
#Test_Set_2[['defending','passing','physic','shooting','goalkeeping']] = Test_Set_2[['defending','passing','physic','shooting','goalkeeping']].apply(lambda x: round(x,1)) #'international_reputation'
Test_Set_2 = Test_Set_2.rename(columns={'Market Value':'Market Value (Euros)','Predicted Market Value': 'Predicted Market Value (Euros)'})
Test_Set_2
# Out:
#           short_name Market Value (Euros) Predicted Market Value (Euros)  age  \
# 0     Juli Freitinho            4,800,000                  2,004,168,998   21
# 1           M. Simon              136,000                    928,990,862   35
# 2           L. Messi           62,400,000                    647,187,876   34
# 3         S. de Vrij           36,000,001                    615,491,373   29
# 4           M. Salah           80,800,000                    494,828,509   29
# ...              ...                  ...                            ...  ...
# 4805   Ivo Gonçalves              104,001                            204   37
# 4806     C. Verfurth              480,001                             54   25
# 4807    C. Lucchetti              200,000                              7   43
# 4808        I. Khune              260,000                              5   34
# 4809    M. Dmitrović           12,800,000                              0   29
#
#       international_reputation  attacking_crossing  attacking_finishing  \
# 0                            1                54.0                 44.0
# 1                            1                48.0                 64.0
# 2                            5                85.0                 95.0
# 3                            3                49.0                 25.0
# 4                            4                79.0                 91.0
# ...                        ...                 ...                  ...
# 4805                         1                25.0                 12.0
# 4806                         1                22.0                 38.0
# 4807                         1                23.0                 13.0
# 4808                         2                20.0                 16.0
# 4809                         1                30.0                 20.0
#
#       attacking_volleys  skill_fk_accuracy  skill_ball_control  ...  \
# 0                  35.0               50.0                63.0  ...
# 1                  36.0               29.0                61.0  ...
# 2                  88.0               94.0                96.0  ...
# 3                  27.0               16.0                75.0  ...
# 4                  81.0               69.0                89.0  ...
# ...                 ...                ...                 ...  ...
# 4805               15.0                9.0                24.0  ...
# 4806               22.0               18.0                65.0  ...
# 4807               18.0               30.0                35.0  ...
# 4808               13.0               38.0                32.0  ...
# 4809               20.0               18.0                 9.0  ...
#
#       power_long_shots  mentality_aggression  mentality_positioning  \
# 0                 45.0                  82.0                   67.0
# 1                 58.0                  93.0                   63.0
# 2                 94.0                  44.0                   93.0
# 3                 60.0                  77.0                   31.0
# 4                 84.0                  63.0                   91.0
# ...                ...                   ...                    ...
# 4805              11.0                  38.0                   18.0
# 4806              59.0                  43.0                   53.0
# 4807              16.0                  45.0                   16.0
# 4808              20.0                  32.0                   14.0
# 4809              17.0                  20.0                    9.0
#
#       mentality_penalties  mentality_composure  defending_marking_awareness  \
# 0                    63.0                 71.0                         82.0
# 1                    66.0                 64.0                         29.0
# 2                    75.0                 96.0                         20.0
# 3                    41.0                 85.0                         89.0
# 4                    86.0                 90.0                         38.0
# ...                   ...                  ...                          ...
# 4805                 17.0                 57.0                          9.0
# 4806                 71.0                 59.0                         60.0
# 4807                 54.0                 41.0                         21.0
# 4808                 49.0                 41.0                         17.0
# 4809                 58.0                 59.0                         19.0
#
#       defending_sliding_tackle  goalkeeping_kicking  goalkeeping_positioning  \
# 0                         75.0                 14.0                     13.0
# 1                         39.0                 11.0                     16.0
# 2                         24.0                 15.0                     14.0
# 3                         85.0                  7.0                     14.0
# 4                         41.0                  9.0                     11.0
# ...                        ...                  ...                      ...
# 4805                      13.0                 64.0                     70.0
# 4806                      58.0                  6.0                     13.0
# 4807                      13.0                 77.0                     69.0
# 4808                      15.0                 90.0                     64.0
# 4809                      20.0                 78.0                     80.0
#
#       preferred_foot_Right
# 0                        1
# 1                        1
# 2                        0
# 3                        1
# 4                        0
# ...                    ...
# 4805                     1
# 4806                     1
# 4807                     1
# 4808                     1
# 4809                     0
#
# [4810 rows x 27 columns]

# %% [markdown]
# # Modelo entero

# %%
rgr = LinearRegression()
rgr.fit(X_model,y)
predicted = rgr.predict(X_model)    
predicted
# Out:
# array([18.62507581, 18.6728061 , 18.00500475, ..., 10.56787417,
#        10.80638471, 10.80638471])

# %%
Test_Set = pd.DataFrame(y).join(X_model).join(pd.DataFrame(players_22_norm['short_name']))
Test_Set['Log Market Value'] = np.exp(Test_Set['Log Market Value'] )
Test_Set = Test_Set.rename(columns={'Log Market Value':'Market Value'})
Test_Set['Predicted Market Value'] = np.exp(predicted)
Test_Set = Test_Set.sort_values(by='Predicted Market Value',ascending=False)
#Test_Set['Market Value'] = Test_Set['Market Value'].apply(lambda x : "{:,}".format(int(x)))
#Test_Set['Predicted Market Value'] = Test_Set['Predicted Market Value'].apply(lambda x : "{:,}".format(int(x)))

# %%
Test_Set.index
# Out:
# RangeIndex(start=0, stop=19239, step=1)

# %%
Test_Set = Test_Set[['short_name', 'overall', 'age', 'international_reputation','Market Value (Euros)', 'Predicted Market Value (Euros)']] #
#Test_Set.reset_index(inplace=True)
#Test_Set.drop('index',axis=1,inplace=True)
Test_Set
# Out:
#           short_name  overall  age  international_reputation  \
# 0          K. Mbappé       91   22                         4
# 1         E. Haaland       88   20                         4
# 2           J. Oblak       91   28                         5
# 3      G. Donnarumma       89   22                         3
# 4          Neymar Jr       91   29                         5
# ...              ...      ...  ...                       ...
# 19234      Gao Xiang       49   32                         1
# 19235  M. McChrystal       52   37                         1
# 19236       G. Maley       52   38                         1
# 19237     J. Russell       49   36                         1
# 19238       K. Miura       59   54                         1
#
#       Market Value (Euros) Predicted Market Value (Euros)
# 0              155,200,001                    284,621,707
# 1              110,000,001                    203,839,052
# 2               89,600,001                    171,320,551
# 3               95,600,001                    157,857,603
# 4              103,200,000                    152,060,900
# ...                    ...                            ...
# 19234               28,001                         15,330
# 19235               12,000                         14,968
# 19236                7,201                         13,285
# 19237               12,000                          9,514
# 19238            2,280,362                          7,493
#
# [19239 rows x 6 columns]

# %%
#Test_Set['Market Value (Euros)'] = Test_Set['Market Value (Euros)'].apply(lambda x : "{:,}".format(int(x)))
#Test_Set['Predicted Market Value (Euros)'] = Test_Set['Predicted Market Value (Euros)'].apply(lambda x : "{:,}".format(int(x)))

# %%
Test_Set.head(20)
# Out:
#              short_name  overall  age  international_reputation  \
# 0             K. Mbappé       91   22                         4
# 1            E. Haaland       88   20                         4
# 2              J. Oblak       91   28                         5
# 3         G. Donnarumma       89   22                         3
# 4             Neymar Jr       91   29                         5
# 5               H. Kane       90   27                         4
# 6        R. Lewandowski       92   32                         5
# 7              L. Messi       93   34                         5
# 8             J. Sancho       87   21                         3
# 9            J. Kimmich       89   26                         4
# 10         K. De Bruyne       91   30                         4
# 11  T. Alexander-Arnold       87   22                         3
# 12        M. ter Stegen       90   29                         4
# 13          R. Sterling       88   26                         4
# 14               H. Son       89   28                         4
# 15             N. Kanté       90   30                         4
# 16              Ederson       89   27                         3
# 17           Rúben Dias       87   24                         3
# 18           F. de Jong       87   24                         3
# 19             M. Salah       89   29                         4
#
#    Market Value (Euros) Predicted Market Value (Euros)
# 0           155,200,001                    284,621,707
# 1           110,000,001                    203,839,052
# 2            89,600,001                    171,320,551
# 3            95,600,001                    157,857,603
# 4           103,200,000                    152,060,900
# 5           103,600,000                    129,554,848
# 6            95,600,001                    128,675,732
# 7            62,400,000                    122,678,272
# 8            93,200,001                    121,436,092
# 9            86,400,001                    120,612,067
# 10          100,400,001                    109,630,845
# 11           91,200,001                    107,784,392
# 12           79,200,001                    102,063,358
# 13           86,000,001                     99,663,457
# 14           83,200,000                     95,018,232
# 15           80,000,000                     90,589,518
# 16           75,200,000                     86,957,284
# 17           82,000,001                     84,912,585
# 18           95,600,001                     84,912,585
# 19           80,800,000                     84,336,396

# %%
#Test_Set = Test_Set.rename(columns={'Market Value':'Market Value (Euros)','Predicted Market Value': 'Predicted Market Value (Euros)'})
#Test_Set
# Out:
#           Market Value (Euros)  overall  age  international_reputation  \
# sofifa_id
# 231747             155,200,001       91   22                         4
# 239085             110,000,001       88   20                         4
# 200389              89,600,001       91   28                         5
# 230621              95,600,001       89   22                         3
# 190871             103,200,000       91   29                         5
# ...                        ...      ...  ...                       ...
# 255618                  28,001       49   32                         1
# 149697                  12,000       52   37                         1
# 245558                   7,201       52   38                         1
# 157190                  12,000       49   36                         1
# 254704               2,280,362       59   54                         1
#
#               short_name Predicted Market Value (Euros)
# sofifa_id
# 231747         K. Mbappé                    284,621,707
# 239085        E. Haaland                    203,839,052
# 200389          J. Oblak                    171,320,551
# 230621     G. Donnarumma                    157,857,603
# 190871         Neymar Jr                    152,060,900
# ...                  ...                            ...
# 255618         Gao Xiang                         15,330
# 149697     M. McChrystal                         14,968
# 245558          G. Maley                         13,285
# 157190        J. Russell                          9,514
# 254704          K. Miura                          7,493
#
# [19239 rows x 6 columns]

# %%
Test_Set.to_csv('prueba final_lr_entero.csv')
